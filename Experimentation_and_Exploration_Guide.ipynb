# %% [markdown]
# #Link To Paper
# https://drive.google.com/file/d/1xbtyMn73fR8bx6IMe0sXpVuPo88Gy5PS/view?usp=sharing
#
# Please glance through to understand the code

# %% [markdown]
# # Setup

# %%
# %%capture
# !pip install wordcloud
# !pip install tensorflow_text
# !pip install rake-nltk
# !pip install keras-tuner

# %%
import os
import re
import string
import random
import pickle
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import inflect
import tensorflow_text
import tensorflow.keras.backend as K
import kerastuner as kt

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from keras.utils import vis_utils
from keras.models import Model, Sequential
from keras.layers import Input, LSTM, Dense, Embedding, TimeDistributed, Layer, GlobalAveragePooling1D, Flatten, Multiply
from keras.layers import Lambda, RepeatVector, Bidirectional, MultiHeadAttention, LayerNormalization, Dropout, Reshape, Concatenate
from tensorflow_text.tools.wordpiece_vocab import bert_vocab_from_dataset as bert_vocab
from tensorflow.keras.callbacks import EarlyStopping
from collections import Counter
from nltk.tokenize import RegexpTokenizer
from nltk import ngrams
from rake_nltk import Rake
from google.colab import files
from wordcloud import WordCloud, STOPWORDS
from IPython.display import SVG
from tensorflow.keras.losses import sparse_categorical_crossentropy
#nltk.download('words')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from ipykernel import kernelapp as app

# %%
################################### LOAD FILES ################################
jokes = np.load("encoded_jokes.npy", allow_pickle=True)

# Create tokenizer from saved vocab file
tokenizer = tensorflow_text.BertTokenizer('vocab.txt', **dict(lower_case=True))

# Tokenize jokes
tokenized_jokes = tokenizer.detokenize(jokes)
tokenized_jokes = list(tokenized_jokes.numpy())
data = []

for x in tokenized_jokes:
  x = [y.decode("utf-8") for y in x]
  x = " ".join([y for y in x if y != '[PAD]'])
  data.append(x)


# Extract keywords
r = Rake(max_length=1)
keywords = []

for x in data:
  kw = r.extract_keywords_from_text(x)
  kw = r.get_ranked_phrases()
  keywords.append(kw)


# Tokenize and encode keywords
keywords_int = tf.ragged.constant(keywords)
keywords_int = tokenizer.tokenize(keywords_int)
# Reshape
keywords_int = keywords_int.merge_dims(-2,-1).to_list()

# Squeeze list
seq_in = []
for x in keywords_int:
  x = [item for sublist in x for item in sublist]
  seq_in.append(x)

# Pad sequences
seq_in = keras.preprocessing.sequence.pad_sequences(seq_in,
                                            value=0,
                                            padding='post',
                                            maxlen=30)

# Prepare the sequences
#seq_in = np.insert(seq_in[:,:-1], 0, 2, axis=1)
seq_out = jokes[:, :-1]
seq_out = np.insert(seq_out[:,:-1], 0, 2, axis=1)
seq_lab = np.expand_dims(seq_out[:, 1:],axis=2)
seq_lab = keras.preprocessing.sequence.pad_sequences(seq_lab,
                                            value=0,
                                            padding='post',
                                            maxlen=30)

# Hyper Parameters
batch_size = 128
vocab_size = 9832
maxlen = 30
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/ragged/ragged_tensor.py:2053: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(rows)

# %%
# Get the required data
source = seq_out[1000:]
target = seq_out[1000:]
keywords = seq_in[1000:]
labels = seq_lab[1000:]

# Select test set.
test_seq = seq_out[:1000]
test_kw = seq_in[:1000]

# %% [markdown]
# # Utils

# %%
def causal_attention_mask(batch_size, n_dest, n_src, dtype):
    """
    Mask the upper half of the dot product matrix in self attention.
    This prevents flow of information from future tokens to current token.
    1's in the lower triangle, counting from the lower right corner.
    """
    i = tf.range(n_dest)[:, None]
    j = tf.range(n_src)
    m = i >= j - n_src + n_dest
    mask = tf.cast(m, dtype)
    mask = tf.reshape(mask, [1, n_dest, n_src])
    mult = tf.concat(
        [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)], 0
    )
    return tf.tile(mask, mult)

class TokenAndPositionEmbedding(Layer):
    def __init__(self, maxlen, vocab_size, embed_dim):
        super(TokenAndPositionEmbedding, self).__init__()
        self.token_emb = Embedding(input_dim=vocab_size, output_dim=embed_dim)
        self.pos_emb = Embedding(input_dim=maxlen, output_dim=embed_dim)

    def call(self, x):
        maxlen = tf.shape(x)[-1]
        positions = tf.range(start=0, limit=maxlen, delta=1)
        positions = self.pos_emb(positions)
        x = self.token_emb(x)
        return x + positions

class TransformerBlock(Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = MultiHeadAttention(num_heads, embed_dim)
        self.ffn = Sequential(
            [Dense(ff_dim, activation="relu"), Dense(embed_dim),]
        )
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)

    def call(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size = input_shape[0]
        seq_len = input_shape[1]
        causal_mask = causal_attention_mask(batch_size, seq_len, seq_len, tf.bool)
        attention_output = self.att(inputs, inputs, attention_mask=causal_mask)
        attention_output = self.dropout1(attention_output)
        out1 = self.layernorm1(inputs + attention_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output)
        return self.layernorm2(out1 + ffn_output)

# %%
# Generator Callback
class TextGenerator(keras.callbacks.Callback):
    """A callback to generate text from a trained model.
    1. Feed some starting prompt to the model
    2. Predict probabilities for the next token
    3. Sample the next token and add it to the next input

    Arguments:
        max_tokens: Integer, the number of tokens to be generated after prompt.
        start_tokens: List of integers, the token indices for the starting prompt.
        index_to_word: List of strings, obtained from the TextVectorization layer.
        top_k: Integer, sample from the `top_k` token predictions.
        print_every: Integer, print after this many epochs.
    """

    def __init__(
        self, max_tokens, start_prompt, tokenizer, top_k=3, print_every=1
    ):
        start_tokens = tokenizer.tokenize(start_prompt)
        start_tokens = tf.squeeze(start_tokens,axis=0)
        start_tokens = list(tf.squeeze(start_tokens, axis=1).numpy())
        start_tokens = [_ for _ in start_tokens]

        self.max_tokens = max_tokens
        self.start_tokens = start_tokens
        self.print_every = print_every
        self.k = top_k
        self.tokenizer = tokenizer

    def sample_from(self, logits):
        logits, indices = tf.math.top_k(logits, k=self.k, sorted=True)
        indices = list(np.asarray(indices).astype("int32"))
        preds = keras.activations.softmax(tf.expand_dims(logits, 0))[0]
        preds = np.asarray(preds).astype("float32")
        return np.random.choice(indices, p=preds)

    def detokenize(self, number):
        x = tokenizer.detokenize([[number]]).to_list()
        x = x[0][0].decode("utf-8")
        return x

    def on_epoch_end(self, epoch, logs=None):
        start_tokens = [_ for _ in self.start_tokens]
        if (epoch + 1) % self.print_every != 0:
            return
        num_tokens_generated = 0
        tokens_generated = []
        while num_tokens_generated <= self.max_tokens:
            pad_len = maxlen - len(start_tokens)
            sample_index = len(start_tokens) - 1
            if pad_len < 0:
                x = start_tokens[:maxlen]
                sample_index = maxlen - 1
            elif pad_len > 0:
                x = start_tokens + [0] * pad_len
            else:
                x = start_tokens
            x = np.array([x])
            y, _ = self.model.predict(x)
            sample_token = self.sample_from(y[0][sample_index])
            tokens_generated.append(sample_token)
            start_tokens.append(sample_token)
            num_tokens_generated = len(tokens_generated)
            word_tokens = [self.detokenize(_) for _ in self.start_tokens + tokens_generated]
        txt = " ".join([x for x in word_tokens if x != '[PAD]'])
        print(f"generated text:\n{txt}\n")

# %%
############################### TOP-K Sampling ##############################
def generate(model, max_tokens, start_prompt, tokenizer, top_k=3, print_every=1):
        # Tokenise prompt
        start_tokens = tokenizer.tokenize(start_prompt)
        start_tokens = tf.squeeze(start_tokens,axis=0)
        start_tokens = list(tf.squeeze(start_tokens, axis=1).numpy())
        start_tokens = [_ for _ in start_tokens]
        
        # Start generating
        num_tokens_generated = 0
        tokens_generated = []
        while num_tokens_generated <= max_tokens:
            pad_len = maxlen - len(start_tokens)
            sample_index = len(start_tokens) - 1
            if pad_len < 0:
                x = start_tokens[:maxlen]
                sample_index = maxlen - 1
            elif pad_len > 0:
                x = start_tokens + [0] * pad_len
            else:
                x = start_tokens
            x = np.array([x])
            y, _ = model.predict(x)

            logits = y[0][sample_index]
            logits, indices = tf.math.top_k(logits, k=top_k, sorted=True)
            indices = np.asarray(indices).astype("int32")

            # remove zero predictions
            #drop = np.where(indices == 0)
            #indices = indices[indices != 0]
            #logits = np.delete(logits.numpy(),drop)

            # Pass through softmax
            preds = keras.activations.softmax(tf.expand_dims(logits, 0))[0]
            preds = np.asarray(preds).astype("float32")
            sample_token = np.random.choice(indices, p=preds)

            # Stop generating if end of sequence
            if sample_token == 0:
              break

            tokens_generated.append(sample_token)
            start_tokens.append(sample_token)
            num_tokens_generated = len(tokens_generated)
            #Detokenize
            word_tokens = tokenizer.detokenize([start_tokens]).to_list()
            #Decode
            word_tokens = [x.decode("utf-8") for x in word_tokens[0]]
            # Drop pads and convert to string
            txt = " ".join([x for x in word_tokens])
            txt = txt.replace(" ##", "")
        return txt


####################### TEST ################################
def test_model(model):
  samples = []
  samples.append("how do you end two deaf persons '")
  samples.append("What does a blonde have in common with a hurricane")
  samples.append("I went to a white pride parade the other day")
  samples.append("i would  make a joke about my neighbor")
  samples.append("what is the difference between god and you")

  # Check if model prints the correct sentence, given first 7 tokens
  for i in range(len(samples)):
    sample = generate(model, maxlen, samples[i], tokenizer)
    #print("TRUE: ", s[i])
    print("INPUT: ", samples[i])
    print("GENERATED: ",sample)
    print("")

# %%
###################################### LUONG ATTENTION LAYER #############################
class LuongAttentionLayer(Layer):
  def compute_mask(self, inputs, mask=None):
    if mask == None:
      return None
    return mask[1]

  def compute_output_shape(self, input_shape):
    return (input_shape[1][0],input_shape[1][1],input_shape[1][2]*2)


  def call(self, inputs, mask=None):
    encoder_outputs, decoder_outputs = inputs

    # transpose the dimensions of decoder outputs
    decoder_outputs_t = K.permute_dimensions(decoder_outputs, (0,2,1))

    # calculate luong score
    luong_score = K.batch_dot(encoder_outputs,decoder_outputs_t)
    luong_score = K.softmax(luong_score, axis=1) # along the 2nd axis

    # expand the dimensions of luong score and encoded outputs to enable multiplication
    luong_score = K.expand_dims(luong_score, axis=-1) # along last axis
    encoder_outputs = K.expand_dims(encoder_outputs, axis=2) # along 2nd axis

    # get encoded vector
    encoder_vector = encoder_outputs * luong_score
    encoder_vector = K.sum(encoder_vector, axis=1, keepdims=False)

    # [batch,max_dec,2*emb]
    new_decoder_outputs = K.concatenate([decoder_outputs, encoder_vector])

    return new_decoder_outputs

# %%
######################################## SAMPLING LAYER ####################################
class Sampling(Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = K.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon


#################################### VAE LOSS ##############################
def vae_loss(y_true, y_pred):
    xent_loss = sparse_categorical_crossentropy(y_true, y_pred)
    kl_loss =  -0.5 * (1 + sigma - tf.square(mu) - tf.exp(sigma))
    kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
    return xent_loss + kl_loss

# %%
def decoder_decode(topic, start=[2]):

    # Encode the input as state vectors.
    (e_out, e_h, e_c) = encoder_model.predict(topic)

    # Generate empty target sequence of length 1
    target_seq = np.zeros((1, 1))

    # Populate the first word of target sequence with the index of start token.
    for i in range(len(start)):
      target_seq[i, i] = start[i]

    stop_condition = False
    decoded_sentence = ''

    while not stop_condition:
        (output_tokens, h, c) = decoder_model.predict([target_seq]
                + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        #sampled_token = reverse_target_word_index[sampled_token_index]
        sampled_token = tokenizer.detokenize([[sampled_token_index]]).to_list()
        sampled_token = sampled_token[0][0].decode("utf-8")

        if sampled_token != '[PAD]':
            decoded_sentence += ' ' + sampled_token

        # Exit condition: either hit max length or find the stop word.
        if sampled_token == '[PAD]' or len(decoded_sentence.split()) \
            >= maxlen - 1:
            stop_condition = True

        # Update the target sequence (of length 1)
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        (e_h, e_c) = (h, c)

    return decoded_sentence.replace(" ##",'')

# Load models
def load_model(model_filename, model_weights_filename):
    with open(model_filename, 'r', encoding='utf8') as f:
        model = keras.models.model_from_json(f.read())
    model.load_weights(model_weights_filename)
    return model

# %%
def detokenize(indices):
  word_tokens = tokenizer.detokenize([indices]).to_list()
  word_tokens = [x.decode("utf-8") for x in word_tokens[0]]
  return word_tokens
  return " ".join([x for x in word_tokens if x != '[PAD]'])

# %% [markdown]
# # Joke-Seq2Seq

# %%
###################################### LUONG ATTENTION LAYER #############################
class LuongAttentionLayer(layers.Layer):
  def compute_mask(self, inputs, mask=None):
    if mask == None:
      return None
    return mask[1]

  def compute_output_shape(self, input_shape):
    return (input_shape[1][0],input_shape[1][1],input_shape[1][2]*2)


  def call(self, inputs, mask=None):
    encoder_outputs, decoder_outputs = inputs

    # transpose the dimensions of decoder outputs
    decoder_outputs_t = K.permute_dimensions(decoder_outputs, (0,2,1))

    # calculate luong score
    luong_score = K.batch_dot(encoder_outputs,decoder_outputs_t)
    luong_score = K.softmax(luong_score, axis=1) # along the 2nd axis

    # expand the dimensions of luong score and encoded outputs to enable multiplication
    luong_score = K.expand_dims(luong_score, axis=-1) # along last axis
    encoder_outputs = K.expand_dims(encoder_outputs, axis=2) # along 2nd axis

    # get encoded vector
    encoder_vector = encoder_outputs * luong_score
    encoder_vector = K.sum(encoder_vector, axis=1, keepdims=False)

    # [batch,max_dec,2*emb]
    new_decoder_outputs = K.concatenate([decoder_outputs, encoder_vector])

    return new_decoder_outputs

######################################## SAMPLING LAYER ####################################
class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = K.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
# Hyperparams
latent_dim = 100
embedding_dim = 200

#################################### ENCODER ##################################
# Encoder inputs
encoder_inputs = keras.Input(shape=(maxlen, ))

# Embedding layer
enc_emb = layers.Embedding(vocab_size, latent_dim, input_length=maxlen)(encoder_inputs)

# Sentence Average
enc_avg = layers.GlobalAveragePooling1D()(enc_emb)

# Hidden Dense
hidden_dense = layers.Dense(latent_dim)
hidden = hidden_dense(enc_avg)

# Encoder dense
enc_dense = layers.Dense(latent_dim)
encoder_outputs = enc_dense(enc_emb)


#################################### DECODER ####################################
# Decoder inputs
decoder_inputs = keras.Input(shape=(maxlen, ))

# Decoder embedding layer
dec_emb_layer = layers.Embedding(vocab_size, latent_dim, trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = layers.LSTM(latent_dim, 
                    return_sequences=True,
                    return_state=True, 
                    dropout=0.4,
                    recurrent_dropout=0.0)

(decoder_outputs, decoder_fwd_state, decoder_back_state) = decoder_lstm(dec_emb, 
                                                           initial_state=[hidden, hidden])

# Add Luong attention
attention = LuongAttentionLayer()
decoder_outputs = attention([encoder_outputs,decoder_outputs])

# Dense layer
decoder_dense = layers.TimeDistributed(layers.Dense(vocab_size, activation='softmax'))
decoder_outputs = decoder_dense(decoder_outputs)


#################################### VAE MODEL ##############################
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# embedding_8 (Embedding)         (None, 30, 100)      983200      input_9[0][0]
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 30)]         0
# __________________________________________________________________________________________________
# global_average_pooling1d_4 (Glo (None, 100)          0           embedding_8[0][0]
# __________________________________________________________________________________________________
# embedding_9 (Embedding)         (None, 30, 100)      983200      input_10[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 100)          10100       global_average_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 30, 100)      10100       embedding_8[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   [(None, 30, 100), (N 80400       embedding_9[0][0]
#                                                                  dense_9[0][0]
#                                                                  dense_9[0][0]
# __________________________________________________________________________________________________
# luong_attention_layer_3 (LuongA (None, 30, 200)      0           dense_10[0][0]
#                                                                  lstm_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (None, 30, 9832)     1976232     luong_attention_layer_3[0][0]
# ==================================================================================================
# Total params: 4,043,232
# Trainable params: 4,043,232
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def model_builder(hp):
  ########## HYPERPARAMS ###########
  latent_dim = hp.Int('latent_dim', min_value=50, max_value=300, step=10)
  embedding_dim = hp.Int('embedding_dim', min_value=50, max_value=300, step=10)
  dropout = hp.Float('dropout', min_value=0.2, max_value=0.8, step=0.05)
  hp_learning_rate = hp.Float('learning_rate', min_value=0.001, max_value=0.02, step=0.001)

  ######### ENCODER #############
  encoder_inputs = keras.Input(shape=(30, ))
  enc_emb = layers.Embedding(9832, embedding_dim, input_length=30)(encoder_inputs)
  encoder_outputs = layers.GlobalAveragePooling1D()(enc_emb)
  encoder_outputs = layers.Dense(latent_dim)(encoder_outputs)

  ######### DECODER #############
  decoder_inputs = keras.Input(shape=(30, ))
  dec_emb_layer = layers.Embedding(9832, latent_dim, trainable=True)
  dec_emb = dec_emb_layer(decoder_inputs)

  decoder_lstm = layers.LSTM(latent_dim, 
                    return_sequences=True,
                    return_state=True, 
                    dropout=dropout,
                    recurrent_dropout=0.0)

  (decoder_outputs, decoder_fwd_state, decoder_back_state) = decoder_lstm(dec_emb, 
                                                           initial_state=[encoder_outputs, encoder_outputs])

  repeat = layers.RepeatVector(30)
  encoder_output_repeated = repeat(encoder_outputs)
  attention = LuongAttentionLayer()
  decoder_outputs = attention([encoder_output_repeated,decoder_outputs])
  decoder_dense = layers.TimeDistributed(layers.Dense(9832, activation='softmax'))
  decoder_outputs = decoder_dense(decoder_outputs)

  ########### VAE #############
  model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)
  model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss=keras.losses.SparseCategoricalCrossentropy())

  return model

# %%
# Hyperparameter tuning
tuner = kt.Hyperband(
    model_builder,
    objective='val_loss',
    max_epochs=30,
    directory='hyperparams',
    hyperband_iterations=2)

tuner.search([seq_in,seq_out], seq_lab, epochs=10, validation_split=0.1, batch_size=batch_size)
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
print('Best Hyperparameters')
print(best_hps)
# Out:
# Trial 179 Complete [00h 16m 57s]
# val_loss: 2.426854372024536
#
# Best val_loss So Far: 2.304979085922241
# Total elapsed time: 16h 47m 52s
# INFO:tensorflow:Oracle triggered exit
# Best Hyperparameters
# <kerastuner.engine.hyperparameters.HyperParameters object at 0x7f06f1f0b810>

# %%
# Select best model
model = tuner.hypermodel.build(best_hps)
#model.save('seq2seq.h5')
with open('model.json', 'w', encoding='utf8') as f:
    f.write(model.to_json())
model.save_weights('model_weights.h5')
model.summary()

# %%
# Hyperparams
epochs = 10
lr = 0.01
optimizer = keras.optimizers.Adam(learning_rate=lr)
es = EarlyStopping(monitor='val_loss', mode='min', patience=5)

# Train the best model
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy')
history = model.fit([keywords, target],
       labels,
       batch_size=batch_size,
       epochs=epochs,
       validation_split=0.1,
       callbacks=[es])
# Out:
# Epoch 1/10
# 709/709 [==============================] - 36s 49ms/step - loss: 3.2983 - val_loss: 2.6924
# Epoch 2/10
# 709/709 [==============================] - 34s 48ms/step - loss: 2.5450 - val_loss: 2.4878
# Epoch 3/10
# 709/709 [==============================] - 35s 50ms/step - loss: 2.3433 - val_loss: 2.4203
# Epoch 4/10
# 709/709 [==============================] - 34s 48ms/step - loss: 2.2342 - val_loss: 2.3950
# Epoch 5/10
# 709/709 [==============================] - 35s 49ms/step - loss: 2.1622 - val_loss: 2.3844
# Epoch 6/10
# 709/709 [==============================] - 34s 48ms/step - loss: 2.1113 - val_loss: 2.3832
# Epoch 7/10
# 709/709 [==============================] - 34s 48ms/step - loss: 2.0730 - val_loss: 2.3883
# Epoch 8/10
# 709/709 [==============================] - 34s 48ms/step - loss: 2.0409 - val_loss: 2.3832
# Epoch 9/10
# 709/709 [==============================] - 35s 49ms/step - loss: 2.0156 - val_loss: 2.3744
# Epoch 10/10
# 709/709 [==============================] - 34s 49ms/step - loss: 1.9940 - val_loss: 2.3958

# %%
model.save_weights('seq2seq_weights.h5')

# %%
# Plot History
history_dict = history.history
plt.plot(range(1,epochs+1), history_dict['loss'], 'r', label='Training loss')
plt.plot(range(1,epochs+1), history_dict['val_loss'], 'g', label='Validation loss')
plt.title('Averaging Seq2Seq Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#################################### ENCODER ##################################
# Encoder inputs
encoder_inputs = keras.Input(shape=(maxlen, ))

# Embedding layer
enc_emb = layers.Embedding(vocab_size, latent_dim, input_length=maxlen)(encoder_inputs)

# Sentence Average
enc_avg = layers.GlobalAveragePooling1D()(enc_emb)

# Hidden Dense
hidden_dense = layers.Dense(latent_dim)
hidden = hidden_dense(enc_avg)

# Encoder dense
enc_dense = layers.Dense(latent_dim)
encoder_outputs = enc_dense(enc_emb)


#################################### DECODER ####################################
# Decoder inputs
decoder_inputs = keras.Input(shape=(maxlen, ))

# Decoder embedding layer
dec_emb_layer = layers.Embedding(vocab_size, latent_dim, trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = layers.LSTM(latent_dim, 
                    return_sequences=True,
                    return_state=True, 
                    dropout=0.4,
                    recurrent_dropout=0.0)

(decoder_outputs, decoder_fwd_state, decoder_back_state) = decoder_lstm(dec_emb, 
                                                           initial_state=[hidden, hidden])

# Add Luong attention
attention = LuongAttentionLayer()
decoder_outputs = attention([encoder_outputs,decoder_outputs])

# Dense layer
decoder_dense = layers.TimeDistributed(layers.Dense(vocab_size, activation='softmax'))
decoder_outputs = decoder_dense(decoder_outputs)


#################################### MODEL ##############################
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.summary()


#################################### INFERENCE ENCODER ################################
encoder_model = keras.Model(inputs=encoder_inputs, outputs=[encoder_outputs, hidden, hidden], name='encoder')
# Print summary
encoder_model.summary()
print('\n\n\n')

#################################### INFERENCE DECODER ################################
decoder_state_input_h = keras.Input(shape=(latent_dim, ))
decoder_state_input_c = keras.Input(shape=(latent_dim, ))
decoder_hidden_state_input = keras.Input(shape=(maxlen, latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2 = dec_emb_layer(decoder_inputs)

# To predict the next word in the sequence, set the initial states to the states from the previous time step
(decoder_outputs2, state_h2, state_c2) = decoder_lstm(dec_emb2,
        initial_state=[decoder_state_input_h, decoder_state_input_c])

# Attention
decoder_outputs2 = attention([decoder_hidden_state_input,decoder_outputs2])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_outputs2)

# Final decoder model
decoder_model = keras.Model([decoder_inputs] + [decoder_hidden_state_input,
                      decoder_state_input_h, decoder_state_input_c],
                      [decoder_outputs2] + [state_h2, state_c2], name="decoder")

# Print summary
decoder_model.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# embedding_8 (Embedding)         (None, 30, 100)      983200      input_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_4 (Glo (None, 100)          0           embedding_8[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 30, 100)      10100       embedding_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 100)          10100       global_average_pooling1d_4[0][0]
# ==================================================================================================
# Total params: 1,003,400
# Trainable params: 1,003,400
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
#
#
#
# Model: "decoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           [(None, 30)]         0
# __________________________________________________________________________________________________
# embedding_9 (Embedding)         (None, 30, 100)      983200      input_10[0][0]
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 100)]        0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 100)]        0
# __________________________________________________________________________________________________
# input_13 (InputLayer)           [(None, 30, 100)]    0
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   [(None, 30, 100), (N 80400       embedding_9[1][0]
#                                                                  input_11[0][0]
#                                                                  input_12[0][0]
# __________________________________________________________________________________________________
# luong_attention_layer_3 (LuongA (None, 30, 200)      0           input_13[0][0]
#                                                                  lstm_4[1][0]
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (None, 30, 9832)     1976232     luong_attention_layer_3[1][0]
# ==================================================================================================
# Total params: 3,039,832
# Trainable params: 3,039,832
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Test
real = np.load("encoded_jokes.npy", allow_pickle=True)
for i in range(100):
  keywords = test_kw[i]
  kw = detokenize(keywords)
  print("KEYWORDS:", [x for x in kw if x != '[PAD]' and x != '[START]'])
  true = detokenize(real[i])
  print("TRUE:", ' '.join([x for x in true if x != '[PAD]']))
  generated = decoder_decode(keywords.reshape(1, 30))
  print("GENERATED:", generated)
  print("")
# Out:
# KEYWORDS: ['switch', 'light', 'arguing']
# TRUE: how do you end two deaf persons ' arguing ? switch off the light .
# GENERATED:  two people are arguing with a light bulb . just won ' t switch off the switch .
#
# KEYWORDS: ['suckin', 'lot', 'lose', 'hurricane', 'house', 'first', 'common', 'blowin', 'blonde']
# TRUE: what does a blonde have in common with a hurricane ? first there is a lot of suckin and blowin , then you lose your house .
# GENERATED:  what do a blonde and a lot have in common ? they both both moan at the house .
#
# KEYWORDS: ['went', 'floats', 'day', 'circles']
# TRUE: i went to a white pride parade the other day . the floats just kept going around in circles about 200 miles per hour .
# GENERATED:  i went to the round of the other day i went round i went round in circles .
#
# KEYWORDS: ['would', 'neighbor', 'joke', 'home', 'close']
# TRUE: i would make a joke about my neighbor . but it would be too close to home
# GENERATED:  i would tell a joke about my neighbor is door . i would be a close to the home .
#
# KEYWORDS: ['god', 'everything', 'difference']
# TRUE: what is the difference between god and you ex wife ? god only wants 10 things . your ex wife wants half of everything .
# GENERATED:  what is the difference between god and god ? god doesn ' t make everything .
#
# KEYWORDS: ['swear', 'castrate']
# TRUE: i swear , i will castrate you do it , you won t . no balls bro .
# GENERATED:  i swear my actors i have a castrate bridge . i ' m a castrate .
#
# KEYWORDS: ['woman', 'way', 'tits', 'looking', 'eyes', 'checks']
# TRUE: the first thing a man notices about a woman is her eyes and when he made sure it is not looking his way , he checks out her tits
# GENERATED:  i ' m looking for a woman with her tits . she gets mad when she gets it when she gets it on her eyes .
#
# KEYWORDS: ['get', 'dead']
# TRUE: what is your favourite insult joke ? i will get it started 2090 called , you are dead and nobody misses you
# GENERATED:  what do you get when you cross a dead dead musician ? dead .
#
# KEYWORDS: ['way', 'thought', 'mall', 'harsh']
# TRUE: trump hows that mexican mall going ? mall ? we thought you said wall trump no way that is harsh , also hows that muslim band looking ?
# GENERATED:  i thought that was the same way to be a mall but i thought it was a pretty reich .
#
# KEYWORDS: ['anyone']
# TRUE: keanu reeves donates so much blood that anyone who has ever received donor blood is at least 6 keanu reeves .
# GENERATED:  anyone who is a lot like a new year old ? anyone who can ' t have a good partner .
#
# KEYWORDS: ['sneezes']
# TRUE: what does a nut say when he sneezes ? ca shew
# GENERATED:  what does a fly fly when a fly sneezes ? a dead centipede .
#
# KEYWORDS: ['nose', 'man', 'ejaculating', 'arrested']
# TRUE: a man was arrested for ejaculating out his nose but he did nutting wrong
# GENERATED:  a man was arrested over his nose he was arrested over .
#
# KEYWORDS: ['write', 'called']
# TRUE: my girlfriend asked me to write an inspirational poem about our love life . i called it , the load less swallowed
# GENERATED:  what is it called when you write a bladder infection ? a ginger belt
#
# KEYWORDS: ['understand', 'talk', 'heroin']
# TRUE: my local police chief does a talk on heroin so you can ' t understand any of it .
# GENERATED:  i don ' t understand my doctor is heroin addict , i ' m a lot like me .
#
# KEYWORDS: ['used', 'thought', 'think', 'telling', 'look', 'brain']
# TRUE: i used to think the brain was the most important organ . then i thought , look what is telling me that .
# GENERATED:  i used to look at my brain but i think i would look at the right ahead of my brain . i think i ' m telling me that
#
# KEYWORDS: ['tumblr', 'trending', 'saw', 'dashboard']
# TRUE: so i saw that princess diana is trending on tumblr . she is all over the dashboard
# GENERATED:  i saw on tumblr on tumblr but i saw her with flint .
#
# KEYWORDS: ['unless', 'speed', 'multiply', 'light', 'energy']
# TRUE: unless you multiply yourself by the speed of light then you energy .
# GENERATED:  life is like speed , then multiply yourself unless you multiply yourself . unless you multiply yourself .
#
# KEYWORDS: ['hollow', 'hillary', 'head']
# TRUE: what is more hollow than donald trump is head ? hillary is diazepam pen .
# GENERATED:  why does hillary clinton have longer than a bad joke ? she is a longer bottle .
#
# KEYWORDS: ['dog', 'boat']
# TRUE: why does a dog on a you boat have a deep bark ? because he is a sub woofer .
# GENERATED:  why did the dog get into the boat ? because he fell forward to the boat .
#
# KEYWORDS: ['reaction']
# TRUE: why don ' t people tell chemistry jokes ? because they never get a reaction .
# GENERATED:  chemistry joke is such a lot like food ? no reaction .
#
# KEYWORDS: ['yet', 'woman', 'w', 'q', 'infront', 'cow', 'back']
# TRUE: q what is infront of the woman , yet , at the back of the cow ? a w
# GENERATED:  q what did the cow say when she was in a cow ? q what did the cow say when she is in a cow ? a cow is
#
# KEYWORDS: ['nazi', 'followers', 'coming']
# TRUE: when hitler killed himself his followers did nazi that coming
# GENERATED:  why did hitler not not a lot of traditional colors ? he kept coming out of his browser .
#
# KEYWORDS: []
# TRUE:
# GENERATED:  what did the pirate say to the other ? aye matey
#
# KEYWORDS: ['sperm', 'directions', 'ask']
# TRUE: why does it take millions of sperm to fertilize one egg ? because they won ' t ask for directions
# GENERATED:  sperm banks are like a sperm bank , i have to ask them for directions .
#
# KEYWORDS: ['experience', 'belittling', 'attacked']
# TRUE: i was attacked by tiny bees . the experience was belittling .
# GENERATED:  i was attacked by a non man , but i was attacked by a few years ago . be attacked .
#
# KEYWORDS: ['spent', 'proud', 'pays', 'lot', 'life', 'brothels', 'bills']
# TRUE: i have spent a lot of my life in brothels . i am not proud of it , but it pays the bills .
# GENERATED:  i spent a brothel that is proud of the brothels . i have spent a lot of money .
#
# KEYWORDS: ['went', 'tiers', 'even', 'cake']
# TRUE: i went to a really depressing wedding recently . even the cake was in tiers .
# GENERATED:  i went to the cake was the cake was the cake was the cake was the cake was the cake was the cake .
#
# KEYWORDS: ['song', 'catchy']
# TRUE: a stormtrooper walks into a cantina stormtrooper damn this song is catchy
# GENERATED:  what song did the song say to catch a song ? catchy
#
# KEYWORDS: ['whens', 'door', 'ajar']
# TRUE: whens a door not a door ? when its ajar .
# GENERATED:  when is a door is favorite kind of door ? when it is ajar .
#
# KEYWORDS: ['little', 'difference']
# TRUE: what is the difference between ancient religious texts and fake news ? a little over 2000 years
# GENERATED:  what is the difference between a little newton and a little more than a little more than a little more than a little more than a little little
#
# KEYWORDS: ['call']
# TRUE: what do you call a graduated spider ? a web designer
# GENERATED:  what do you call a gay midget ? a boo bees
#
# KEYWORDS: ['see', 'mother', 'father', 'beauty']
# TRUE: a son asks his father . a son asks his father dad , what is beauty ? do you see your mother ? yes well that is not it
# GENERATED:  if your mother is a lot of children is mother , i see her father .
#
# KEYWORDS: ['rapist', 'predator', 'call']
# TRUE: what do you call an immigrant fighting a rapist ? alien vs . predator
# GENERATED:  what do you call a rapist with a rapist ? alien vs predator
#
# KEYWORDS: ['groups', 'even']
# TRUE: why do white girls always walk in groups with odd numbers ? they can ' t even
# GENERATED:  why cant groups of numbers travel ? because they can ' t even .
#
# KEYWORDS: ['rest', 'made', 'funeral', 'awkward']
# TRUE: got caught sniffing my sisters panties yesterday it made the rest of her funeral very awkward .
# GENERATED:  i made a funeral tomorrow i made the rest of the funeral .
#
# KEYWORDS: ['want', 'making', 'joke', 'hear']
# TRUE: you want to hear a joke ? me making it on the front page .
# GENERATED:  did you hear about the joke about making a joke ? it is making a joke .
#
# KEYWORDS: ['week', 'set', '100']
# TRUE: set your wifi password to 100 so when someone ask tell them it is how many times a week this gets reposted .
# GENERATED:  how did the schizophrenic executive go to the trash ? because he is a 100 , but 100 , but 100 , but 100 100 100 100 100 100
#
# KEYWORDS: ['fascist', 'faggot', 'call', 'axe']
# TRUE: what do you call a faggot with an axe ? a fascist
# GENERATED:  what do you call a fascist tree who is an axe ? axe mate .
#
# KEYWORDS: ['vegetables', 'thumbs', 'people', 'know', 'fingers']
# TRUE: you know how all thumbs are fingers , but not all fingers are thumbs ? some people can be vegetables , but vegetables can ' t be people .
# GENERATED:  i don ' t know why the jokes about their vegetables so i can ' t stopplays .
#
# KEYWORDS: ['marc', 'homosexual', 'group', 'friends']
# TRUE: they say one in ten men are homosexual in my group of friends i ' m pretty sure it is marc . he is really cute
# GENERATED:  what group of friends do you call a group of friends ? marcrculosis
#
# KEYWORDS: ['engineers']
# TRUE: a good joke for the engineers out there free time
# GENERATED:  what is the most common language ? they are both engineers .
#
# KEYWORDS: ['writing', 'song', 'getting', 'end']
# TRUE: i ' m writing a song about getting my front door lock replaced . there is a lovely key change at the end .
# GENERATED:  what song is the most popular part about the song about the end of the end of the song ? the end of the decade
#
# KEYWORDS: ['charge']
# TRUE: i gave away all of my dead batteries free of charge .
# GENERATED:  why did the neutron receive a nipple pierced ? because of charge .
#
# KEYWORDS: ['point', 'life', 'diarrhea', '80']
# TRUE: studies show that 80 of redditors suffer from diarrhea at some point in life then why are the rest enjoying it ?
# GENERATED:  the only one benefit of the vinyl solution in the vinyl solution , the other is the point of the people .
#
# KEYWORDS: ['someone', 'makes', 'cents', 'call']
# TRUE: what do you call a bad european banker that talks gibberish ? someone that makes no cents .
# GENERATED:  what do you call a british british pound ? someone who makes cents .
#
# KEYWORDS: ['win', 'olympics', 'logic', 'chance']
# TRUE: to win the olympics , you must go big or go home . by that logic , the refugee team never had a chance .
# GENERATED:  the man asked me what a chance of the father is logic fetish . enemy .
#
# KEYWORDS: ['frank', 'burn']
# TRUE: why won ' t people let hitler go to the bar bq ? he ' ll just burn the frank ' s
# GENERATED:  you know what you are frank ? you burn
#
# KEYWORDS: ['porn', 'disabled']
# TRUE: is all your porn here disabled ? no it is regular porn you sick fuck .
# GENERATED:  what porn does porn is disabled people with porn ? the porn trend .
#
# KEYWORDS: ['lazy', 'descirbe']
# TRUE: i can descirbe myself in just two words . lazy .
# GENERATED:  i ' m starting a debecruger . i ' m not lazy .
#
# KEYWORDS: ['wife', 'tequila', 'cliff']
# TRUE: why did the mexican man throw his wife off of a cliff ? tequila
# GENERATED:  why did the mexican push his wife off a cliff ? tequila
#
# KEYWORDS: ['nuts', 'heard', 'guy', 'glitter', 'dipped']
# TRUE: have you heard about the guy who dipped his nuts in glitter ? pretty ballsy
# GENERATED:  have you heard about the guy going to see a black hat ? he is going around going to see his nuts .
#
# KEYWORDS: ['reason', 'politicians', 'diapers', 'common']
# TRUE: politicians and diapers have one thing in common . they should both be changed regularly , and for the same reason .
# GENERATED:  what do hotdogs and diapers have in common ? both should be changed regularly .
#
# KEYWORDS: ['married', 'friends']
# TRUE: why couldn ' t stevie wonder see his friends ? because he was married
# GENERATED:  i have been married and i have a few years resolution . i ' m married .
#
# KEYWORDS: ['sex', 'problem', 'given', 'example']
# TRUE: nsfw houston , we have a problem i feel like porn has me given such unrealistic expectations about sex for example , having it with another person .
# GENERATED:  having sex is a problem with a problem with a good example for example for example airport security is the problem with a good partner .
#
# KEYWORDS: ['required', 'president', 'know', 'duck']
# TRUE: did you know the secret service is no longer allowed to say get down when the president is getting attacked ? now they are required to say donald , duck
# GENERATED:  you know why the required is a duck ? because it required the required to the required .
#
# KEYWORDS: []
# TRUE: whom did the boston strangler choke last ? the atlanta falcons .
# GENERATED:  what did the pirate say to the other ? aye matey
#
# KEYWORDS: ['got', 'friend', 'farm', 'cieio']
# TRUE: my friend just got a new job heading up old macdonald is farm . he is the cieio
# GENERATED:  friend i got a friend of a farmie . i got a cieioie .
#
# KEYWORDS: ['want', 'library', 'hang']
# TRUE: what is the best part of the library to hang out if you want to get laid ? adult friction .
# GENERATED:  i ' m a library , i ' m a library , i ' m a librarian . i ' m a librarian .
#
# KEYWORDS: ['wife', 'pants', 'morning', 'happy', 'got', 'found']
# TRUE: i got in my wife is pants this morning . she wasn ' t too happy once she found out .
# GENERATED:  i found out of my wife this morning i got her pants up this morning . i have got a happy meal .
#
# KEYWORDS: ['ex', 'eat', 'asshole']
# TRUE: if you are what you eat then that would explain why my ex is such an asshole .
# GENERATED:  what do you eat an asshole ? an asshole .
#
# KEYWORDS: ['call']
# TRUE: what do you call a testicle outside earth ? a space nut
# GENERATED:  what do you call a gay midget ? a boo bees
#
# KEYWORDS: ['work', 'used', 'taking', 'fired', 'days', 'couple']
# TRUE: i used to work in a calender factory but i was fired for taking a couple of days off .
# GENERATED:  taking a couple of these days but i used to work for days . but i ' m not fired .
#
# KEYWORDS: ['plenty', 'percs', 'make']
# TRUE: being a drug dealer is a tough job . but it has plenty of percs to make up for it .
# GENERATED:  percsccsulacs are in the streets of ancient insects there are plenty of percs .
#
# KEYWORDS: ['really', 'insomniac', 'hear', 'dyslexic', 'dog', 'agnostic']
# TRUE: did you hear about the dyslexic , agnostic , insomniac ? he was up all night wondering if there really was a dog .
# GENERATED:  did you hear about the agnostic insomniac who really likes to get up an agnostic ? he really likes to get up late .
#
# KEYWORDS: ['mum', 'found', 'concieved']
# TRUE: i found i out i was concieved at my grandmothers funeral appearently , my mum was trying comfort him . stupid mourning wood .
# GENERATED:  i found out of my mumced me in a orphanage prescription she was conved .
#
# KEYWORDS: ['ransomware', 'know']
# TRUE: hey officer , how did the hackers escape ? i don ' t know , they just ransomware .
# GENERATED:  did you know that hitler was ransomware ? he ransomware .
#
# KEYWORDS: ['ridiculous', 'health', 'even', 'bad']
# TRUE: it is ridiculous that there was such a long debate whether smoking would be bad for the health . even the nazis knew it is .
# GENERATED:  my health is bad forensive to be doing health . even that is bad for health .
#
# KEYWORDS: ['works', 'fertilizer', 'entremanure', 'call']
# TRUE: what do you call a self employed individual who works with fertilizer ? an entremanure .
# GENERATED:  what do you call a new fertilizer who works for a fertilizer ? a fertilizer .
#
# KEYWORDS: ['tomorrow', 'tell', 'take', 'ehh', 'change']
# TRUE: how many procrastinators does it take to change a light bulb ? ehh , i ' ll tell you tomorrow .
# GENERATED:  how many brexiteers does it take to change a light bulb ? i ' ll tell you tomorrow .
#
# KEYWORDS: ['time']
# TRUE: child psychologists hear touching stories from time to time .
# GENERATED:  what time does a mexican is time ? a time
#
# KEYWORDS: ['laptop', 'difference', 'consultant', 'butt']
# TRUE: what is the difference between an it consultant and a catholic priest ? the it consultant is laptop has no butt .
# GENERATED:  what is the difference between a laptop and a laptop ? a slight of his butt .
#
# KEYWORDS: ['want', 'sticking', 'means', 'meaning', 'many', 'lot', 'figured']
# TRUE: thanks everyone i want to thank everyone for sticking with me while i figured out the meaning of many . it means a lot .
# GENERATED:  i figured out how many people are sticking to dente . it is a lot of many people . that means a lot of many people .
#
# KEYWORDS: ['exactly']
# TRUE: me hey bro someone said you sound like an owl bro who ? me exactly
# GENERATED:  what is the best thing you are exactly like ? exactly . exactly like me skeletons .
#
# KEYWORDS: ['whey', 'claims', 'bodybuilder']
# TRUE: does anyone believe the bodybuilder who claims he never used protein suppliments ? no whey .
# GENERATED:  what does a bodybuilder say as a bodybuilder ? he is a protein ono .
#
# KEYWORDS: []
# TRUE: what do you call 2000 mockingbirds ? 2kilo mocking birds .
# GENERATED:  what did the pirate say to the other ? aye matey
#
# KEYWORDS: ['masturbate', 'hard', 'easy', 'choose']
# TRUE: we choose to masturbate , not because it is easy , but because it is hard .
# GENERATED:  i ' m easy to decide if you are not easy to myself .
#
# KEYWORDS: ['aula']
# TRUE: knock knock who is there ? aula . aula who ? allah huakbar
# GENERATED:  what did austria say when they are a big fan ? aula vader
#
# KEYWORDS: ['suicide', 'nevermind', 'leave', 'joke', 'hanging', 'ah']
# TRUE: wanna hear a joke about suicide ? ah , nevermind , i ' ll leave you hanging
# GENERATED:  have you ever heard about the joke about jeffrey epstein is worst nightmare ? nevermind , it was a lot of the time .
#
# KEYWORDS: ['pirate', 'charge', 'arr']
# TRUE: i ' m not often hired to be a pirate but when i am , i charge by the ' arr '
# GENERATED:  what is a pirate is favorite letter ? arr dead .
#
# KEYWORDS: ['sleep', 'saw', 'money']
# TRUE: was about to sleep when i saw the robber last night in my house searching for money . i immediately got up . and searched alongside with him .
# GENERATED:  i saw a new car that i saw a new iphone x men . i just saw a few days .
#
# KEYWORDS: ['road']
# TRUE: why did the dinosaur cross the road ? what road ?
# GENERATED:  why did the chicken cross the road ? because he was a little meteor .
#
# KEYWORDS: ['vegan', 'proud', 'meals', 'call']
# TRUE: i am proud to call myself a vegan but only in between meals .
# GENERATED:  what do you call a proud of meals ? a vegan .
#
# KEYWORDS: ['trying', 'transporting', 'tell', 'package', 'messed', 'mailman', 'joke', 'delivery']
# TRUE: a mailman was trying to tell a joke while transporting a package but he messed up the delivery
# GENERATED:  i messed up competitive to the mailman is like the mailman , i messed up when i messed up competitive . but when i messed up with no wonder
#
# KEYWORDS: ['paint']
# TRUE: who is this rorschach guy and why does he paint so many penises ?
# GENERATED:  why did the paint driver get kicked out of paint ? because he was a little meteor .
#
# KEYWORDS: []
# TRUE: how does harry potter order tequila shots ? patron us
# GENERATED:  what did the pirate say to the other ? aye matey
#
# KEYWORDS: ['wet', 'soft', 'pink', 'hard', 'goes', 'dry', 'comes']
# TRUE: what is pink ? ? ? goes in hard and dry and comes out soft and wet a bubble gum
# GENERATED:  what is pink and hard and comes out and wet and wet bubble gum out ?
#
# KEYWORDS: ['urination', 'pee', 'land', 'country']
# TRUE: what did the un say to the land of pee when it officially became a country ? urination .
# GENERATED:  if you are fully acting like a lot of peeinations . you are always urination .
#
# KEYWORDS: ['understand', 'told', 'ex']
# TRUE: i told the ambulance guys the wrong blood type for my ex now she should understand what rejection feels like .
# GENERATED:  i told my ex girlfriend for a few weeks ago i told her she was exc .
#
# KEYWORDS: ['thanks', 'see', 'guess', 'booming']
# TRUE: thanks to recent events i guess you could say the pressure cooker business is booming i ' ll see myself out now .
# GENERATED:  i guess that is a booming job . thanks , i guess it is booming
#
# KEYWORDS: ['women', 'way', 'stick', 'like', 'hot', 'em', 'dick']
# TRUE: i like my coffee like i like my women not too hot . that way i can stick my dick in em .
# GENERATED:  women are like a dick , but i don ' t like my dick . i just stick it .
#
# KEYWORDS: ['world', 'see', 'need', 'guy', 'collided', 'anymore']
# TRUE: ever since i had that car accident i see the world with different eyes shoutout to the guy i collided with who doesn ' t need them anymore
# GENERATED:  what did the guy say to the other who collided with a guy ? i need to see his dick .
#
# KEYWORDS: ['play', 'get']
# TRUE: what do you get when you play a country music record backwards ? you get your wife back , your dog back , your truck back
# GENERATED:  what do you get when you play a play with a play with a play ? a rubik is .
#
# KEYWORDS: ['salad', 'man']
# TRUE: an italian man walks into a mental hospital with salad . man it is getting caprese in here
# GENERATED:  what did the man say to the man with a man with a man ? man , i have a salad dressing .
#
# KEYWORDS: ['night', 'dick', 'black', 'ass']
# TRUE: what is 8 inches long , and black as the night ? the dick up your ass
# GENERATED:  what is black and white and white and black people at night ? a dick
#
# KEYWORDS: ['shot', 'bird']
# TRUE: what did the awkward adolescent say when he shot a bird ? pew birdy puberty
# GENERATED:  what is the most unexpected thing about a race ? a bird .
#
# KEYWORDS: ['turned', 'around', 'addicted']
# TRUE: i was addicted to the hokey pokey but , i turned myself around .
# GENERATED:  i ' m addicted to hokey pokey but i turned it around .
#
# KEYWORDS: ['hell', 'feedback']
# TRUE: what brand microphone did kurt cobain use ? remingtoni head the feedback was hell .
# GENERATED:  feeds and feeds . feed the hell outback .
#
# KEYWORDS: ['see']
# TRUE: at your next helloween party expect to see the typical costumes . the sexy nurse , the sexy nun and the sexist judge .
# GENERATED:  what did the vampire say to the other lesbian vampire ? see you see you
#
# KEYWORDS: ['allowed']
# TRUE: i envy women they are allowed to have big titties and i ' m not
# GENERATED:  why did the bicycle fall into a bar ? because he is not allowed to be allowed to be a registered six offender .
#
# KEYWORDS: ['great', 'alright']
# TRUE: i think greta thunberg is alright but dyslexics think she is great
# GENERATED:  what is great about great doctors ? alright , alright , alright , alright , alright , alright , alright , alright .

# %%
# Test
start_prompt = "witch home children"
start_tokens = tokenizer.tokenize(start_prompt)
start_tokens = tf.squeeze(start_tokens,axis=0)
start_tokens = list(tf.squeeze(start_tokens, axis=1).numpy())
start_tokens = keras.preprocessing.sequence.pad_sequences([start_tokens],
                                            value=0,
                                            padding='post',
                                            maxlen=maxlen)[0] 

print("KEYWORDS:", start_prompt)
print("OUTPUT:", decoder_decode(start_tokens.reshape(1, maxlen)))
# Out:
# KEYWORDS: witch home children
# OUTPUT:  why did the witch get rid of his children ? because he was a witch .

# %%
g = 2 > 1 and 1 > 2

# %%
if g:
  print(g)

# %% [markdown]
# # Joke-VAE

# %%
# Hyper parameters
latent_dim = 100
embedding_dim = 200
maxlen = 30
vocab_size = 9832

# from tensorflow.python.framework.ops import disable_eager_execution
# disable_eager_execution()

#################################### ENCODER ##################################
# Encoder inputs
encoder_inputs = tf.keras.Input(shape=(maxlen, ))

# Embedding layer
enc_emb = tf.keras.layers.Embedding(vocab_size, latent_dim, input_length=maxlen)(encoder_inputs)

# Sentence Averaging Encoder
encoder_avg = tf.keras.layers.GlobalAveragePooling1D()(enc_emb)


################################### SAMPLING ####################################
mu = tf.keras.layers.Dense(latent_dim)(encoder_avg)
sigma = tf.keras.layers.Dense(latent_dim)(encoder_avg)
z = Sampling()([mu, sigma])

# Hidden Dense
hidden_dense = tf.keras.layers.Dense(latent_dim)
hidden = hidden_dense(encoder_avg)

# Encoder dense
enc_dense = tf.keras.layers.Dense(latent_dim)
encoder_outputs = enc_dense(enc_emb)


#################################### DECODER ####################################
# Decoder inputs
decoder_inputs = tf.keras.Input(shape=(None, ))

# Decoder embedding layer
dec_emb_layer = tf.keras.layers.Embedding(vocab_size, latent_dim, trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = tf.keras.layers.LSTM(latent_dim,
                    return_sequences=True,
                    return_state=True,
                    dropout=0.4,
                    recurrent_dropout=0.0)

(decoder_outputs, decoder_fwd_state, decoder_back_state) = decoder_lstm(dec_emb,
                                                           initial_state=[hidden, hidden])

# Add Luong attention
attention = LuongAttentionLayer()
decoder_outputs = attention([encoder_outputs, decoder_outputs])

# Dense layer
decoder_dense = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(vocab_size, activation='softmax'))
decoder_outputs = decoder_dense(decoder_outputs)


#################################### VAE LOSS ##############################
# Z loss
def loss_fn(y_true, y_pred):
    xent_loss = tf.keras.losses.sparse_categorical_crossentropy(y_true, y_pred)
    kl_loss =  -0.5 * (1 + sigma - tf.square(mu) - tf.exp(sigma))
    kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
    return xent_loss + kl_loss


#################################### VAE MODEL ##############################
model = tf.keras.Model([encoder_inputs, decoder_inputs], decoder_outputs, name="vae")
model.summary()
print('\n\n\n')
# Out:
# Model: "vae"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 30, 100)      983200      input_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 100)          0           embedding[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 100)    983200      input_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          10100       global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, None, 100),  80400       embedding_1[0][0]
#                                                                  dense_2[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 30, 100)      10100       embedding[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose (TFOpLam (None, 100, None)    0           lstm[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul (TFOpLambda)   (None, 30, None)     0           dense_3[0][0]
#                                                                  tf.compat.v1.transpose[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.softmax (TFOpLa (None, 30, None)     0           tf.linalg.matmul[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_1 (TFOpLambda)   (None, 30, 1, 100)   0           dense_3[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims (TFOpLambda)     (None, 30, None, 1)  0           tf.compat.v1.nn.softmax[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None, 30, None, 100 0           tf.expand_dims_1[0][0]
#                                                                  tf.expand_dims[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum (TFOpLambda) (None, None, 100)    0           tf.math.multiply_2[0][0]
# __________________________________________________________________________________________________
# tf.concat (TFOpLambda)          (None, None, 200)    0           lstm[0][0]
#                                                                  tf.math.reduce_sum[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 9832)   1976232     tf.concat[0][0]
# ==================================================================================================
# Total params: 4,043,232
# Trainable params: 4,043,232
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Hyperparameters
epochs = 10
lr = 0.01
validation_split = 0.1
optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=5)

# Train the best model
model.compile(optimizer=optimizer, loss=loss_fn)
history = model.fit([keywords, target],
       labels,
       batch_size=batch_size,
       epochs=epochs,
       validation_split=validation_split,
       callbacks=[es])
# Out:
# Train on 90655 samples, validate on 10073 samples
# Epoch 1/10
# 90624/90655 [============================>.] - ETA: 0s - loss: 3.3807
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 90655/90655 [==============================] - 54s 591us/sample - loss: 3.3805 - val_loss: 2.7690
# Epoch 2/10
# 90655/90655 [==============================] - 52s 569us/sample - loss: 2.6273 - val_loss: 2.5512
# Epoch 3/10
# 90655/90655 [==============================] - 51s 567us/sample - loss: 2.4236 - val_loss: 2.4808
# Epoch 4/10
# 90655/90655 [==============================] - 52s 572us/sample - loss: 2.3111 - val_loss: 2.4376
# Epoch 5/10
# 90655/90655 [==============================] - 51s 565us/sample - loss: 2.2369 - val_loss: 2.4253
# Epoch 6/10
# 90655/90655 [==============================] - 52s 577us/sample - loss: 2.1835 - val_loss: 2.4290
# Epoch 7/10
# 90655/90655 [==============================] - 53s 581us/sample - loss: 2.1442 - val_loss: 2.4154
# Epoch 8/10
# 90655/90655 [==============================] - 52s 575us/sample - loss: 2.1114 - val_loss: 2.4132
# Epoch 9/10
# 90655/90655 [==============================] - 52s 574us/sample - loss: 2.0845 - val_loss: 2.4099
# Epoch 10/10
# 90655/90655 [==============================] - 53s 579us/sample - loss: 2.0615 - val_loss: 2.4286

# %%
# Plot History
history_dict = history.history
plt.plot(range(1,epochs+1), history_dict['loss'], 'r', label='Training loss')
plt.plot(range(1,epochs+1), history_dict['val_loss'], 'g', label='Validation loss')
plt.title('Averaging Seq2Seq Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#################################### INFERENCE ENCODER ################################
# Encode the input sequence to get the feature vector
encoder_model = tf.keras.Model(inputs=encoder_inputs, outputs=[encoder_outputs,
                      hidden, hidden], name='encoder')
encoder_model.summary()
print('\n\n\n')


################################### INFERENCE DECODER ###############################
# Below tensors will hold the states of the previous time step
decoder_state_input_h = tf.keras.layers.Input(shape=(latent_dim, ))
decoder_state_input_c = tf.keras.layers.Input(shape=(latent_dim, ))
decoder_hidden_state_input = tf.keras.layers.Input(shape=(maxlen, latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2 = dec_emb_layer(decoder_inputs)

# To predict the next word in the sequence, set the initial states to the states from the previous time step
(decoder_outputs2, state_h2, state_c2) = decoder_lstm(dec_emb2,
        initial_state=[decoder_state_input_h, decoder_state_input_c])

# Attention
decoder_outputs2 = attention([decoder_hidden_state_input,decoder_outputs2])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_outputs2)

# Final decoder model
decoder_model = tf.keras.Model([decoder_inputs] + [decoder_hidden_state_input,
                      decoder_state_input_h, decoder_state_input_c],
                      [decoder_outputs2] + [state_h2, state_c2], name='decoder')

decoder_model.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 30, 100)      983200      input_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 100)          0           embedding[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 30, 100)      10100       embedding[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          10100       global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,003,400
# Trainable params: 1,003,400
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
#
#
#
# Model: "decoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 100)    983200      input_2[0][0]
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, None, 100),  80400       embedding_1[1][0]
#                                                                  input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 30, 100)]    0
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_1 (TFOpL (None, 100, None)    0           lstm[1][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_1 (TFOpLambda) (None, 30, None)     0           input_5[0][0]
#                                                                  tf.compat.v1.transpose_1[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.softmax_1 (TFOp (None, 30, None)     0           tf.linalg.matmul_1[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_3 (TFOpLambda)   (None, 30, 1, 100)   0           input_5[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_2 (TFOpLambda)   (None, 30, None, 1)  0           tf.compat.v1.nn.softmax_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_3 (TFOpLambda) (None, 30, None, 100 0           tf.expand_dims_3[0][0]
#                                                                  tf.expand_dims_2[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_1 (TFOpLambd (None, None, 100)    0           tf.math.multiply_3[0][0]
# __________________________________________________________________________________________________
# tf.concat_1 (TFOpLambda)        (None, None, 200)    0           lstm[1][0]
#                                                                  tf.math.reduce_sum_1[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 9832)   1976232     tf.concat_1[0][0]
# ==================================================================================================
# Total params: 3,039,832
# Trainable params: 3,039,832
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Load weights
encoder_model.load_weights('vae_enc_weights.h5')
decoder_model.load_weights('vae_dec_weights.h5')

# Test
real = np.load("encoded_jokes.npy", allow_pickle=True)
for i in range(100):
  keyword = keywords[i]
  kw = detokenize(test_kw[i])
  print("KEYWORDS:", [x for x in kw if x != '[PAD]' and x != '[START]'])
  true = detokenize(test_seq[i])
  print("TRUE:", ' '.join([x for x in true if x != '[PAD]' and x != '[START]']))
  generated = decoder_decode(keyword.reshape(1, 30))
  print("GENERATED:", generated)
  print("")
# Out:
# KEYWORDS: ['switch', 'light', 'arguing']
# TRUE: how do you end two deaf persons ' arguing ? switch off the light .
# GENERATED:  i was able to be able to build a legolas . i was able to build a legolas .
#
# KEYWORDS: ['suckin', 'lot', 'lose', 'hurricane', 'house', 'first', 'common', 'blowin', 'blonde']
# TRUE: what does a blonde have in common with a hurricane ? first there is a lot of suckin and blowin , then you lose your house .
# GENERATED:  what is the best part about being a blogen ? jokes .
#
# KEYWORDS: ['went', 'floats', 'day', 'circles']
# TRUE: i went to a white pride parade the other day . the floats just kept going around in circles about 200 miles per hour .
# GENERATED:  ran through a campground you ran through the campground they ran tents .
#
# KEYWORDS: ['would', 'neighbor', 'joke', 'home', 'close']
# TRUE: i would make a joke about my neighbor . but it would be too close to home
# GENERATED:  nice to a living in a living room for a living room .
#
# KEYWORDS: ['god', 'everything', 'difference']
# TRUE: what is the difference between god and you ex wife ? god only wants 10 things . your ex wife wants half of everything .
# GENERATED:  what do you get when you mix a reline ? pee .
#
# KEYWORDS: ['swear', 'castrate']
# TRUE: i swear , i will castrate you do it , you won t . no balls bro .
# GENERATED:  what is the best part about a gay man ? a little whine
#
# KEYWORDS: ['woman', 'way', 'tits', 'looking', 'eyes', 'checks']
# TRUE: the first thing a man notices about a woman is her eyes and when he made sure it is not looking his way , he checks out her
# GENERATED:  what did the fish say to give a handjob ? a clock .
#
# KEYWORDS: ['get', 'dead']
# TRUE: what is your favourite insult joke ? i will get it started 2090 called , you are dead and nobody misses you
# GENERATED:  what is a pocs is favorite drink ? pocscs
#
# KEYWORDS: ['way', 'thought', 'mall', 'harsh']
# TRUE: trump hows that mexican mall going ? mall ? we thought you said wall trump no way that is harsh , also hows that muslim band looking
# GENERATED:  why is the alphabet like the alphabet ? because they are c .
#
# KEYWORDS: ['anyone']
# TRUE: keanu reeves donates so much blood that anyone who has ever received donor blood is at least 6 keanu reeves .
# GENERATED:  what is the most dangerous part of the most dangerous ? a bad joke
#
# KEYWORDS: ['sneezes']
# TRUE: what does a nut say when he sneezes ? ca shew
# GENERATED:  i saw a new year old girl in the city . he was full of money .
#
# KEYWORDS: ['nose', 'man', 'ejaculating', 'arrested']
# TRUE: a man was arrested for ejaculating out his nose but he did nutting wrong
# GENERATED:  i cheating on my taxes and i ' m cheating on my taxes . i ' m fine .
#
# KEYWORDS: ['write', 'called']
# TRUE: my girlfriend asked me to write an inspirational poem about our love life . i called it , the load less swallowed
# GENERATED:  what do you call a black man who can ' t give a black man ? a bro
#
# KEYWORDS: ['understand', 'talk', 'heroin']
# TRUE: my local police chief does a talk on heroin so you can ' t understand any of it .
# GENERATED:  why are black people so full of themselves ? because they are full of themselves .
#
# KEYWORDS: ['used', 'thought', 'think', 'telling', 'look', 'brain']
# TRUE: i used to think the brain was the most important organ . then i thought , look what is telling me that .
# GENERATED:  i ' m not a judgement snowflakes . i don ' t trust the only time .
#
# KEYWORDS: ['tumblr', 'trending', 'saw', 'dashboard']
# TRUE: so i saw that princess diana is trending on tumblr . she is all over the dashboard
# GENERATED:  how does a gynaecologist say when she lost his job at a gynaecologist ? a guy is a gynecologist .
#
# KEYWORDS: ['unless', 'speed', 'multiply', 'light', 'energy']
# TRUE: unless you multiply yourself by the speed of light then you energy .
# GENERATED:  what did the pirate say to masturbate ? he is a slipnut .
#
# KEYWORDS: ['hollow', 'hillary', 'head']
# TRUE: what is more hollow than donald trump is head ? hillary is diazepam pen .
# GENERATED:  i grabbed my friend from my friend today . he grabbed me and destroyed the years .
#
# KEYWORDS: ['dog', 'boat']
# TRUE: why does a dog on a you boat have a deep bark ? because he is a sub woofer .
# GENERATED:  i just read an article about an article about the new years resolution i ' m not sure i ' m not sure .
#
# KEYWORDS: ['reaction']
# TRUE: why don ' t people tell chemistry jokes ? because they never get a reaction .
# GENERATED:  why do native americans hate the isis ? they invade land on land .
#
# KEYWORDS: ['yet', 'woman', 'w', 'q', 'infront', 'cow', 'back']
# TRUE: q what is infront of the woman , yet , at the back of the cow ? a w
# GENERATED:  what did the lushin say to the lnieur ? luctus
#
# KEYWORDS: ['nazi', 'followers', 'coming']
# TRUE: when hitler killed himself his followers did nazi that coming
# GENERATED:  what is a baby is favorite drink ? a baby .
#
# KEYWORDS: []
# TRUE:
# GENERATED:  what did the cannibal say to the other ? let him go to let the other .
#
# KEYWORDS: ['sperm', 'directions', 'ask']
# TRUE: why does it take millions of sperm to fertilize one egg ? because they won ' t ask for directions
# GENERATED:  what is the worst part about being a gay person ? a little boy .
#
# KEYWORDS: ['experience', 'belittling', 'attacked']
# TRUE: i was attacked by tiny bees . the experience was belittling .
# GENERATED:  nsfw i went to my girlfriend and i pretend to pretend to pretend she is having sex with me .
#
# KEYWORDS: ['spent', 'proud', 'pays', 'lot', 'life', 'brothels', 'bills']
# TRUE: i have spent a lot of my life in brothels . i am not proud of it , but it pays the bills .
# GENERATED:  i have been hooked up a duck . i have been hooked up .
#
# KEYWORDS: ['went', 'tiers', 'even', 'cake']
# TRUE: i went to a really depressing wedding recently . even the cake was in tiers .
# GENERATED:  what is a keeper is favorite number ? a keeper
#
# KEYWORDS: ['song', 'catchy']
# TRUE: a stormtrooper walks into a cantina stormtrooper damn this song is catchy
# GENERATED:  why did the blind man fall into a well ? because he told him well , he was a well .
#
# KEYWORDS: ['whens', 'door', 'ajar']
# TRUE: whens a door not a door ? when its ajar .
# GENERATED:  how do you sink a blonde ? knock knock who is there ?
#
# KEYWORDS: ['little', 'difference']
# TRUE: what is the difference between ancient religious texts and fake news ? a little over 2000 years
# GENERATED:  i have gains to berown . but i ' m not a frown .
#
# KEYWORDS: ['call']
# TRUE: what do you call a graduated spider ? a web designer
# GENERATED:  what is a stick of a gay bar ? a stick .
#
# KEYWORDS: ['see', 'mother', 'father', 'beauty']
# TRUE: a son asks his father . a son asks his father dad , what is beauty ? do you see your mother ? yes well that is not it
# GENERATED:  why did the hedgehog go to the middle east ? because he wanted to deal with a deck of cards .
#
# KEYWORDS: ['rapist', 'predator', 'call']
# TRUE: what do you call an immigrant fighting a rapist ? alien vs . predator
# GENERATED:  what is the best part about a gay man ? a little whine
#
# KEYWORDS: ['groups', 'even']
# TRUE: why do white girls always walk in groups with odd numbers ? they can ' t even
# GENERATED:  someone asked me if someone is name is a new york . i asked him if someone is name .
#
# KEYWORDS: ['rest', 'made', 'funeral', 'awkward']
# TRUE: got caught sniffing my sisters panties yesterday it made the rest of her funeral very awkward .
# GENERATED:  why did the blonde get pregnant ? because he was moodi
#
# KEYWORDS: ['want', 'making', 'joke', 'hear']
# TRUE: you want to hear a joke ? me making it on the front page .
# GENERATED:  what was mixing and magnesium and magnesium ? mglasses
#
# KEYWORDS: ['week', 'set', '100']
# TRUE: set your wifi password to 100 so when someone ask tell them it is how many times a week this gets reposted .
# GENERATED:  what do you call a cult that is not a cult ? a cult
#
# KEYWORDS: ['fascist', 'faggot', 'call', 'axe']
# TRUE: what do you call a faggot with an axe ? a fascist
# GENERATED:  what elements the letter is favorite letter ? a letter .
#
# KEYWORDS: ['vegetables', 'thumbs', 'people', 'know', 'fingers']
# TRUE: you know how all thumbs are fingers , but not all fingers are thumbs ? some people can be vegetables , but vegetables can ' t be people .
# GENERATED:  what do you say when you offended an apology ? african african african african african african african african african african african african african african african african african african african
#
# KEYWORDS: ['marc', 'homosexual', 'group', 'friends']
# TRUE: they say one in ten men are homosexual in my group of friends i ' m pretty sure it is marc . he is really cute
# GENERATED:  what do you say when you love a competition ? a competition .
#
# KEYWORDS: ['engineers']
# TRUE: a good joke for the engineers out there free time
# GENERATED:  what is the best part about a gay man ? a little whine
#
# KEYWORDS: ['writing', 'song', 'getting', 'end']
# TRUE: i ' m writing a song about getting my front door lock replaced . there is a lovely key change at the end .
# GENERATED:  what is a minor is favorite song ? a minor
#
# KEYWORDS: ['charge']
# TRUE: i gave away all of my dead batteries free of charge .
# GENERATED:  why are there no tissues ? because they both have a hot dog .
#
# KEYWORDS: ['point', 'life', 'diarrhea', '80']
# TRUE: studies show that 80 of redditors suffer from diarrhea at some point in life then why are the rest enjoying it ?
# GENERATED:  what did the left say to the bathroom ? where is left ?
#
# KEYWORDS: ['someone', 'makes', 'cents', 'call']
# TRUE: what do you call a bad european banker that talks gibberish ? someone that makes no cents .
# GENERATED:  what is the best part about a gay man ? a little whine
#
# KEYWORDS: ['win', 'olympics', 'logic', 'chance']
# TRUE: to win the olympics , you must go big or go home . by that logic , the refugee team never had a chance .
# GENERATED:  thieves stole everything and stole my house in the house . they can pick up rooms .
#
# KEYWORDS: ['frank', 'burn']
# TRUE: why won ' t people let hitler go to the bar bq ? he ' ll just burn the frank ' s
# GENERATED:  why do you vaccinate your kids ? because they don ' t last .
#
# KEYWORDS: ['porn', 'disabled']
# TRUE: is all your porn here disabled ? no it is regular porn you sick fuck .
# GENERATED:  what does a pervert say when he is a pervert ? a pervert
#
# KEYWORDS: ['lazy', 'descirbe']
# TRUE: i can descirbe myself in just two words . lazy .
# GENERATED:  what is the best part about being a hard time ? an assassin .
#
# KEYWORDS: ['wife', 'tequila', 'cliff']
# TRUE: why did the mexican man throw his wife off of a cliff ? tequila
# GENERATED:  what does a dog and a dog have in common ? they both have collar id
#
# KEYWORDS: ['nuts', 'heard', 'guy', 'glitter', 'dipped']
# TRUE: have you heard about the guy who dipped his nuts in glitter ? pretty ballsy
# GENERATED:  i said i ' m not a good joke about the correct answer .
#
# KEYWORDS: ['reason', 'politicians', 'diapers', 'common']
# TRUE: politicians and diapers have one thing in common . they should both be changed regularly , and for the same reason .
# GENERATED:  what is the alpha is releasing a new cent ? a new york jets .
#
# KEYWORDS: ['married', 'friends']
# TRUE: why couldn ' t stevie wonder see his friends ? because he was married
# GENERATED:  i like my wife i like my wife i like my doctor . i like my doctor .
#
# KEYWORDS: ['sex', 'problem', 'given', 'example']
# TRUE: nsfw houston , we have a problem i feel like porn has me given such unrealistic expectations about sex for example , having it with another person .
# GENERATED:  why do you know why the blind man is early ? he is too early .
#
# KEYWORDS: ['required', 'president', 'know', 'duck']
# TRUE: did you know the secret service is no longer allowed to say get down when the president is getting attacked ? now they are required to say donald ,
# GENERATED:  did you know that the boy asked me to get for christmas ? he hasn ' t opened it yet .
#
# KEYWORDS: []
# TRUE: whom did the boston strangler choke last ? the atlanta falcons .
# GENERATED:  i was going to buy a new year old son . i ' m going to buy it .
#
# KEYWORDS: ['got', 'friend', 'farm', 'cieio']
# TRUE: my friend just got a new job heading up old macdonald is farm . he is the cieio
# GENERATED:  how do mechanic make a mechanic ? a mechanic
#
# KEYWORDS: ['want', 'library', 'hang']
# TRUE: what is the best part of the library to hang out if you want to get laid ? adult friction .
# GENERATED:  i wanted to leave a whole year old son i said i wanted to leave the whole world .
#
# KEYWORDS: ['wife', 'pants', 'morning', 'happy', 'got', 'found']
# TRUE: i got in my wife is pants this morning . she wasn ' t too happy once she found out .
# GENERATED:  i was rushed to my doctor and i was rushed to build a giant crab .
#
# KEYWORDS: ['ex', 'eat', 'asshole']
# TRUE: if you are what you eat then that would explain why my ex is such an asshole .
# GENERATED:  what do you call a women in annetters ? annette
#
# KEYWORDS: ['call']
# TRUE: what do you call a testicle outside earth ? a space nut
# GENERATED:  what is the best part about a gay man ? a little whine
#
# KEYWORDS: ['work', 'used', 'taking', 'fired', 'days', 'couple']
# TRUE: i used to work in a calender factory but i was fired for taking a couple of days off .
# GENERATED:  what do you get when you mix an elephant ? an elephant
#
# KEYWORDS: ['plenty', 'percs', 'make']
# TRUE: being a drug dealer is a tough job . but it has plenty of percs to make up for it .
# GENERATED:  what is the best part about being cremated ? a healthy body .
#
# KEYWORDS: ['really', 'insomniac', 'hear', 'dyslexic', 'dog', 'agnostic']
# TRUE: did you hear about the dyslexic , agnostic , insomniac ? he was up all night wondering if there really was a dog .
# GENERATED:  what does a cattle say when he is a cattle ? a cattle field .
#
# KEYWORDS: ['mum', 'found', 'concieved']
# TRUE: i found i out i was concieved at my grandmothers funeral appearently , my mum was trying comfort him . stupid mourning wood .
# GENERATED:  why do you never see an 8 year old ? because they are nice .
#
# KEYWORDS: ['ransomware', 'know']
# TRUE: hey officer , how did the hackers escape ? i don ' t know , they just ransomware .
# GENERATED:  raising a jewish girl is a hand . his hand is raising raising raising raising raising raising raising raising raising raising raising raising raising raising raising raising raising raising
#
# KEYWORDS: ['ridiculous', 'health', 'even', 'bad']
# TRUE: it is ridiculous that there was such a long debate whether smoking would be bad for the health . even the nazis knew it is .
# GENERATED:  what is the best part about a gay man ? a little whine
#
# KEYWORDS: ['works', 'fertilizer', 'entremanure', 'call']
# TRUE: what do you call a self employed individual who works with fertilizer ? an entremanure .
# GENERATED:  what do you call a fat psychic ? a little whine
#
# KEYWORDS: ['tomorrow', 'tell', 'take', 'ehh', 'change']
# TRUE: how many procrastinators does it take to change a light bulb ? ehh , i ' ll tell you tomorrow .
# GENERATED:  guys , i ' m going to eat a problem with a problem with a pretty good joke .
#
# KEYWORDS: ['time']
# TRUE: child psychologists hear touching stories from time to time .
# GENERATED:  what is dark spelled in the dark ? k . k . k . k . k . k . k . k . k . k . k
#
# KEYWORDS: ['laptop', 'difference', 'consultant', 'butt']
# TRUE: what is the difference between an it consultant and a catholic priest ? the it consultant is laptop has no butt .
# GENERATED:  i threw a phone in my phone today i just threw a phone . i said maybe i threw a phone .
#
# KEYWORDS: ['want', 'sticking', 'means', 'meaning', 'many', 'lot', 'figured']
# TRUE: thanks everyone i want to thank everyone for sticking with me while i figured out the meaning of many . it means a lot .
# GENERATED:  how is the window ? peeking a window .
#
# KEYWORDS: ['exactly']
# TRUE: me hey bro someone said you sound like an owl bro who ? me exactly
# GENERATED:  what keeps the best thing about your toes ? keeps the toes .
#
# KEYWORDS: ['whey', 'claims', 'bodybuilder']
# TRUE: does anyone believe the bodybuilder who claims he never used protein suppliments ? no whey .
# GENERATED:  be careful that is careful of careful of the worlds careful .
#
# KEYWORDS: []
# TRUE: what do you call 2000 mockingbirds ? 2kilo mocking birds .
# GENERATED:  39 , i have been a fight with 4 .
#
# KEYWORDS: ['masturbate', 'hard', 'easy', 'choose']
# TRUE: we choose to masturbate , not because it is easy , but because it is hard .
# GENERATED:  did you hear about the new zealanders ? it was giving me a little stiff .
#
# KEYWORDS: ['aula']
# TRUE: knock knock who is there ? aula . aula who ? allah huakbar
# GENERATED:  have you heard about the new movie about the new york ? it is called it is called it .
#
# KEYWORDS: ['suicide', 'nevermind', 'leave', 'joke', 'hanging', 'ah']
# TRUE: wanna hear a joke about suicide ? ah , nevermind , i ' ll leave you hanging
# GENERATED:  what do you do if you cant stop masturbating ? apologise
#
# KEYWORDS: ['pirate', 'charge', 'arr']
# TRUE: i ' m not often hired to be a pirate but when i am , i charge by the ' arr '
# GENERATED:  what do you say when you are a wife ? i told her to say .
#
# KEYWORDS: ['sleep', 'saw', 'money']
# TRUE: was about to sleep when i saw the robber last night in my house searching for money . i immediately got up . and searched alongside with him
# GENERATED:  i don ' t know why people are wrong . they don ' t know what they are wrong .
#
# KEYWORDS: ['road']
# TRUE: why did the dinosaur cross the road ? what road ?
# GENERATED:  why did the blonde go to the blonde ? because he was trying to make a ipad .
#
# KEYWORDS: ['vegan', 'proud', 'meals', 'call']
# TRUE: i am proud to call myself a vegan but only in between meals .
# GENERATED:  people are like a new york jets .
#
# KEYWORDS: ['trying', 'transporting', 'tell', 'package', 'messed', 'mailman', 'joke', 'delivery']
# TRUE: a mailman was trying to tell a joke while transporting a package but he messed up the delivery
# GENERATED:  what do you call it when a model has a model on instagram ? a squist
#
# KEYWORDS: ['paint']
# TRUE: who is this rorschach guy and why does he paint so many penises ?
# GENERATED:  i gave a glass of water . it gave me a glass of water .
#
# KEYWORDS: []
# TRUE: how does harry potter order tequila shots ? patron us
# GENERATED:  what is the best part about a gay man ? a little whine
#
# KEYWORDS: ['wet', 'soft', 'pink', 'hard', 'goes', 'dry', 'comes']
# TRUE: what is pink ? ? ? goes in hard and dry and comes out soft and wet a bubble gum
# GENERATED:  i entered ten puns in ten . but i entered ten bucks in ten .
#
# KEYWORDS: ['urination', 'pee', 'land', 'country']
# TRUE: what did the un say to the land of pee when it officially became a country ? urination .
# GENERATED:  did you hear about the new zealand that went to prison ? he left the prison guard in prison .
#
# KEYWORDS: ['understand', 'told', 'ex']
# TRUE: i told the ambulance guys the wrong blood type for my ex now she should understand what rejection feels like .
# GENERATED:  what is the difference between an ash and a jewish person ? none , they end up in the end .
#
# KEYWORDS: ['thanks', 'see', 'guess', 'booming']
# TRUE: thanks to recent events i guess you could say the pressure cooker business is booming i ' ll see myself out now .
# GENERATED:  i think i have to break up with people who don ' t see that people are a little break .
#
# KEYWORDS: ['women', 'way', 'stick', 'like', 'hot', 'em', 'dick']
# TRUE: i like my coffee like i like my women not too hot . that way i can stick my dick in em .
# GENERATED:  what is a man is favorite type of coordination ? man
#
# KEYWORDS: ['world', 'see', 'need', 'guy', 'collided', 'anymore']
# TRUE: ever since i had that car accident i see the world with different eyes shoutout to the guy i collided with who doesn ' t need them anymore
# GENERATED:  my girlfriend told me to go to my basement . i asked her to go to my basement . i said i ' m not a compulsive liar .
#
# KEYWORDS: ['play', 'get']
# TRUE: what do you get when you play a country music record backwards ? you get your wife back , your dog back , your truck back
# GENERATED:  i borrowed my book on the librarian but i kept the librarian but i kept the librarian . i kept the librarian .
#
# KEYWORDS: ['salad', 'man']
# TRUE: an italian man walks into a mental hospital with salad . man it is getting caprese in here
# GENERATED:  why did the programmer quit his job ? because he was soda pressing .
#
# KEYWORDS: ['night', 'dick', 'black', 'ass']
# TRUE: what is 8 inches long , and black as the night ? the dick up your ass
# GENERATED:  why is black people so tall ? because they are too short .
#
# KEYWORDS: ['shot', 'bird']
# TRUE: what did the awkward adolescent say when he shot a bird ? pew birdy puberty
# GENERATED:  what did the chef say to die ? he die .
#
# KEYWORDS: ['turned', 'around', 'addicted']
# TRUE: i was addicted to the hokey pokey but , i turned myself around .
# GENERATED:  what did the doctor say to the doctor ? it hertz .
#
# KEYWORDS: ['hell', 'feedback']
# TRUE: what brand microphone did kurt cobain use ? remingtoni head the feedback was hell .
# GENERATED:  what do you call professionals without a black whale ? sircum aid
#
# KEYWORDS: ['see']
# TRUE: at your next helloween party expect to see the typical costumes . the sexy nurse , the sexy nun and the sexist judge .
# GENERATED:  what is the best part about dating a homeless dates ? you can drop her off anywhere .
#
# KEYWORDS: ['allowed']
# TRUE: i envy women they are allowed to have big titties and i ' m not
# GENERATED:  a man walks into piss . sadly , i can ' t piss off .
#
# KEYWORDS: ['great', 'alright']
# TRUE: i think greta thunberg is alright but dyslexics think she is great
# GENERATED:  a narcissist , a narcissist walk into a bar the other is a narcissist .

# %%
# Test
start_prompt = "dream"
start_tokens = tokenizer.tokenize(start_prompt)
start_tokens = tf.squeeze(start_tokens,axis=0)
start_tokens = list(tf.squeeze(start_tokens, axis=1).numpy())
start_tokens = keras.preprocessing.sequence.pad_sequences([start_tokens],
                                            value=0,
                                            padding='post',
                                            maxlen=maxlen)[0] 

print("KEYWORDS:", start_prompt)
print("OUTPUT:", decoder_decode(start_tokens.reshape(1, maxlen)))
# Out:
# KEYWORDS: dream
# OUTPUT:  what is the best thing about being a good boxer ? you are not a good time travel .

# %% [markdown]
# # Joke-Transformer

# %%
########################################## TRANSFORMER ############################################

def causal_attention_mask(batch_size, n_dest, n_src, dtype):
    """
    Mask the upper half of the dot product matrix in self attention.
    This prevents flow of information from future tokens to current token.
    1's in the lower triangle, counting from the lower right corner.
    """
    i = tf.range(n_dest)[:, None]
    j = tf.range(n_src)
    m = i >= j - n_src + n_dest
    mask = tf.cast(m, dtype)
    mask = tf.reshape(mask, [1, n_dest, n_src])
    mult = tf.concat(
        [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)], 0
    )
    return tf.tile(mask, mult)

class TokenAndPositionEmbedding(layers.Layer):
    def __init__(self, maxlen, vocab_size, embed_dim):
        super(TokenAndPositionEmbedding, self).__init__()
        self.token_emb = layers.Embedding(input_dim=vocab_size, output_dim=embed_dim)
        self.pos_emb = layers.Embedding(input_dim=maxlen, output_dim=embed_dim)

    def call(self, x):
        maxlen = tf.shape(x)[-1]
        positions = tf.range(start=0, limit=maxlen, delta=1)
        positions = self.pos_emb(positions)
        x = self.token_emb(x)
        return x + positions

class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = layers.MultiHeadAttention(num_heads, embed_dim)
        self.ffn = keras.Sequential(
            [layers.Dense(ff_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size = input_shape[0]
        seq_len = input_shape[1]
        causal_mask = causal_attention_mask(batch_size, seq_len, seq_len, tf.bool)
        attention_output = self.att(inputs, inputs, attention_mask=causal_mask)
        attention_output = self.dropout1(attention_output)
        out1 = self.layernorm1(inputs + attention_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output)
        return self.layernorm2(out1 + ffn_output)

# %%
################ Transformer Params ###########
embed_dim = 256  # Embedding size for each token
num_heads = 3  # Number of attention heads
feed_forward_dim = 256  # Hidden layer size in feed forward network inside transformer

# %%
# GPT2 Style Transformer
inputs = layers.Input(shape=(maxlen,), dtype=tf.int32)
embedding_layer = TokenAndPositionEmbedding(maxlen, vocab_size, embed_dim)
x = embedding_layer(inputs)
transformer_block1 = TransformerBlock(embed_dim, num_heads, feed_forward_dim)
x = transformer_block1(x)
transformer_block2 = TransformerBlock(embed_dim, num_heads, feed_forward_dim)
x = transformer_block2(x)
transformer_block3 = TransformerBlock(embed_dim, num_heads, feed_forward_dim)
x = transformer_block3(x)
transformer_block4 = TransformerBlock(embed_dim, num_heads, feed_forward_dim)
x = transformer_block4(x)
outputs = layers.Dense(vocab_size)(x)
model = keras.Model(inputs=inputs, outputs=[outputs, x])
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
model.compile("adam", loss=[loss_fn, None],)  # No loss and optimization based on word embeddings from transformer block
model.summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_27 (InputLayer)        [(None, 30)]              0
# _________________________________________________________________
# token_and_position_embedding (None, 30, 256)           2524672
# _________________________________________________________________
# transformer_block_44 (Transf (None, 30, 256)           921600
# _________________________________________________________________
# transformer_block_45 (Transf (None, 30, 256)           921600
# _________________________________________________________________
# transformer_block_46 (Transf (None, 30, 256)           921600
# _________________________________________________________________
# transformer_block_47 (Transf (None, 30, 256)           921600
# _________________________________________________________________
# dense_116 (Dense)            (None, 30, 9832)          2526824
# =================================================================
# Total params: 8,737,896
# Trainable params: 8,737,896
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit model
start_prompt = "what do you"
text_gen_callback = TextGenerator(maxlen, start_prompt, tokenizer, top_k=2)
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10)
model.fit(target, 
          np.squeeze(labels), 
          validation_split=0.1, 
          batch_size=batch_size, 
          epochs=epochs, 
          callbacks=[text_gen_callback, es])

# %%
# Save model
model.save_weights('transformer_sub.h5')

# %%
# Testing for overfitting
model.load_weights('transformer_sub.h5')
test_model(model)

# %%
#model.load_weights('transformer_sub.h5')
start_prompt = "what do you"
generate(model, maxlen, start_prompt, top_k=2, tokenizer=tokenizer)

# %% [markdown]
# # Joke-GAN (Reconstruction Seq2Seq)

# %%
latent_dim = 100
embedding_dim = 200
latent_dim_0 = int(latent_dim / 2)
r_drop = 0.0
d_drop = 0.4

################################# ENCODER #######################################
# Source input
encoder_inputs = Input(shape=(maxlen, ))

# Embedding layer
enc_emb = Embedding(vocab_size, embedding_dim,
                    trainable=True)(encoder_inputs)

# Encoder LSTM
encoder_bilstm = Bidirectional(LSTM(latent_dim_0, return_state=True,
                     return_sequences=True,
                     dropout=d_drop,
                     recurrent_dropout=r_drop))

_, forward_h, _, backward_h, _ = encoder_bilstm(enc_emb)
hidden = Concatenate()([forward_h, backward_h])

################################# DECODER #######################################
# Produce cell state from hidden variable
reweight_cell = Dense(latent_dim, activation='relu')
cell = reweight_cell(hidden)

# Produce encoder output from hidden variable by repeating and reparameterizing
expand_output = RepeatVector(maxlen)
expanded_outputs = expand_output(hidden)
reweight_output = Dense(latent_dim, activation='relu')
encoder_outputs = reweight_output(expanded_outputs)

# Target inputs
decoder_inputs = Input(shape=(None, ))

# Embedding layer
dec_emb_layer = Embedding(vocab_size, latent_dim, trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

# Decoder LSTM
decoder_lstm = LSTM(latent_dim, return_sequences=True,
                    return_state=True, 
                    dropout=d_drop,
                  recurrent_dropout=r_drop)

(decoder_outputs, h, c) = decoder_lstm(dec_emb, initial_state=[hidden, cell])
layer_norm_1 = LayerNormalization()
decoder_outputs = layer_norm_1(decoder_outputs)

# Attention
decoder_attention = LuongAttentionLayer()
decoder_outputs = decoder_attention([encoder_outputs,decoder_outputs])

# Dense layer
decoder_dense = TimeDistributed(Dense(vocab_size, activation='softmax'))
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')
model.load_weights('/content/reconstructor_weights.h5')

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 30, 200)      1966400     input_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) [(None, 30, 100), (N 100400      embedding_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 100)          0           bidirectional_1[0][1]
#                                                                  bidirectional_1[0][3]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, None, 100)    983200      input_4[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 100)          10100       concatenate_1[0][0]
# __________________________________________________________________________________________________
# repeat_vector_1 (RepeatVector)  (None, 30, 100)      0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 100),  80400       embedding_3[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 30, 100)      10100       repeat_vector_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, None, 100)    200         lstm_3[0][0]
# __________________________________________________________________________________________________
# luong_attention_layer_1 (LuongA (None, None, 200)    0           dense_4[0][0]
#                                                                  layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, None, 9832)   1976232     luong_attention_layer_1[0][0]
# ==================================================================================================
# Total params: 5,127,032
# Trainable params: 5,127,032
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Compile and Fit model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')
es = EarlyStopping(monitor='val_loss', mode='min', patience=5)
#text_gen_callback = TextGenerator(encoder_model, stepper_model, decoder_model, test[:5], tokenizer)

epochs = 10
history = model.fit([source,target],
                   labels,
                   batch_size=batch_size,
                   validation_split=0.1,
                   epochs=epochs,
                   callbacks=[es])#, text_gen_callback])
# Out:
# Epoch 1/10
# 645/645 [==============================] - 48s 66ms/step - loss: 4.5263 - val_loss: 3.0264
# Epoch 2/10
# 645/645 [==============================] - 42s 65ms/step - loss: 2.9377 - val_loss: 2.6394
# Epoch 3/10
# 645/645 [==============================] - 41s 64ms/step - loss: 2.5785 - val_loss: 2.3969
# Epoch 4/10
# 645/645 [==============================] - 42s 64ms/step - loss: 2.3358 - val_loss: 2.2101
# Epoch 5/10
# 645/645 [==============================] - 42s 65ms/step - loss: 2.1583 - val_loss: 2.0694
# Epoch 6/10
# 645/645 [==============================] - 41s 64ms/step - loss: 1.9951 - val_loss: 1.9528
# Epoch 7/10
# 645/645 [==============================] - 42s 65ms/step - loss: 1.8564 - val_loss: 1.8563
# Epoch 8/10
# 645/645 [==============================] - 42s 65ms/step - loss: 1.7532 - val_loss: 1.7677
# Epoch 9/10
# 645/645 [==============================] - 41s 64ms/step - loss: 1.6602 - val_loss: 1.6927
# Epoch 10/10
# 645/645 [==============================] - 41s 64ms/step - loss: 1.5738 - val_loss: 1.6330

# %%
# Plot History
history_dict = history.history
plt.plot(range(1,epochs+1), history_dict['loss'], 'r', label='Training loss')
plt.plot(range(1,epochs+1), history_dict['val_loss'], 'g', label='Validation loss')
plt.title('Seq2Seq Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# INFERENCE ENCODER
encoder_model = Model(inputs=encoder_inputs, outputs=hidden)


# INFERENCE STEPPER
input_z = Input(shape=(latent_dim, ))

# Obtain the outputs and cell state
cell_s = reweight_cell(input_z)
expanded_z = expand_output(input_z)
outputs_s = reweight_output(expanded_z)
stepper_model = Model(inputs=input_z, outputs=[outputs_s, cell_s])
    


# INFERENCE DECODER
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim, ))
decoder_state_input_c = Input(shape=(latent_dim, ))
decoder_hidden_state_input = Input(shape=(maxlen, latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2 = dec_emb_layer(decoder_inputs)

# To predict the next word in the sequence, set the initial states to the states from the previous time step
(decoder_outputs2, state_h2, state_c2) = decoder_lstm(dec_emb2,
        initial_state=[decoder_state_input_h, decoder_state_input_c])
decoder_outputs2 = layer_norm_1(decoder_outputs2)

# Attention
decoder_outputs2 = decoder_attention([decoder_hidden_state_input,decoder_outputs2])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_outputs2)

# Final decoder model
decoder_model = Model([decoder_inputs] + [decoder_hidden_state_input,
                      decoder_state_input_h, decoder_state_input_c],
                      [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(topic, start=[2]):
    # Obtain the latent variable
    e_h = encoder_model.predict(topic)
    
    # Use stepper to obtain the encoder outputs and cell state
    (e_out, e_c) = stepper_model.predict(e_h)

    # Generate empty target sequence of length 1
    target_seq = np.zeros((1, 1))

    # Populate the first word of target sequence with the index of start token.
    for i in range(len(start)):
      target_seq[i, i] = start[i]

    stop_condition = False
    decoded_sentence = ''

    while not stop_condition:
        (output_tokens, h, c) = decoder_model.predict([target_seq]
                + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        #sampled_token = reverse_target_word_index[sampled_token_index]
        sampled_token = tokenizer.detokenize([[sampled_token_index]]).to_list()
        sampled_token = sampled_token[0][0].decode("utf-8")

        if sampled_token != '[PAD]':
            decoded_sentence += ' ' + sampled_token

        # Exit condition: either hit max length or find the stop word.
        if sampled_token == '[PAD]' or len(decoded_sentence.split()) \
            >= maxlen - 1:
            stop_condition = True

        # Update the target sequence (of length 1)
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        (e_h, e_c) = (h, c)

    return decoded_sentence.replace(" ##",'')

# %%
# Test
for i in range(10):
  input = test[i]
  true = detokenize(test[i])
  print("TRUE:", ' '.join([x for x in true if x != '[PAD]' and x != '[START]']))
  generated = decode_sequence(input.reshape(1, maxlen))
  print("GENERATED:", generated)
  print("")
# Out:
# TRUE: why was orlando bloom sad when he realised he wasn ' t able to build small toy houses ? because he was legolas .
# GENERATED:  why was orlando bloomour sad when he realised he wasn ' t had 5 for lego . because he was toy t spotted
#
# TRUE: why aren ' t there any white jokes on r jokes ? because jokes are the white man is burden .
# GENERATED:  why aren ' t there any white jokes on r jokes ? because all jokes survive a real pan ziet .
#
# TRUE: you can ' t run through a campground , you can only ran because its past tents
# GENERATED:  you can ' t run through a campground , you can only ran because its past tents
#
# TRUE: the secret of living to 100 years old is patience
# GENERATED:  the secret of living to 100 years old is patience
#
# TRUE: why can ' t you get out of a sex cult with r . kelly ? once you are inurine
# GENERATED:  why can ' t you get out of a bad man rel ? relax , it should be in maur .
#
# TRUE: what is samsung ceo is favorite movie total recall
# GENERATED:  what is samsung producer is favorite movie total recall
#
# TRUE: what did the clock say to the other clock after she gave him a handjob ? now give me a second hand job
# GENERATED:  what did the clock say to the clock and she left after the phone gave ? give me for a hand phone ?
#
# TRUE: why is the dyslexic black guy labeled an uncle tom ? he keeps writing fuck the pocs .
# GENERATED:  why is the boy who smokes labelonie an uncle ? he was off to ramu akbar .
#
# TRUE: why can ' t pirates finish the alphabet ? because they get lost at c
# GENERATED:  why can ' t pirates finish the alphabet ? because they got at 6 c
#
# TRUE: why can ' t virgins play baseball ? they can ' t score
# GENERATED:  why can ' t virgins play baseball ? they can ' t score

# %%
encoder_model.save_weights('encoder_model_weights.h5')
stepper_model.save_weights('stepper_model_weights.h5')
decoder_model.save_weights('decoder_model_weights.h5')

# %% [markdown]
# # Joke-GAN (PyTorch)

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd
from torch.autograd import Variable
from torch.distributions.normal import Normal
from torch.utils.data import DataLoader

class Block(nn.Module):
    
    def __init__(self, block_dim):
        super().__init__()

        self.net = nn.Sequential(
            nn.Linear(block_dim, block_dim),
            nn.ReLU(True),
            nn.Linear(block_dim, block_dim),
        )
    
    def forward(self, x):
        return self.net(x) + x

class Generator(nn.Module):
    
    def __init__(self, n_layers, block_dim):
        super().__init__()

        self.net = nn.Sequential(
            *[Block(block_dim) for _ in range(n_layers)]
        )

    def forward(self, x):
        return self.net(x)

class Critic(nn.Module):
    
    def __init__(self, n_layers, block_dim):
        super().__init__()

        self.net = nn.Sequential(
            *[Block(block_dim) for _ in range(n_layers)]
        )

    def forward(self, x):
        return self.net(x)

# %%
def compute_grad_penalty(critic, real_data, fake_data):
    B = real_data.size(0)
    alpha = torch.FloatTensor(np.random.random((B, 1)))
    if cuda:
        alpha = alpha.cuda()
    sample = alpha*real_data + (1-alpha)*fake_data
    sample.requires_grad_(True)
    score = critic(sample)

    outputs = torch.FloatTensor(B, latent_dim).fill_(1.0)
    outputs.requires_grad_(False)
    if cuda:
        outputs = outputs.cuda()
    grads = autograd.grad(
        outputs=score,
        inputs=sample,
        grad_outputs=outputs,
        create_graph=True,
        retain_graph=True,
        only_inputs=True
    )[0]
    #grads = grads.view(B, -1)
    grad_penalty = ((grads.norm(2, dim=1) - 1.) ** 2).mean()
    return grad_penalty


def train_gan(epoch):
    #autoencoder.eval()
    generator.train()
    critic.train()
    c_train_loss = 0.
    g_train_loss = 0.
    g_batches = 0
    for i, x in enumerate(train_loader):
        if cuda:
            x = x.cuda()
        
        # train critic
        B = x.size(0)
        c_optimizer.zero_grad()
        noise = torch.from_numpy(np.random.normal(0, 1, (B,
                                 latent_dim))).float()
        if cuda:
            noise = noise.cuda()
        with torch.no_grad():
            x = x.cpu()
            x = x.numpy()
            z_real = encoder_model(x)
            z_real = z_real.numpy()
            z_real = torch.FloatTensor(z_real).cuda()

        z_fake = generator(noise)
        real_score = critic(z_real)
        fake_score = critic(z_fake)
        grad_penalty = compute_grad_penalty(critic, z_real.data, z_fake.data)
        c_loss = -torch.mean(real_score) + torch.mean(fake_score) + \
                 gp_lambda*grad_penalty
        c_train_loss += c_loss.item()
        c_loss.backward()
        c_optimizer.step()

        # train generator
        if i % n_critic == 0:
            g_batches += 1
            g_optimizer.zero_grad()
            fake_score = critic(generator(noise))
            g_loss = -torch.mean(fake_score)
            g_train_loss += g_loss.item()
            g_loss.backward()
            g_optimizer.step()
        
        if interval > 0 and i % interval == 0:
            print('Epoch: {} | Batch: {}/{} ({:.0f}%) | G Loss: {:.6f} | C Loss: {:.6f}'.format(
                epoch, batch_size*i, len(train_loader.dataset),
                100.*(batch_size*i)/len(train_loader.dataset),
                g_loss.item(), c_loss.item()
            ))
    g_train_loss /= g_batches
    c_train_loss /= len(train_loader)
    print('* (Train) Epoch: {} | G Loss: {:.4f} | C Loss: {:.4f}'.format(
        epoch, g_train_loss, c_train_loss
    ))
    return (g_train_loss, c_train_loss)


def decode(seq):
  sampled_token = tokenizer.detokenize(seq[None,:,:]).to_list()
  sampled_token = sampled_token[0][0]
  sampled_token = [x.decode("utf-8") for x in sampled_token]
  result = " ".join([x for x in sampled_token if x != '[START]'])
  return result

# %%
batch_size = 32
embedding_dim = 200 
latent_dim = 100
vocab_size = 9832
maxlen = 30
seed=0
epochs=1
lr=5e-4
interval=10
cuda=torch.cuda.is_available()
n_layers = 5
block_dim = 100
n_critic = 5
gp_lambda = 10

# Load Data
data = torch.tensor(seq_out,dtype=torch.long)
train_loader = DataLoader(data, batch_size, shuffle=True)

torch.manual_seed(seed)
torch.backends.cudnn.deterministic = True
generator = Generator(n_layers, block_dim)
critic = Critic(n_layers, block_dim)

# %%
# Train GAN
g_optimizer = optim.Adam(generator.parameters(), lr=lr)
c_optimizer = optim.Adam(critic.parameters(), lr=lr)

total_loss = []
total_g_loss = []
total_c_loss = []

if cuda:
   #autoencoder = autoencoder.cuda()
   generator = generator.cuda()
   critic = critic.cuda()
    
   print('G Parameters:', sum([p.numel() for p in generator.parameters() if p.requires_grad]))
   print('C Parameters:', sum([p.numel() for p in critic.parameters() if p.requires_grad]))
    
   best_loss = np.inf
    
   for epoch in range(1, epochs + 1):
     g_loss, c_loss = train_gan(epoch)
     loss = g_loss + c_loss
     total_loss.append(loss)
     total_g_loss.append(g_loss)
     total_c_loss.append(c_loss)

     print('Samples:')
     generator.cpu()
     for x in range(10):
        joke = generate_joke()
        print(joke)
          
     if loss < best_loss:
        best_loss = loss
        print('* Saved')
        torch.save(generator.state_dict(), 'generator.th')
        torch.save(critic.state_dict(), 'critic.th')
# Out:
# G Parameters: 101000
# C Parameters: 101000
# Epoch: 1 | Batch: 0/101728 (0%) | G Loss: -0.071708 | C Loss: -0.007274
# Epoch: 1 | Batch: 320/101728 (0%) | G Loss: -0.080412 | C Loss: 0.092105
# Epoch: 1 | Batch: 640/101728 (1%) | G Loss: -0.077947 | C Loss: 0.051432
# Epoch: 1 | Batch: 960/101728 (1%) | G Loss: -0.082574 | C Loss: 0.020005
# Epoch: 1 | Batch: 1280/101728 (1%) | G Loss: -0.082634 | C Loss: 0.005060
# Epoch: 1 | Batch: 1600/101728 (2%) | G Loss: -0.082479 | C Loss: 0.007400
# Epoch: 1 | Batch: 1920/101728 (2%) | G Loss: -0.079033 | C Loss: 0.021854
# Epoch: 1 | Batch: 2240/101728 (2%) | G Loss: -0.071473 | C Loss: 0.005592
# Epoch: 1 | Batch: 2560/101728 (3%) | G Loss: -0.062739 | C Loss: 0.004895
# Epoch: 1 | Batch: 2880/101728 (3%) | G Loss: -0.054123 | C Loss: 0.005749
# Epoch: 1 | Batch: 3200/101728 (3%) | G Loss: -0.045469 | C Loss: -0.007965
# Epoch: 1 | Batch: 3520/101728 (3%) | G Loss: -0.039044 | C Loss: -0.008982
# Epoch: 1 | Batch: 3840/101728 (4%) | G Loss: -0.033531 | C Loss: -0.013414
# Epoch: 1 | Batch: 4160/101728 (4%) | G Loss: -0.030715 | C Loss: -0.016939
# Epoch: 1 | Batch: 4480/101728 (4%) | G Loss: -0.028192 | C Loss: -0.011524
# Epoch: 1 | Batch: 4800/101728 (5%) | G Loss: -0.028662 | C Loss: -0.010892
# Epoch: 1 | Batch: 5120/101728 (5%) | G Loss: -0.030773 | C Loss: -0.015764
# Epoch: 1 | Batch: 5440/101728 (5%) | G Loss: -0.034016 | C Loss: -0.013229
# Epoch: 1 | Batch: 5760/101728 (6%) | G Loss: -0.037808 | C Loss: -0.012559
# Epoch: 1 | Batch: 6080/101728 (6%) | G Loss: -0.044434 | C Loss: -0.011164
# Epoch: 1 | Batch: 6400/101728 (6%) | G Loss: -0.049237 | C Loss: -0.010053
# Epoch: 1 | Batch: 6720/101728 (7%) | G Loss: -0.054017 | C Loss: -0.004002
# Epoch: 1 | Batch: 7040/101728 (7%) | G Loss: -0.057244 | C Loss: -0.006533
# Epoch: 1 | Batch: 7360/101728 (7%) | G Loss: -0.059710 | C Loss: -0.001828
# Epoch: 1 | Batch: 7680/101728 (8%) | G Loss: -0.059432 | C Loss: 0.002989
# Epoch: 1 | Batch: 8000/101728 (8%) | G Loss: -0.060406 | C Loss: -0.007936
# Epoch: 1 | Batch: 8320/101728 (8%) | G Loss: -0.060608 | C Loss: -0.006686
# Epoch: 1 | Batch: 8640/101728 (8%) | G Loss: -0.061161 | C Loss: -0.005661
# Epoch: 1 | Batch: 8960/101728 (9%) | G Loss: -0.061733 | C Loss: -0.005076
# Epoch: 1 | Batch: 9280/101728 (9%) | G Loss: -0.061671 | C Loss: -0.000211
# Epoch: 1 | Batch: 9600/101728 (9%) | G Loss: -0.062329 | C Loss: -0.005525
# Epoch: 1 | Batch: 9920/101728 (10%) | G Loss: -0.062094 | C Loss: 0.000663
# Epoch: 1 | Batch: 10240/101728 (10%) | G Loss: -0.059630 | C Loss: -0.005249
# Epoch: 1 | Batch: 10560/101728 (10%) | G Loss: -0.057210 | C Loss: -0.010483
# Epoch: 1 | Batch: 10880/101728 (11%) | G Loss: -0.056605 | C Loss: -0.010071
# Epoch: 1 | Batch: 11200/101728 (11%) | G Loss: -0.055543 | C Loss: -0.006902
# Epoch: 1 | Batch: 11520/101728 (11%) | G Loss: -0.051000 | C Loss: -0.003875
# Epoch: 1 | Batch: 11840/101728 (12%) | G Loss: -0.048291 | C Loss: -0.004708
# Epoch: 1 | Batch: 12160/101728 (12%) | G Loss: -0.046656 | C Loss: -0.009082
# Epoch: 1 | Batch: 12480/101728 (12%) | G Loss: -0.047006 | C Loss: -0.010356
# Epoch: 1 | Batch: 12800/101728 (13%) | G Loss: -0.048119 | C Loss: -0.009337
# Epoch: 1 | Batch: 13120/101728 (13%) | G Loss: -0.049139 | C Loss: -0.007019
# Epoch: 1 | Batch: 13440/101728 (13%) | G Loss: -0.050000 | C Loss: -0.003685
# Epoch: 1 | Batch: 13760/101728 (14%) | G Loss: -0.050900 | C Loss: -0.006461
# Epoch: 1 | Batch: 14080/101728 (14%) | G Loss: -0.055289 | C Loss: -0.005826
# Epoch: 1 | Batch: 14400/101728 (14%) | G Loss: -0.056263 | C Loss: -0.007304
# Epoch: 1 | Batch: 14720/101728 (14%) | G Loss: -0.060317 | C Loss: -0.005704
# Epoch: 1 | Batch: 15040/101728 (15%) | G Loss: -0.061754 | C Loss: -0.006104
# Epoch: 1 | Batch: 15360/101728 (15%) | G Loss: -0.063352 | C Loss: -0.003691
# Epoch: 1 | Batch: 15680/101728 (15%) | G Loss: -0.067083 | C Loss: -0.003991
# Epoch: 1 | Batch: 16000/101728 (16%) | G Loss: -0.067704 | C Loss: 0.005549
# Epoch: 1 | Batch: 16320/101728 (16%) | G Loss: -0.070620 | C Loss: -0.002490
# Epoch: 1 | Batch: 16640/101728 (16%) | G Loss: -0.070954 | C Loss: 0.002368
# Epoch: 1 | Batch: 16960/101728 (17%) | G Loss: -0.069029 | C Loss: -0.004058
# Epoch: 1 | Batch: 17280/101728 (17%) | G Loss: -0.067575 | C Loss: -0.004511
# Epoch: 1 | Batch: 17600/101728 (17%) | G Loss: -0.065757 | C Loss: -0.008298
# Epoch: 1 | Batch: 17920/101728 (18%) | G Loss: -0.064113 | C Loss: -0.008933
# Epoch: 1 | Batch: 18240/101728 (18%) | G Loss: -0.060030 | C Loss: -0.000420
# Epoch: 1 | Batch: 18560/101728 (18%) | G Loss: -0.057023 | C Loss: -0.007730
# Epoch: 1 | Batch: 18880/101728 (19%) | G Loss: -0.057962 | C Loss: -0.005008
# Epoch: 1 | Batch: 19200/101728 (19%) | G Loss: -0.057721 | C Loss: -0.005189
# Epoch: 1 | Batch: 19520/101728 (19%) | G Loss: -0.057202 | C Loss: -0.003228
# Epoch: 1 | Batch: 19840/101728 (20%) | G Loss: -0.053775 | C Loss: -0.007823
# Epoch: 1 | Batch: 20160/101728 (20%) | G Loss: -0.052582 | C Loss: -0.006821
# Epoch: 1 | Batch: 20480/101728 (20%) | G Loss: -0.051430 | C Loss: -0.008412
# Epoch: 1 | Batch: 20800/101728 (20%) | G Loss: -0.050227 | C Loss: -0.003041
# Epoch: 1 | Batch: 21120/101728 (21%) | G Loss: -0.049221 | C Loss: -0.009792
# Epoch: 1 | Batch: 21440/101728 (21%) | G Loss: -0.047730 | C Loss: -0.007077
# Epoch: 1 | Batch: 21760/101728 (21%) | G Loss: -0.048775 | C Loss: -0.005735
# Epoch: 1 | Batch: 22080/101728 (22%) | G Loss: -0.047579 | C Loss: -0.007975
# Epoch: 1 | Batch: 22400/101728 (22%) | G Loss: -0.050066 | C Loss: -0.007567
# Epoch: 1 | Batch: 22720/101728 (22%) | G Loss: -0.051748 | C Loss: -0.008640
# Epoch: 1 | Batch: 23040/101728 (23%) | G Loss: -0.053576 | C Loss: -0.005693
# Epoch: 1 | Batch: 23360/101728 (23%) | G Loss: -0.055336 | C Loss: -0.006421
# Epoch: 1 | Batch: 23680/101728 (23%) | G Loss: -0.055591 | C Loss: -0.003047
# Epoch: 1 | Batch: 24000/101728 (24%) | G Loss: -0.055952 | C Loss: -0.008719
# Epoch: 1 | Batch: 24320/101728 (24%) | G Loss: -0.056569 | C Loss: -0.006992
# Epoch: 1 | Batch: 24640/101728 (24%) | G Loss: -0.057253 | C Loss: -0.003816
# Epoch: 1 | Batch: 24960/101728 (25%) | G Loss: -0.055106 | C Loss: -0.010007
# Epoch: 1 | Batch: 25280/101728 (25%) | G Loss: -0.056436 | C Loss: -0.004850
# Epoch: 1 | Batch: 25600/101728 (25%) | G Loss: -0.057635 | C Loss: 0.002276
# Epoch: 1 | Batch: 25920/101728 (25%) | G Loss: -0.056194 | C Loss: -0.008234
# Epoch: 1 | Batch: 26240/101728 (26%) | G Loss: -0.055922 | C Loss: -0.000566
# Epoch: 1 | Batch: 26560/101728 (26%) | G Loss: -0.056083 | C Loss: 0.005991
# Epoch: 1 | Batch: 26880/101728 (26%) | G Loss: -0.055370 | C Loss: -0.002922
# Epoch: 1 | Batch: 27200/101728 (27%) | G Loss: -0.055312 | C Loss: -0.004872
# Epoch: 1 | Batch: 27520/101728 (27%) | G Loss: -0.053857 | C Loss: -0.004121
# Epoch: 1 | Batch: 27840/101728 (27%) | G Loss: -0.052439 | C Loss: -0.004312
# Epoch: 1 | Batch: 28160/101728 (28%) | G Loss: -0.051574 | C Loss: -0.003736
# Epoch: 1 | Batch: 28480/101728 (28%) | G Loss: -0.047247 | C Loss: 0.002330
# Epoch: 1 | Batch: 28800/101728 (28%) | G Loss: -0.045134 | C Loss: -0.003647
# Epoch: 1 | Batch: 29120/101728 (29%) | G Loss: -0.045364 | C Loss: -0.010683
# Epoch: 1 | Batch: 29440/101728 (29%) | G Loss: -0.047875 | C Loss: -0.007382
# Epoch: 1 | Batch: 29760/101728 (29%) | G Loss: -0.050487 | C Loss: -0.012248
# Epoch: 1 | Batch: 30080/101728 (30%) | G Loss: -0.052455 | C Loss: -0.013484
# Epoch: 1 | Batch: 30400/101728 (30%) | G Loss: -0.055719 | C Loss: -0.009742
# Epoch: 1 | Batch: 30720/101728 (30%) | G Loss: -0.058028 | C Loss: -0.006212
# Epoch: 1 | Batch: 31040/101728 (31%) | G Loss: -0.061265 | C Loss: -0.004532
# Epoch: 1 | Batch: 31360/101728 (31%) | G Loss: -0.063721 | C Loss: 0.000174
# Epoch: 1 | Batch: 31680/101728 (31%) | G Loss: -0.064368 | C Loss: -0.002526
# Epoch: 1 | Batch: 32000/101728 (31%) | G Loss: -0.062545 | C Loss: -0.004993
# Epoch: 1 | Batch: 32320/101728 (32%) | G Loss: -0.059017 | C Loss: -0.004490
# Epoch: 1 | Batch: 32640/101728 (32%) | G Loss: -0.054914 | C Loss: -0.010453
# Epoch: 1 | Batch: 32960/101728 (32%) | G Loss: -0.049925 | C Loss: -0.011394
# Epoch: 1 | Batch: 33280/101728 (33%) | G Loss: -0.044746 | C Loss: -0.013569
# Epoch: 1 | Batch: 33600/101728 (33%) | G Loss: -0.044959 | C Loss: -0.012865
# Epoch: 1 | Batch: 33920/101728 (33%) | G Loss: -0.044349 | C Loss: -0.007125
# Epoch: 1 | Batch: 34240/101728 (34%) | G Loss: -0.043228 | C Loss: -0.005056
# Epoch: 1 | Batch: 34560/101728 (34%) | G Loss: -0.043176 | C Loss: -0.008908
# Epoch: 1 | Batch: 34880/101728 (34%) | G Loss: -0.040760 | C Loss: -0.008461
# Epoch: 1 | Batch: 35200/101728 (35%) | G Loss: -0.040884 | C Loss: -0.010010
# Epoch: 1 | Batch: 35520/101728 (35%) | G Loss: -0.042721 | C Loss: -0.004461
# Epoch: 1 | Batch: 35840/101728 (35%) | G Loss: -0.044110 | C Loss: -0.009850
# Epoch: 1 | Batch: 36160/101728 (36%) | G Loss: -0.048717 | C Loss: -0.008884
# Epoch: 1 | Batch: 36480/101728 (36%) | G Loss: -0.049454 | C Loss: -0.003604
# Epoch: 1 | Batch: 36800/101728 (36%) | G Loss: -0.050085 | C Loss: -0.005671
# Epoch: 1 | Batch: 37120/101728 (36%) | G Loss: -0.051492 | C Loss: -0.006964
# Epoch: 1 | Batch: 37440/101728 (37%) | G Loss: -0.053849 | C Loss: -0.003502
# Epoch: 1 | Batch: 37760/101728 (37%) | G Loss: -0.052902 | C Loss: -0.005418
# Epoch: 1 | Batch: 38080/101728 (37%) | G Loss: -0.053009 | C Loss: 0.018876
# Epoch: 1 | Batch: 38400/101728 (38%) | G Loss: -0.053420 | C Loss: -0.004107
# Epoch: 1 | Batch: 38720/101728 (38%) | G Loss: -0.054426 | C Loss: -0.003983
# Epoch: 1 | Batch: 39040/101728 (38%) | G Loss: -0.051781 | C Loss: -0.007906
# Epoch: 1 | Batch: 39360/101728 (39%) | G Loss: -0.051983 | C Loss: -0.007996
# Epoch: 1 | Batch: 39680/101728 (39%) | G Loss: -0.052199 | C Loss: -0.000688
# Epoch: 1 | Batch: 40000/101728 (39%) | G Loss: -0.050533 | C Loss: -0.006290
# Epoch: 1 | Batch: 40320/101728 (40%) | G Loss: -0.048011 | C Loss: -0.008955
# Epoch: 1 | Batch: 40640/101728 (40%) | G Loss: -0.045714 | C Loss: -0.007331
# Epoch: 1 | Batch: 40960/101728 (40%) | G Loss: -0.044808 | C Loss: -0.004992
# Epoch: 1 | Batch: 41280/101728 (41%) | G Loss: -0.042695 | C Loss: -0.007735
# Epoch: 1 | Batch: 41600/101728 (41%) | G Loss: -0.044069 | C Loss: -0.008280
# Epoch: 1 | Batch: 41920/101728 (41%) | G Loss: -0.043358 | C Loss: -0.008310
# Epoch: 1 | Batch: 42240/101728 (42%) | G Loss: -0.042617 | C Loss: -0.007720
# Epoch: 1 | Batch: 42560/101728 (42%) | G Loss: -0.041437 | C Loss: -0.003758
# Epoch: 1 | Batch: 42880/101728 (42%) | G Loss: -0.040689 | C Loss: -0.008656
# Epoch: 1 | Batch: 43200/101728 (42%) | G Loss: -0.042037 | C Loss: -0.009053
# Epoch: 1 | Batch: 43520/101728 (43%) | G Loss: -0.043671 | C Loss: -0.006065
# Epoch: 1 | Batch: 43840/101728 (43%) | G Loss: -0.045822 | C Loss: -0.005674
# Epoch: 1 | Batch: 44160/101728 (43%) | G Loss: -0.047559 | C Loss: -0.003159
# Epoch: 1 | Batch: 44480/101728 (44%) | G Loss: -0.048825 | C Loss: 0.006415
# Epoch: 1 | Batch: 44800/101728 (44%) | G Loss: -0.049690 | C Loss: -0.000860
# Epoch: 1 | Batch: 45120/101728 (44%) | G Loss: -0.048039 | C Loss: -0.001063
# Epoch: 1 | Batch: 45440/101728 (45%) | G Loss: -0.044547 | C Loss: -0.005427
# Epoch: 1 | Batch: 45760/101728 (45%) | G Loss: -0.041745 | C Loss: -0.002352
# Epoch: 1 | Batch: 46080/101728 (45%) | G Loss: -0.043307 | C Loss: 0.007858
# Epoch: 1 | Batch: 46400/101728 (46%) | G Loss: -0.042404 | C Loss: -0.010118
# Epoch: 1 | Batch: 46720/101728 (46%) | G Loss: -0.043311 | C Loss: -0.006098
# Epoch: 1 | Batch: 47040/101728 (46%) | G Loss: -0.042818 | C Loss: -0.008833
# Epoch: 1 | Batch: 47360/101728 (47%) | G Loss: -0.042979 | C Loss: -0.004875
# Epoch: 1 | Batch: 47680/101728 (47%) | G Loss: -0.044162 | C Loss: 0.004779
# Epoch: 1 | Batch: 48000/101728 (47%) | G Loss: -0.047184 | C Loss: 0.009153
# Epoch: 1 | Batch: 48320/101728 (47%) | G Loss: -0.046575 | C Loss: -0.003147
# Epoch: 1 | Batch: 48640/101728 (48%) | G Loss: -0.044993 | C Loss: -0.002889
# Epoch: 1 | Batch: 48960/101728 (48%) | G Loss: -0.045388 | C Loss: -0.004760
# Epoch: 1 | Batch: 49280/101728 (48%) | G Loss: -0.043595 | C Loss: -0.009363
# Epoch: 1 | Batch: 49600/101728 (49%) | G Loss: -0.047195 | C Loss: -0.003639
# Epoch: 1 | Batch: 49920/101728 (49%) | G Loss: -0.050247 | C Loss: 0.002895
# Epoch: 1 | Batch: 50240/101728 (49%) | G Loss: -0.052934 | C Loss: -0.008803
# Epoch: 1 | Batch: 50560/101728 (50%) | G Loss: -0.055619 | C Loss: -0.008344
# Epoch: 1 | Batch: 50880/101728 (50%) | G Loss: -0.056316 | C Loss: -0.006058
# Epoch: 1 | Batch: 51200/101728 (50%) | G Loss: -0.058945 | C Loss: -0.005620
# Epoch: 1 | Batch: 51520/101728 (51%) | G Loss: -0.059530 | C Loss: -0.004143
# Epoch: 1 | Batch: 51840/101728 (51%) | G Loss: -0.060933 | C Loss: -0.002107
# Epoch: 1 | Batch: 52160/101728 (51%) | G Loss: -0.061986 | C Loss: -0.005348
# Epoch: 1 | Batch: 52480/101728 (52%) | G Loss: -0.060815 | C Loss: -0.001369
# Epoch: 1 | Batch: 52800/101728 (52%) | G Loss: -0.056553 | C Loss: -0.005550
# Epoch: 1 | Batch: 53120/101728 (52%) | G Loss: -0.054263 | C Loss: -0.006132
# Epoch: 1 | Batch: 53440/101728 (53%) | G Loss: -0.049367 | C Loss: -0.004248
# Epoch: 1 | Batch: 53760/101728 (53%) | G Loss: -0.042944 | C Loss: -0.006347
# Epoch: 1 | Batch: 54080/101728 (53%) | G Loss: -0.041807 | C Loss: 0.000096
# Epoch: 1 | Batch: 54400/101728 (53%) | G Loss: -0.041967 | C Loss: -0.007388
# Epoch: 1 | Batch: 54720/101728 (54%) | G Loss: -0.039377 | C Loss: -0.004306
# Epoch: 1 | Batch: 55040/101728 (54%) | G Loss: -0.039633 | C Loss: -0.006661
# Epoch: 1 | Batch: 55360/101728 (54%) | G Loss: -0.038436 | C Loss: -0.005914
# Epoch: 1 | Batch: 55680/101728 (55%) | G Loss: -0.040270 | C Loss: -0.008246
# Epoch: 1 | Batch: 56000/101728 (55%) | G Loss: -0.042378 | C Loss: 0.001949
# Epoch: 1 | Batch: 56320/101728 (55%) | G Loss: -0.045666 | C Loss: -0.002339
# Epoch: 1 | Batch: 56640/101728 (56%) | G Loss: -0.045119 | C Loss: -0.003665
# Epoch: 1 | Batch: 56960/101728 (56%) | G Loss: -0.046147 | C Loss: -0.000970
# Epoch: 1 | Batch: 57280/101728 (56%) | G Loss: -0.046826 | C Loss: -0.006030
# Epoch: 1 | Batch: 57600/101728 (57%) | G Loss: -0.049093 | C Loss: -0.007249
# Epoch: 1 | Batch: 57920/101728 (57%) | G Loss: -0.050392 | C Loss: 0.002598
# Epoch: 1 | Batch: 58240/101728 (57%) | G Loss: -0.050650 | C Loss: -0.007925
# Epoch: 1 | Batch: 58560/101728 (58%) | G Loss: -0.051911 | C Loss: -0.006377
# Epoch: 1 | Batch: 58880/101728 (58%) | G Loss: -0.052682 | C Loss: 0.001325
# Epoch: 1 | Batch: 59200/101728 (58%) | G Loss: -0.052888 | C Loss: -0.003416
# Epoch: 1 | Batch: 59520/101728 (59%) | G Loss: -0.049531 | C Loss: -0.002115
# Epoch: 1 | Batch: 59840/101728 (59%) | G Loss: -0.048117 | C Loss: -0.007102
# Epoch: 1 | Batch: 60160/101728 (59%) | G Loss: -0.049428 | C Loss: -0.004084
# Epoch: 1 | Batch: 60480/101728 (59%) | G Loss: -0.048505 | C Loss: -0.001290
# Epoch: 1 | Batch: 60800/101728 (60%) | G Loss: -0.049937 | C Loss: -0.008882
# Epoch: 1 | Batch: 61120/101728 (60%) | G Loss: -0.048978 | C Loss: -0.007768
# Epoch: 1 | Batch: 61440/101728 (60%) | G Loss: -0.045129 | C Loss: -0.009446
# Epoch: 1 | Batch: 61760/101728 (61%) | G Loss: -0.043337 | C Loss: -0.009313
# Epoch: 1 | Batch: 62080/101728 (61%) | G Loss: -0.045224 | C Loss: -0.006168
# Epoch: 1 | Batch: 62400/101728 (61%) | G Loss: -0.047759 | C Loss: -0.002461
# Epoch: 1 | Batch: 62720/101728 (62%) | G Loss: -0.048232 | C Loss: -0.006553
# Epoch: 1 | Batch: 63040/101728 (62%) | G Loss: -0.048123 | C Loss: -0.006223
# Epoch: 1 | Batch: 63360/101728 (62%) | G Loss: -0.049671 | C Loss: -0.007045
# Epoch: 1 | Batch: 63680/101728 (63%) | G Loss: -0.049141 | C Loss: -0.008002
# Epoch: 1 | Batch: 64000/101728 (63%) | G Loss: -0.050029 | C Loss: -0.007728
# Epoch: 1 | Batch: 64320/101728 (63%) | G Loss: -0.049336 | C Loss: -0.002294
# Epoch: 1 | Batch: 64640/101728 (64%) | G Loss: -0.049951 | C Loss: -0.002243
# Epoch: 1 | Batch: 64960/101728 (64%) | G Loss: -0.050330 | C Loss: -0.004152
# Epoch: 1 | Batch: 65280/101728 (64%) | G Loss: -0.048581 | C Loss: -0.008075
# Epoch: 1 | Batch: 65600/101728 (64%) | G Loss: -0.044614 | C Loss: -0.004518
# Epoch: 1 | Batch: 65920/101728 (65%) | G Loss: -0.040482 | C Loss: -0.005581
# Epoch: 1 | Batch: 66240/101728 (65%) | G Loss: -0.040187 | C Loss: -0.009287
# Epoch: 1 | Batch: 66560/101728 (65%) | G Loss: -0.039966 | C Loss: -0.002072
# Epoch: 1 | Batch: 66880/101728 (66%) | G Loss: -0.040303 | C Loss: -0.004649
# Epoch: 1 | Batch: 67200/101728 (66%) | G Loss: -0.042819 | C Loss: -0.006879
# Epoch: 1 | Batch: 67520/101728 (66%) | G Loss: -0.045409 | C Loss: -0.002852
# Epoch: 1 | Batch: 67840/101728 (67%) | G Loss: -0.047658 | C Loss: -0.004047
# Epoch: 1 | Batch: 68160/101728 (67%) | G Loss: -0.049723 | C Loss: -0.004295
# Epoch: 1 | Batch: 68480/101728 (67%) | G Loss: -0.051458 | C Loss: -0.000092
# Epoch: 1 | Batch: 68800/101728 (68%) | G Loss: -0.053272 | C Loss: -0.000283
# Epoch: 1 | Batch: 69120/101728 (68%) | G Loss: -0.054195 | C Loss: -0.002623
# Epoch: 1 | Batch: 69440/101728 (68%) | G Loss: -0.056191 | C Loss: -0.006455
# Epoch: 1 | Batch: 69760/101728 (69%) | G Loss: -0.058034 | C Loss: -0.006096
# Epoch: 1 | Batch: 70080/101728 (69%) | G Loss: -0.058217 | C Loss: -0.006782
# Epoch: 1 | Batch: 70400/101728 (69%) | G Loss: -0.058629 | C Loss: -0.006185
# Epoch: 1 | Batch: 70720/101728 (70%) | G Loss: -0.056300 | C Loss: -0.005874
# Epoch: 1 | Batch: 71040/101728 (70%) | G Loss: -0.050266 | C Loss: -0.009008
# Epoch: 1 | Batch: 71360/101728 (70%) | G Loss: -0.049753 | C Loss: 0.002277
# Epoch: 1 | Batch: 71680/101728 (70%) | G Loss: -0.048100 | C Loss: -0.005189
# Epoch: 1 | Batch: 72000/101728 (71%) | G Loss: -0.050367 | C Loss: 0.000932
# Epoch: 1 | Batch: 72320/101728 (71%) | G Loss: -0.050578 | C Loss: 0.006524
# Epoch: 1 | Batch: 72640/101728 (71%) | G Loss: -0.048713 | C Loss: 0.000770
# Epoch: 1 | Batch: 72960/101728 (72%) | G Loss: -0.041722 | C Loss: -0.002974
# Epoch: 1 | Batch: 73280/101728 (72%) | G Loss: -0.036191 | C Loss: -0.010706
# Epoch: 1 | Batch: 73600/101728 (72%) | G Loss: -0.031569 | C Loss: -0.012050
# Epoch: 1 | Batch: 73920/101728 (73%) | G Loss: -0.030703 | C Loss: -0.013817
# Epoch: 1 | Batch: 74240/101728 (73%) | G Loss: -0.031431 | C Loss: -0.014009
# Epoch: 1 | Batch: 74560/101728 (73%) | G Loss: -0.033854 | C Loss: -0.012300
# Epoch: 1 | Batch: 74880/101728 (74%) | G Loss: -0.034763 | C Loss: -0.008279
# Epoch: 1 | Batch: 75200/101728 (74%) | G Loss: -0.037347 | C Loss: -0.001631
# Epoch: 1 | Batch: 75520/101728 (74%) | G Loss: -0.044366 | C Loss: -0.002896
# Epoch: 1 | Batch: 75840/101728 (75%) | G Loss: -0.049739 | C Loss: -0.003868
# Epoch: 1 | Batch: 76160/101728 (75%) | G Loss: -0.052000 | C Loss: 0.002501
# Epoch: 1 | Batch: 76480/101728 (75%) | G Loss: -0.054782 | C Loss: -0.001522
# Epoch: 1 | Batch: 76800/101728 (75%) | G Loss: -0.055102 | C Loss: -0.000651
# Epoch: 1 | Batch: 77120/101728 (76%) | G Loss: -0.055296 | C Loss: -0.005261
# Epoch: 1 | Batch: 77440/101728 (76%) | G Loss: -0.054632 | C Loss: -0.006144
# Epoch: 1 | Batch: 77760/101728 (76%) | G Loss: -0.051309 | C Loss: -0.003236
# Epoch: 1 | Batch: 78080/101728 (77%) | G Loss: -0.049210 | C Loss: -0.001661
# Epoch: 1 | Batch: 78400/101728 (77%) | G Loss: -0.049514 | C Loss: 0.013177
# Epoch: 1 | Batch: 78720/101728 (77%) | G Loss: -0.048033 | C Loss: -0.001077
# Epoch: 1 | Batch: 79040/101728 (78%) | G Loss: -0.046731 | C Loss: -0.003502
# Epoch: 1 | Batch: 79360/101728 (78%) | G Loss: -0.041956 | C Loss: -0.008541
# Epoch: 1 | Batch: 79680/101728 (78%) | G Loss: -0.038757 | C Loss: 0.000448
# Epoch: 1 | Batch: 80000/101728 (79%) | G Loss: -0.036596 | C Loss: -0.002680
# Epoch: 1 | Batch: 80320/101728 (79%) | G Loss: -0.031209 | C Loss: -0.005981
# Epoch: 1 | Batch: 80640/101728 (79%) | G Loss: -0.027463 | C Loss: -0.006160
# Epoch: 1 | Batch: 80960/101728 (80%) | G Loss: -0.026236 | C Loss: 0.003113
# Epoch: 1 | Batch: 81280/101728 (80%) | G Loss: -0.027265 | C Loss: -0.005786
# Epoch: 1 | Batch: 81600/101728 (80%) | G Loss: -0.030081 | C Loss: -0.008319
# Epoch: 1 | Batch: 81920/101728 (81%) | G Loss: -0.033653 | C Loss: -0.009184
# Epoch: 1 | Batch: 82240/101728 (81%) | G Loss: -0.038746 | C Loss: -0.008989
# Epoch: 1 | Batch: 82560/101728 (81%) | G Loss: -0.042501 | C Loss: -0.004164
# Epoch: 1 | Batch: 82880/101728 (81%) | G Loss: -0.047263 | C Loss: -0.005474
# Epoch: 1 | Batch: 83200/101728 (82%) | G Loss: -0.051885 | C Loss: -0.004476
# Epoch: 1 | Batch: 83520/101728 (82%) | G Loss: -0.052719 | C Loss: -0.004673
# Epoch: 1 | Batch: 83840/101728 (82%) | G Loss: -0.053353 | C Loss: -0.002764
# Epoch: 1 | Batch: 84160/101728 (83%) | G Loss: -0.051985 | C Loss: -0.007779
# Epoch: 1 | Batch: 84480/101728 (83%) | G Loss: -0.052852 | C Loss: -0.004046
# Epoch: 1 | Batch: 84800/101728 (83%) | G Loss: -0.053350 | C Loss: 0.004794
# Epoch: 1 | Batch: 85120/101728 (84%) | G Loss: -0.052689 | C Loss: -0.001059
# Epoch: 1 | Batch: 85440/101728 (84%) | G Loss: -0.051678 | C Loss: 0.004680
# Epoch: 1 | Batch: 85760/101728 (84%) | G Loss: -0.050109 | C Loss: -0.005172
# Epoch: 1 | Batch: 86080/101728 (85%) | G Loss: -0.050384 | C Loss: -0.004144
# Epoch: 1 | Batch: 86400/101728 (85%) | G Loss: -0.049185 | C Loss: -0.007977
# Epoch: 1 | Batch: 86720/101728 (85%) | G Loss: -0.048310 | C Loss: -0.007837
# Epoch: 1 | Batch: 87040/101728 (86%) | G Loss: -0.046642 | C Loss: -0.007321
# Epoch: 1 | Batch: 87360/101728 (86%) | G Loss: -0.042086 | C Loss: 0.000694
# Epoch: 1 | Batch: 87680/101728 (86%) | G Loss: -0.038730 | C Loss: -0.004265
# Epoch: 1 | Batch: 88000/101728 (87%) | G Loss: -0.037971 | C Loss: -0.004136
# Epoch: 1 | Batch: 88320/101728 (87%) | G Loss: -0.036659 | C Loss: -0.005433
# Epoch: 1 | Batch: 88640/101728 (87%) | G Loss: -0.034720 | C Loss: 0.000949
# Epoch: 1 | Batch: 88960/101728 (87%) | G Loss: -0.031826 | C Loss: 0.024915
# Epoch: 1 | Batch: 89280/101728 (88%) | G Loss: -0.030721 | C Loss: -0.005247
# Epoch: 1 | Batch: 89600/101728 (88%) | G Loss: -0.035408 | C Loss: 0.002072
# Epoch: 1 | Batch: 89920/101728 (88%) | G Loss: -0.040515 | C Loss: 0.000793
# Epoch: 1 | Batch: 90240/101728 (89%) | G Loss: -0.044563 | C Loss: -0.000915
# Epoch: 1 | Batch: 90560/101728 (89%) | G Loss: -0.046292 | C Loss: 0.003935
# Epoch: 1 | Batch: 90880/101728 (89%) | G Loss: -0.045594 | C Loss: -0.003748
# Epoch: 1 | Batch: 91200/101728 (90%) | G Loss: -0.044296 | C Loss: -0.004890
# Epoch: 1 | Batch: 91520/101728 (90%) | G Loss: -0.043961 | C Loss: -0.000108
# Epoch: 1 | Batch: 91840/101728 (90%) | G Loss: -0.043495 | C Loss: -0.002136
# Epoch: 1 | Batch: 92160/101728 (91%) | G Loss: -0.044032 | C Loss: -0.004332
# Epoch: 1 | Batch: 92480/101728 (91%) | G Loss: -0.044363 | C Loss: -0.006107
# Epoch: 1 | Batch: 92800/101728 (91%) | G Loss: -0.044217 | C Loss: -0.005731
# Epoch: 1 | Batch: 93120/101728 (92%) | G Loss: -0.044984 | C Loss: -0.003040
# Epoch: 1 | Batch: 93440/101728 (92%) | G Loss: -0.045369 | C Loss: -0.010702
# Epoch: 1 | Batch: 93760/101728 (92%) | G Loss: -0.045497 | C Loss: -0.008968
# Epoch: 1 | Batch: 94080/101728 (92%) | G Loss: -0.044298 | C Loss: -0.003775
# Epoch: 1 | Batch: 94400/101728 (93%) | G Loss: -0.044855 | C Loss: -0.007442
# Epoch: 1 | Batch: 94720/101728 (93%) | G Loss: -0.043870 | C Loss: -0.006974
# Epoch: 1 | Batch: 95040/101728 (93%) | G Loss: -0.044089 | C Loss: -0.000263
# Epoch: 1 | Batch: 95360/101728 (94%) | G Loss: -0.044179 | C Loss: -0.006173
# Epoch: 1 | Batch: 95680/101728 (94%) | G Loss: -0.042907 | C Loss: 0.000465
# Epoch: 1 | Batch: 96000/101728 (94%) | G Loss: -0.041689 | C Loss: -0.004746
# Epoch: 1 | Batch: 96320/101728 (95%) | G Loss: -0.040483 | C Loss: -0.004452
# Epoch: 1 | Batch: 96640/101728 (95%) | G Loss: -0.040014 | C Loss: -0.003854
# Epoch: 1 | Batch: 96960/101728 (95%) | G Loss: -0.038024 | C Loss: 0.000227
# Epoch: 1 | Batch: 97280/101728 (96%) | G Loss: -0.038868 | C Loss: 0.005573
# Epoch: 1 | Batch: 97600/101728 (96%) | G Loss: -0.041922 | C Loss: -0.002856
# Epoch: 1 | Batch: 97920/101728 (96%) | G Loss: -0.044903 | C Loss: -0.004886
# Epoch: 1 | Batch: 98240/101728 (97%) | G Loss: -0.044148 | C Loss: -0.005359
# Epoch: 1 | Batch: 98560/101728 (97%) | G Loss: -0.045295 | C Loss: 0.000827
# Epoch: 1 | Batch: 98880/101728 (97%) | G Loss: -0.043987 | C Loss: -0.006219
# Epoch: 1 | Batch: 99200/101728 (98%) | G Loss: -0.043851 | C Loss: -0.006395
# Epoch: 1 | Batch: 99520/101728 (98%) | G Loss: -0.043177 | C Loss: -0.006613
# Epoch: 1 | Batch: 99840/101728 (98%) | G Loss: -0.043282 | C Loss: -0.003265
# Epoch: 1 | Batch: 100160/101728 (98%) | G Loss: -0.043776 | C Loss: -0.004929
# Epoch: 1 | Batch: 100480/101728 (99%) | G Loss: -0.043047 | C Loss: -0.009030
# Epoch: 1 | Batch: 100800/101728 (99%) | G Loss: -0.041867 | C Loss: -0.008735
# Epoch: 1 | Batch: 101120/101728 (99%) | G Loss: -0.041865 | C Loss: -0.007940
# Epoch: 1 | Batch: 101440/101728 (100%) | G Loss: -0.042383 | C Loss: -0.006067
# * (Train) Epoch: 1 | G Loss: -0.0491 | C Loss: -0.0024
# Samples:
#
#
#  ? sposh
#
#  annoyed jerk because reduss lion but but noise will drill a the red over glue .
#  usingpr ? ? ? ? ? ? ? ? ? ? redneck ? a laughing definitely definitely comb ?
# ima blond ? blond ? ? forgive ? why does kanye frog ? across across a raise ahouse ? it landed ?
#  finnishrat ? finnish and ? ? ? ? a see across glad ? anyway fucked what
#  trouble . toothpaste . expert . a mum firm week . . .
#  lights cell ? k k . . . ? ? ? how does ? ? ? ? anyone ? ? a injured bra . stop myself i never stops
# * Saved

# %%
fig, axs = plt.subplots(3)
fig.set_size_inches(10, 10)
plt.xlabel('Epoch')
plt.ylabel('Loss')
axs[0].plot(range(epochs), total_loss)
axs[0].set_title('Total Loss')
axs[1].plot(range(epochs), total_g_loss)
axs[1].set_title('Generator Loss')
axs[2].plot(range(epochs), total_c_loss)
axs[2].set_title('Critic Loss')

# %%
generator = Generator(n_layers, block_dim)
generator.eval()
generator.load_state_dict(torch.load('generator.th', map_location='cpu'))
#stepper_model.load_weights('/content/stepper_model_weights.h5')
#decoder_model.load_weights('/content/decoder_model_weights.h5')
# Out:
# <All keys matched successfully>

# %%
def generate_joke(start=[2], hidden_dim=100):
    # Obtain the latent variable from a random noise
    noise = torch.FloatTensor(np.random.normal(0, 1, (1, hidden_dim)))
    z = generator(noise[None,:,:])
    z = z.squeeze(dim=1)
    z = z.cpu()
    e_h = z.detach().numpy()
    
    # Use stepper to obtain the encoder outputs and cell state
    (e_out, e_c) = stepper_model.predict(e_h)

    # Generate empty target sequence of length 1
    target_seq = np.zeros((1, 1))

    # Populate the first word of target sequence with the index of start token.
    for i in range(len(start)):
      target_seq[i, i] = start[i]

    stop_condition = False
    decoded_sentence = ''

    while not stop_condition:
        (output_tokens, h, c) = decoder_model.predict([target_seq]
                + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        #sampled_token = reverse_target_word_index[sampled_token_index]
        sampled_token = tokenizer.detokenize([[sampled_token_index]]).to_list()
        sampled_token = sampled_token[0][0].decode("utf-8")

        if sampled_token != '[PAD]':
            decoded_sentence += ' ' + sampled_token

        # Exit condition: either hit max length or find the stop word.
        if sampled_token == '[PAD]' or len(decoded_sentence.split()) \
            >= maxlen - 1:
            stop_condition = True

        # Update the target sequence (of length 1)
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        (e_h, e_c) = (h, c)

    return decoded_sentence.replace(" ##",'')

# %%
for x in range(10):
  joke = generate_joke()
  print(joke)

# %% [markdown]
# # Clean and Explore (Dont Run)

# %%
############################################# SETUP ################################################
jokes = np.load("jokes.npy", allow_pickle=True)
jokes = [x[1] for x in jokes if len(x[1].split()) <= 30]
print("No of Jokes:", len(jokes))
print("Samples:",jokes[0])

# %%
def unify(text):
  text = text.lower()
  tokenizer = RegexpTokenizer(r'[A-Za-z0-9?-?,.\']+')
  toks = tokenizer.tokenize(text)
  text = " ".join(toks)
  # separate important punctiations
  text = text.replace(",", " , ")
  text = text.replace("...", "")
  text = text.replace("..", "")
  text = text.replace("....", "")
  text = text.replace(".....", "")
  text = text.replace(".", " . ")
  text = text.replace("! ", " ! ")
  text = text.replace("? ", " ? ")
  text = text.replace("-", " - ")
  text = text.replace("&", "and")
  text = text.replace("'s ", " is ")
  text = text.replace(" m ", " am ")
  text = text.replace("'ve ", " have ")
  text = text.replace("'re ", " are ")
  text = text.replace("'d ", " would ")
  #text = text.replace("n't", " not")
  text = text.replace(" ll ", " will ")
  text = text.replace(" re ", " are ")
  text = text.replace(" ve ", " have ")
  text = text.replace(" d ", " would ")
  text = text.replace(" u ", " you ")
  text = text.replace(" s ", " is ")
  #text = text.replace(":", " , ")
  #text = text.replace(";", " , ")
  text = text.replace("'", " ' ")
  #text = text.replace('"', ' " ')
  #text = text.replace('[', '')
  #text = text.replace(']', '')

  # tokenize using regular expression
  #tokenizer = RegexpTokenizer(r'[A-Za-z0-9?!-?,.\']+')
  #toks = tokenizer.tokenize(text)

  #return "".join(toks)
  return text

# Call
jokes = [unify(x) for x in jokes]

# %%
jokes[:100]

# %%
# Combine jokes to form a long sequence
corpus = " ".join(jokes)
corpus[:1000]

# %%
# Save the cleaned short jokes 
np.save("short_jokes.npy", jokes)

# %%
# Generate word cloud
wordcloud = WordCloud(width = 3000, height = 2000, random_state=1, background_color='white', collocations=False, stopwords = STOPWORDS).generate(corpus)

# Plot word cloud
plt.figure(figsize=(40, 30))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
# Get a dictionary of words by frequency and print the most frequent words
tokenized_jokes = corpus.split(" ")
count = Counter(tokenized_jokes)
unigrams = {k: v for k, v in sorted(count.items(), key=lambda item: item[1], reverse=True)}
bigrams = Counter(ngrams(tokenized_jokes,2))
trigrams = Counter(ngrams(tokenized_jokes,3))

# Get vocabulary and print size
vocab = list(set(count.keys()))
print("Vocab Size:", len(vocab))

# %%
# Create data frames for the frequencies
unigrams = pd.DataFrame(unigrams.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)
bigrams = pd.DataFrame(bigrams.items(),columns=['pairs','frequency']).sort_values(by='frequency',ascending=False)
trigrams = pd.DataFrame(trigrams.items(),columns=['trigrams','frequency']).sort_values(by='frequency',ascending=False)

# %%
# Frequency of frequencies
unigrams.groupby(['frequency']).count()

# %%
unigrams.tail(30)

# %%
# create subplot of the different data frames
fig, axes = plt.subplots(3,1,figsize=(8,20))
sns.barplot(ax=axes[0],x='frequency',y='word',data=unigrams.head(30))
sns.barplot(ax=axes[1],x='frequency',y='pairs',data=bigrams.head(30))
sns.barplot(ax=axes[2],x='frequency',y='trigrams',data=trigrams.head(30))

# %%
# set up dictionary of words
words = set(nltk.corpus.words.words())
count = []

# Tokenise jokes
tokenized_jokes = [jokes.split(" ") for x in jokes]

# Set up engine for checking if word is singular 
p = inflect.engine()

for joke in tokenized_jokes:
  # Assume all words are real
  real = True
  # Check to see if any word does not exist
  for w in joke:
    if w not in words:
      # Count any sentence with such words as false
      real = False
  count.append(real)

count = Counter(count)
count

# %% [markdown]
# # Keyword Analysis (Dont Run)

# %%
# Load and detokenize data
#data = np.load("short_jokes.npy", allow_pickle=True)
jokes = np.load("encoded_jokes.npy", allow_pickle=True)
jokes = tokenizer.detokenize(jokes)
jokes = list(jokes.numpy())
data = []

for x in jokes:
  x = [y.decode("utf-8") for y in x]
  x = " ".join([y for y in x if y != '[PAD]'])
  data.append(x)


# Extract keywords
r = Rake(max_length=1)
keywords = []

for x in data:
  kw = r.extract_keywords_from_text(x)
  kw = r.get_ranked_phrases()
  keywords.append(kw)


# Tokenize and encode keywords
keywords_int = tf.ragged.constant(keywords)
keywords_int = tokenizer.tokenize(keywords_int)
# Reshape
keywords_int = keywords_int.merge_dims(-2,-1).to_list()

# Squeeze list
seq_in = []
for x in keywords_int:
  x = [item for sublist in x for item in sublist]
  seq_in.append(x)

# Pad sequences
seq_in = keras.preprocessing.sequence.pad_sequences(seq_in,
                                            value=0,
                                            padding='post',
                                            maxlen=30)

# Prepare the sequences
seq_in = np.insert(seq_in[:,:-1], 0, 2, axis=1)
seq_out = np.load("encoded_jokes.npy", allow_pickle=True)[:, :-1]
seq_out = np.insert(seq_out[:,:-1], 0, 2, axis=1)
seq_lab = np.expand_dims(seq_out[:, 1:],axis=2)
seq_lab = keras.preprocessing.sequence.pad_sequences(seq_lab,
                                            value=0,
                                            padding='post',
                                            maxlen=30)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/ragged/ragged_tensor.py:2053: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(rows)

# %%
# Analyse keywords
corpus = [j for i in keywords for j in i]
keywords_freq_dict = Counter(corpus)
lengths = [len(x) for x in keywords]
kw_length_frequency = Counter(lengths)
plt.bar(kw_length_frequency.keys(), kw_length_frequency.values(), 2, color='g')
kw_length_frequency
# Out:
# Counter({0: 5982,
#          1: 16129,
#          2: 22359,
#          3: 21902,
#          4: 16497,
#          5: 10362,
#          6: 5187,
#          7: 2223,
#          8: 783,
#          9: 231,
#          10: 62,
#          11: 11})

# %%
kw = [item for sublist in keywords for item in sublist]
print("No of keywords:", len(list(set(kw))))

count = Counter(kw)
#unigrams = {k: v for k, v in sorted(count.items(), key=lambda item: item[1], reverse=True)}
bigrams = Counter(ngrams(kw,2))
trigrams = Counter(ngrams(kw,3))
quadgrams = Counter(ngrams(kw,4))
pentgrams = Counter(ngrams(kw,5))
# Create data frames for the frequencies
#unigrams = pd.DataFrame(unigrams.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)
bigrams = pd.DataFrame(bigrams.items(),columns=['pairs','frequency']).sort_values(by='frequency',ascending=False)
trigrams = pd.DataFrame(trigrams.items(),columns=['trigrams','frequency']).sort_values(by='frequency',ascending=False)
quadgrams = pd.DataFrame(quadgrams.items(),columns=['pairs','frequency']).sort_values(by='frequency',ascending=False)
pentgrams = pd.DataFrame(pentgrams.items(),columns=['pairs','frequency']).sort_values(by='frequency',ascending=False)
# create subplot of the different data frames
fig, axes = plt.subplots(2,1,figsize=(8,20))
#sns.barplot(ax=axes[0],x='frequency',y='word',data=unigrams.head(30))
sns.barplot(ax=axes[0],x='frequency',y='pairs',data=bigrams.head(30))
sns.barplot(ax=axes[1],x='frequency',y='trigrams',data=trigrams.head(30))
#sns.barplot(ax=axes[0],x='frequency',y='pairs',data=quadgrams.head(30))
#sns.barplot(ax=axes[1],x='frequency',y='pairs',data=pentgrams.head(30))
# Out:
# No of keywords: 24757

# %%
kw_joined = " ".join(kw)

# Sensoring some explicit words
kw_joined = kw_joined.replace("dick", "dxxk")
kw_joined = kw_joined.replace("ass", "axs")
kw_joined = kw_joined.replace("fuck", "fxxk")

# %%
# Generate word cloud
wordcloud = WordCloud(width = 4000, height = 8000, random_state=1, background_color='white', collocations=False, stopwords = STOPWORDS).generate(kw_joined)

# %%
# Plot word cloud
plt.figure(figsize=(20, 40))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# # Subword/Word Vocab (Dont Run)

# %%
# Create subword vocabulary
bert_tokenizer_params=dict(lower_case=True)
reserved_tokens=["[PAD]", "[UNK]", "[START]", "[END]"]

# Crete the dataset
data = tf.data.Dataset.from_tensor_slices(train)
data = dataset.shuffle(buffer_size=256)

bert_vocab_args = dict(
    # The target vocabulary size
    vocab_size = 10000,
    # Reserved tokens that must be included in the vocabulary
    reserved_tokens=reserved_tokens,
    # Arguments for `text.BertTokenizer`
    bert_tokenizer_params=bert_tokenizer_params,
    # Arguments for `wordpiece_vocab.wordpiece_tokenizer_learner_lib.learn`
    learn_params={},
)

vocab = bert_vocab.bert_vocab_from_dataset(
    data.batch(1000).prefetch(2),
    **bert_vocab_args
)

# %%
print(len(vocab))
# Out:
# 9832

# %%
# Save vocab as a textfile
with open('vocab.txt', 'w') as f:
    for token in vocab:
      print(token, file=f)

# %%
############################### LOAD SAVED SHORT JOKES INSTEAD ###################################
jokes = np.load("short_jokes.npy", allow_pickle=True)
print("No of Jokes:", len(jokes))
print("Samples:",jokes[:10])
# Out:
# No of Jokes: 112260
# Samples: ["how do you end two deaf persons '  arguing ? switch off the light . "
#  'what does a blonde have in common with a hurricane ? first there is a lot of suckin and blowin ,  then you lose your house . '
#  'i went to a white pride parade the other day .  the floats just kept going around in circles about 200 miles per hour . '
#  'i would make a joke about my neighbor .  but it would be too close to home'
#  'what is the difference between god and you ex wife ? god only wants 10 things .  your ex wife wants half of everything . '
#  'i swear ,  i will castrate you do it ,  you won t .  no balls bro . '
#  'the first thing a man notices about a woman is her eyes and when he made sure it is not looking his way , he checks out her tits '
#  'what is your favourite insult joke ? i will get it started 2090 called ,  you are dead and nobody misses you'
#  'trump hows that mexican mall going ? mall ? we thought you said wall trump no way that is harsh ,  also hows that muslim band looking?'
#  'keanu reeves donates so much blood  that anyone who has ever received donor blood is at least 6 keanu reeves . ']

# %%
# Create tokenizer
tokenizer = tensorflow_text.BertTokenizer('vocab.txt', **dict(lower_case=True))
# Get ints
jokes_ints = tokenizer.tokenize(jokes)
# Reshape
jokes_ints = jokes_ints.merge_dims(-2,-1).to_list()

# %%
# Drop jokes with more than 30 tokens
data = [x for x in jokes_ints if len(x) <= 30]

# Pad
data = keras.preprocessing.sequence.pad_sequences(data,
                                            value=0,
                                            padding='post',
                                            maxlen=30+1)

print("No of Samples:", len(data))

# Save encoded and padded jokes
np.save("encoded_jokes.npy", data)
# Out:
# No of Samples: 101728

# %%
def detokenize(indices):
  word_tokens = tokenizer.detokenize([indices]).to_list()
  word_tokens = [x.decode("utf-8") for x in word_tokens[0]]
  return word_tokens
  #return " ".join([x for x in word_tokens if x != '[PAD]'])

# %%
# Detokenize
samples = tokenizer.detokenize(jokes)
samples = list(samples.numpy())
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/ragged/ragged_tensor.py:2053: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(rows)

# %%
# decode and join
corpus = []
for x in samples:
  x = [y.decode("utf-8") for y in x]
  corpus.append([y for y in x if y != '[PAD]'])

# %%
# merge the tokens
corpus = [j for i in corpus for j in i]

# %%
count = Counter(corpus)
unigrams = {k: v for k, v in sorted(count.items(), key=lambda item: item[1], reverse=True)}
bigrams = Counter(ngrams(corpus,2))
trigrams = Counter(ngrams(corpus,3))
quadgrams = Counter(ngrams(corpus,4))
pentgrams = Counter(ngrams(corpus,5))

# %%
# Create data frames for the frequencies
unigrams = pd.DataFrame(unigrams.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)
bigrams = pd.DataFrame(bigrams.items(),columns=['pairs','frequency']).sort_values(by='frequency',ascending=False)
trigrams = pd.DataFrame(trigrams.items(),columns=['trigrams','frequency']).sort_values(by='frequency',ascending=False)
quadgrams = pd.DataFrame(quadgrams.items(),columns=['quadgrams','frequency']).sort_values(by='frequency',ascending=False)
pentgrams = pd.DataFrame(pentgrams.items(),columns=['pentgrams','frequency']).sort_values(by='frequency',ascending=False)

# %%
# create subplot of the different data frames
fig, axes = plt.subplots(4,1,figsize=(8,20))
sns.barplot(ax=axes[0],x='frequency',y='word',data=unigrams.head(30))
sns.barplot(ax=axes[1],x='frequency',y='pairs',data=bigrams.head(30))
sns.barplot(ax=axes[2],x='frequency',y='quadgrams',data=quadgrams.head(30))
sns.barplot(ax=axes[3],x='frequency',y='pentgrams',data=pentgrams.head(30))

# %%
pentgrams.head(50)
# Out:
#                                   pentgrams  frequency
# 536                (what, do, you, call, a)       5007
# 660                (., what, do, you, call)       3695
# 84     (what, is, the, difference, between)       2606
# 519          (., what, is, the, difference)       1345
# 4669      (is, the, difference, between, a)       1287
# 1150           (did, you, hear, about, the)       1281
# 575               (what, do, you, call, an)        716
# 1149             (., did, you, hear, about)        669
# 6021            (have, in, common, ?, they)        548
# 1673             (what, do, you, get, when)        476
# 1674              (do, you, get, when, you)        436
# 1260           (does, it, take, to, change)        431
# 1261              (it, take, to, change, a)        425
# 1207                   (i, don, ', t, know)        379
# 29784             (what, do, you, call, it)        367
# 29785             (do, you, call, it, when)        366
# 11810               (., what, do, you, get)        321
# 3748                      (., i, don, ', t)        312
# 6022            (in, common, ?, they, both)        288
# 794                (?, what, do, you, call)        275
# 6674             (what, do, you, call, the)        275
# 2022            (does, it, take, to, screw)        255
# 4807             (i, like, my, women, like)        244
# 2023              (it, take, to, screw, in)        242
# 2024               (take, to, screw, in, a)        241
# 3107             (walks, into, a, bar, and)        235
# 5797           (you, get, when, you, cross)        233
# 5910       (take, to, change, a, lightbulb)        232
# 5911          (to, change, a, lightbulb, ?)        231
# 4808             (like, my, women, like, i)        224
# 4810             (women, like, i, like, my)        223
# 4809             (my, women, like, i, like)        222
# 5969         (what, do, you, call, someone)        208
# 1391         (knock, knock, who, is, there)        202
# 1263           (to, change, a, light, bulb)        196
# 13112                   (., why, can, ', t)        196
# 1206                      (?, i, don, ', t)        193
# 1264            (change, a, light, bulb, ?)        193
# 1392             (knock, who, is, there, ?)        193
# 1262           (take, to, change, a, light)        186
# 380                     (., why, don, ', t)        181
# 3510             (man, walks, into, a, bar)        180
# 7409               (., what, is, the, best)        176
# 3609        (did, the, chicken, cross, the)        175
# 3608        (why, did, the, chicken, cross)        174
# 11543          (you, hear, about, the, guy)        173
# 6282                (how, do, you, make, a)        167
# 28407             (cross, the, road, ?, to)        165
# 4806                (., i, like, my, women)        163
# 3610       (the, chicken, cross, the, road)        162

# %% [markdown]
# # Dataset Preparation (Archived)

# %%
######################################## DATASET PREPARATION #######################################
jokes = np.load("short_jokes.npy", allow_pickle=True)

idx = int(len(jokes) * 0.9)
train = jokes[:idx]
valid = jokes[idx:]
 
dataset = tf.data.Dataset.from_tensor_slices(train)
dataset = dataset.shuffle(buffer_size=256)
dataset = dataset.batch(batch_size)
 
def custom_standardization(input_string):
    #Remove html line-break tags and handle punctuation
    lowercased = tf.strings.lower(input_string)
    stripped_html = tf.strings.regex_replace(lowercased, "<br />", " ")
    return tf.strings.regex_replace(stripped_html, f"([{string.punctuation}])", r" \1")
 
 
# Create a vectorization layer and adapt it to the text
vectorize_layer = TextVectorization(
    standardize=custom_standardization,
    max_tokens=vocab_size - 1,
    output_mode="int",
    output_sequence_length=maxlen + 1,
)
vectorize_layer.adapt(dataset)
vocab = vectorize_layer.get_vocabulary()  # To get words back from token indices
print(len(vocab))
 
 
def prepare_lm_inputs_labels(text):
    #Shift word sequences by 1 position so that the target for position (i) is
    #word at position (i+1). The model will use all words up till position (i)
    #to predict the next word.

    text = tf.expand_dims(text, -1)
    tokenized_sentences = vectorize_layer(text)
    x = tokenized_sentences[:, :-1]
    y = tokenized_sentences[:, 1:]
    return x, y
 
dataset = dataset.map(prepare_lm_inputs_labels)
dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
 
word_to_index = {}
for index, word in enumerate(vocab):
    word_to_index[word] = index
print(dataset)
# Out:
# 39999
# <PrefetchDataset shapes: ((None, 50), (None, 50)), types: (tf.int64, tf.int64)>

# %%
# Validation Set
valid = tf.data.Dataset.from_tensor_slices(valid)
valid = valid.shuffle(buffer_size=256)
valid = valid.batch(batch_size)
valid = valid.map(prepare_lm_inputs_labels)
valid = valid.prefetch(tf.data.experimental.AUTOTUNE)
print(valid)
# Out:
# <PrefetchDataset shapes: ((None, 50), (None, 50)), types: (tf.int64, tf.int64)>

# %%
for joke in jokes[:10]:
  print(joke)
  print(custom_standardization(joke))
  print(" ")
# Out:
# how do you end two deaf persons' arguing? switch off the light.
# tf.Tensor(b"how do you end two deaf persons ' arguing ? switch off the light .", shape=(), dtype=string)
#
# what does a blonde have in common with a hurricane? first there is a lot of suckin and blowin, then you lose your house.
# tf.Tensor(b'what does a blonde have in common with a hurricane ? first there is a lot of suckin and blowin , then you lose your house .', shape=(), dtype=string)
#
# i went to a white pride parade the other day. the floats just kept going around in circles about 200 miles per hour.
# tf.Tensor(b'i went to a white pride parade the other day . the floats just kept going around in circles about 200 miles per hour .', shape=(), dtype=string)
#
# going to make an app. i have decided to create an app where you tour museums and art galleries finding famous paintings.  i am going to call it van gogh.   source - me
# tf.Tensor(b'going to make an app . i have decided to create an app where you tour museums and art galleries finding famous paintings .  i am going to call it van gogh .   source  - me', shape=(), dtype=string)
#
# i would  make a joke about my neighbor.... but it would be too close to home
# tf.Tensor(b'i would  make a joke about my neighbor . . . . but it would be too close to home', shape=(), dtype=string)
#
# what is the difference between god and you ex-wife? god only wants 10 things.   your ex-wife wants half of everything.
# tf.Tensor(b'what is the difference between god and you ex -wife ? god only wants 10 things .   your ex -wife wants half of everything .', shape=(), dtype=string)
#
# “i swear, i’ll castrate you!!” “do it, you won’t. no balls bro.”
# tf.Tensor(b'\xe2\x80\x9ci swear , i\xe2\x80\x99ll castrate you ! !\xe2\x80\x9d \xe2\x80\x9cdo it , you won\xe2\x80\x99t . no balls bro .\xe2\x80\x9d', shape=(), dtype=string)
#
# the first thing a man notices about a woman is her eyes.. and when he made sure it is  not looking his way,he checks out her tits ..
# tf.Tensor(b'the first thing a man notices about a woman is her eyes . . and when he made sure it is  not looking his way ,he checks out her tits  . .', shape=(), dtype=string)
#
# what is your favourite insult joke? i’ll get it started: 2090 called, you’re dead and nobody misses you
# tf.Tensor(b'what is your favourite insult joke ? i\xe2\x80\x99ll get it started : 2090 called , you\xe2\x80\x99re dead and nobody misses you', shape=(), dtype=string)
#
# trump:   "  hows that mexican mall going?  "     "  mall? we thought you said wall  "    trump:   "  no way that is  harsh, also hows that muslim band looking?  "
# tf.Tensor(b'trump :    "  hows that mexican mall going ?   "      "  mall ? we thought you said wall   "    trump :    "  no way that is  harsh , also hows that muslim band looking ?   "  ', shape=(), dtype=string)

# %% [markdown]
# # Utils (Archived)

# %%
# Generator Callback
class TextGenerator(keras.callbacks.Callback):
    """A callback to generate text from a trained model.
    1. Feed some starting prompt to the model
    2. Predict probabilities for the next token
    3. Sample the next token and add it to the next input

    Arguments:
        max_tokens: Integer, the number of tokens to be generated after prompt.
        start_tokens: List of integers, the token indices for the starting prompt.
        index_to_word: List of strings, obtained from the TextVectorization layer.
        top_k: Integer, sample from the `top_k` token predictions.
        print_every: Integer, print after this many epochs.
    """

    def __init__(
        self, max_tokens, start_tokens, index_to_word, top_k=10, print_every=1
    ):
        self.max_tokens = max_tokens
        self.start_tokens = start_tokens
        self.index_to_word = index_to_word
        self.print_every = print_every
        self.k = top_k

    def sample_from(self, logits):
        logits, indices = tf.math.top_k(logits, k=self.k, sorted=True)
        indices = np.asarray(indices).astype("int32")
        preds = keras.activations.softmax(tf.expand_dims(logits, 0))[0]
        preds = np.asarray(preds).astype("float32")
        return np.random.choice(indices, p=preds)

    def detokenize(self, number):
        return self.index_to_word[number]

    def on_epoch_end(self, epoch, logs=None):
        start_tokens = [_ for _ in self.start_tokens]
        if (epoch + 1) % self.print_every != 0:
            return
        num_tokens_generated = 0
        tokens_generated = []
        while num_tokens_generated <= self.max_tokens:
            pad_len = maxlen - len(start_tokens)
            sample_index = len(start_tokens) - 1
            if pad_len < 0:
                x = start_tokens[:maxlen]
                sample_index = maxlen - 1
            elif pad_len > 0:
                x = start_tokens + [0] * pad_len
            else:
                x = start_tokens
            x = np.array([x])
            y, _ = self.model.predict(x)
            sample_token = self.sample_from(y[0][sample_index])
            tokens_generated.append(sample_token)
            start_tokens.append(sample_token)
            num_tokens_generated = len(tokens_generated)
        txt = " ".join(
            [self.detokenize(_) for _ in self.start_tokens + tokens_generated]
        )
        print(f"generated text:\n{txt}\n")

# %%
####################################### Beam Search Generator ##############################
def generate(model, max_tokens, start_tokens, index_to_word, top_k=5, print_every=1):
        start_tokens = [_ for _ in start_tokens]
        num_tokens_generated = 0
        tokens_generated = []
        while num_tokens_generated <= max_tokens:
            pad_len = maxlen - len(start_tokens)
            sample_index = len(start_tokens) - 1
            if pad_len < 0:
                x = start_tokens[:maxlen]
                sample_index = maxlen - 1
            elif pad_len > 0:
                x = start_tokens + [0] * pad_len
            else:
                x = start_tokens
            x = np.array([x])
            y, _ = model.predict(x)

            logits = y[0][sample_index]
            logits, indices = tf.math.top_k(logits, k=top_k, sorted=True)
            indices = np.asarray(indices).astype("int32")
            preds = keras.activations.softmax(tf.expand_dims(logits, 0))[0]
            preds = np.asarray(preds).astype("float32")
            sample_token = np.random.choice(indices, p=preds)

            tokens_generated.append(sample_token)
            start_tokens.append(sample_token)
            num_tokens_generated = len(tokens_generated)
            txt = " ".join(
            [index_to_word[_] for _ in start_tokens])
        return txt


####################### TEST ################################
def test_model(model):
  samples = []
  samples.append("how do you end two deaf persons")
  samples.append("What does a blonde have in common with a hurricane")
  samples.append("I went to a white pride parade the other day")
  samples.append("Going to make an app")
  samples.append("i would  make a joke about my neighbor")
  samples.append("what is the difference between god and you")

  # Check if model prints the correct sentence, given first 7 tokens
  for i in range(len(samples)):
    start_tokens = [word_to_index.get(_, 1) for _ in samples[i].lower().split()]
    num_tokens_generated = 50
    sample = generate(model, num_tokens_generated, start_tokens, vocab)
    print("TRUE: ", jokes[i])
    print("INPUT: ", samples[i])
    print("GENERATED: ",sample)
    print("")

# %%
start_prompt = "what do you"
start_tokens = [word_to_index.get(_, 1) for _ in start_prompt.lower().split()]
text_gen_callback = TextGenerator(num_tokens_generated, start_tokens, vocab)

# %% [markdown]
# # BiLstm (Archived)

# %%
# Simple BiLSTM
inputs = layers.Input(shape=(maxlen,), dtype=tf.int32)
# Embedding
x = layers.Embedding(vocab_size, 100, input_length=maxlen)(inputs)
# BiLSTM
x = layers.Bidirectional(layers.LSTM(100,return_sequences=True))(x)
# Outputs
outputs = layers.Dense(vocab_size)(x)

# Setup model
model = keras.Model(inputs=inputs, outputs=[outputs, x])
# Loss
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
# Compile
model.compile("adam", loss=[loss_fn, None],)  # No loss and optimization based on word embeddings from transformer block
# Summarize
model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 30)]              0
# _________________________________________________________________
# embedding_9 (Embedding)      (None, 30, 100)           983200
# _________________________________________________________________
# bidirectional_7 (Bidirection (None, 30, 200)           160800
# _________________________________________________________________
# dense_9 (Dense)              (None, 30, 9832)          1976232
# =================================================================
# Total params: 3,120,232
# Trainable params: 3,120,232
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit model
history = model.fit(dataset, epochs=100, validation_data=valid, callbacks=[text_gen_callback])

# Save model
model.save_weights('bilstm.h5')

# Download model
files.download('bilstm.h5')
# Out:
# Epoch 1/100
# 59/59 [==============================] - 16s 231ms/step - loss: 6.4129 - dense_28_loss: 6.4129 - val_loss: 3.6105 - val_dense_28_loss: 3.6105
# generated text:
# how do you end two deaf  is . ,  to                   "  is     . . a .      .
#
# Epoch 2/100
# 59/59 [==============================] - 13s 218ms/step - loss: 3.3789 - dense_28_loss: 3.3789 - val_loss: 3.2621 - val_dense_28_loss: 3.2621
# generated text:
# how do you end two deaf  .           ,                            to
#
# Epoch 3/100
# 59/59 [==============================] - 13s 218ms/step - loss: 2.9527 - dense_28_loss: 2.9527 - val_loss: 2.9872 - val_dense_28_loss: 2.9872
# generated text:
# how do you end two deaf to a you a                      and
#
# Epoch 4/100
# 59/59 [==============================] - 13s 219ms/step - loss: 2.8331 - dense_28_loss: 2.8331 - val_loss: 2.9492 - val_dense_28_loss: 2.9492
# generated text:
# how do you end two deaf a a
#
# Epoch 5/100
# 59/59 [==============================] - 13s 219ms/step - loss: 2.7867 - dense_28_loss: 2.7867 - val_loss: 2.9203 - val_dense_28_loss: 2.9203
# generated text:
# how do you end two deaf to of to is is the the is is to the of ?
#
# Epoch 6/100
# 59/59 [==============================] - 13s 218ms/step - loss: 2.7460 - dense_28_loss: 2.7460 - val_loss: 2.8985 - val_dense_28_loss: 2.8985
# generated text:
# how do you end two deaf the was to a a is the a ? to , . . . . but i i , a the .
#
# Epoch 7/100
# 59/59 [==============================] - 13s 218ms/step - loss: 2.7067 - dense_28_loss: 2.7067 - val_loss: 2.8731 - val_dense_28_loss: 2.8731
# generated text:
# how do you end two deaf the is ? ? .
#
# Epoch 8/100
# 59/59 [==============================] - 13s 216ms/step - loss: 2.6629 - dense_28_loss: 2.6629 - val_loss: 2.8435 - val_dense_28_loss: 2.8435
# generated text:
# how do you end two deaf is to a the ?
#
# Epoch 9/100
# 59/59 [==============================] - 13s 219ms/step - loss: 2.6107 - dense_28_loss: 2.6107 - val_loss: 2.8063 - val_dense_28_loss: 2.8063
# generated text:
# how do you end two deaf ?
#
# Epoch 10/100
# 59/59 [==============================] - 13s 219ms/step - loss: 2.5436 - dense_28_loss: 2.5436 - val_loss: 2.7497 - val_dense_28_loss: 2.7497
# generated text:
# how do you end two deaf ? .
#
# Epoch 11/100
# 59/59 [==============================] - 13s 219ms/step - loss: 2.4563 - dense_28_loss: 2.4563 - val_loss: 2.6635 - val_dense_28_loss: 2.6635
# generated text:
# how do you end two deaf the call of common ? because                                and
#
# Epoch 12/100
# 59/59 [==============================] - 13s 218ms/step - loss: 2.3556 - dense_28_loss: 2.3556 - val_loss: 2.5810 - val_dense_28_loss: 2.5810
# generated text:
# how do you end two deaf when ? because i said .
#
# Epoch 13/100
# 59/59 [==============================] - 13s 218ms/step - loss: 2.2575 - dense_28_loss: 2.2575 - val_loss: 2.5033 - val_dense_28_loss: 2.5033
# generated text:
# how do you end two deaf with say ? he have it on
#
# Epoch 14/100
# 59/59 [==============================] - 13s 219ms/step - loss: 2.1711 - dense_28_loss: 2.1711 - val_loss: 2.4435 - val_dense_28_loss: 2.4435
# generated text:
# how do you end two deaf at . with when it is one . when it is a man . . .
#
# Epoch 15/100
# 59/59 [==============================] - 13s 217ms/step - loss: 2.0945 - dense_28_loss: 2.0945 - val_loss: 2.4024 - val_dense_28_loss: 2.4024
# generated text:
# how do you end two deaf in ?
#
# Epoch 16/100
# 59/59 [==============================] - 13s 218ms/step - loss: 2.0272 - dense_28_loss: 2.0272 - val_loss: 2.3567 - val_dense_28_loss: 2.3567
# generated text:
# how do you end two deaf with common on one on it .
#
# Epoch 17/100
# 59/59 [==============================] - 13s 218ms/step - loss: 1.9646 - dense_28_loss: 1.9646 - val_loss: 2.3201 - val_dense_28_loss: 2.3201
# generated text:
# how do you end two deaf when do it doesn call out .
#
# Epoch 18/100
# 59/59 [==============================] - 13s 218ms/step - loss: 1.9031 - dense_28_loss: 1.9031 - val_loss: 2.2860 - val_dense_28_loss: 2.2860
# generated text:
# how do you end two deaf who people when it can have get up when it have them .
#
# Epoch 19/100
# 59/59 [==============================] - 13s 221ms/step - loss: 1.8380 - dense_28_loss: 1.8380 - val_loss: 2.2321 - val_dense_28_loss: 2.2321
# generated text:
# how do you end two deaf people in it ? because it is
#
# Epoch 20/100
# 59/59 [==============================] - 13s 218ms/step - loss: 1.7661 - dense_28_loss: 1.7661 - val_loss: 2.1809 - val_dense_28_loss: 2.1809
# generated text:
# how do you end two deaf . people have it like it when what it do if it doesn 't want like it . if it can get when it doesn do it .
#
# Epoch 21/100
# 59/59 [==============================] - 13s 219ms/step - loss: 1.6926 - dense_28_loss: 1.6926 - val_loss: 2.1366 - val_dense_28_loss: 2.1366
# generated text:
# how do you end two deaf at women because it doesn take have when if it . .
#
# Epoch 22/100
# 59/59 [==============================] - 13s 219ms/step - loss: 1.6226 - dense_28_loss: 1.6226 - val_loss: 2.0877 - val_dense_28_loss: 2.0877
# generated text:
# how do you end two deaf people who have on people up when if people have have common on when when it had up on it .
#
# Epoch 23/100
# 59/59 [==============================] - 13s 219ms/step - loss: 1.5583 - dense_28_loss: 1.5583 - val_loss: 2.0427 - val_dense_28_loss: 2.0427
# generated text:
# how do you end two deaf people when do it have have when it doesn 't like it .
#
# Epoch 24/100
# 59/59 [==============================] - 13s 218ms/step - loss: 1.4986 - dense_28_loss: 1.4986 - val_loss: 2.0099 - val_dense_28_loss: 2.0099
# generated text:
# how do you end two deaf people with get at it ?
#
# Epoch 25/100
# 59/59 [==============================] - 13s 218ms/step - loss: 1.4430 - dense_28_loss: 1.4430 - val_loss: 1.9725 - val_dense_28_loss: 1.9725
# generated text:
# how do you end two deaf ? because it can 't call him it
#
# Epoch 26/100
# 59/59 [==============================] - 13s 218ms/step - loss: 1.3893 - dense_28_loss: 1.3893 - val_loss: 1.9447 - val_dense_28_loss: 1.9447
# generated text:
# how do you end two deaf people that take on with it it in it called it .
#
# Epoch 27/100
# 59/59 [==============================] - 13s 219ms/step - loss: 1.3382 - dense_28_loss: 1.3382 - val_loss: 1.9186 - val_dense_28_loss: 1.9186
# generated text:
# how do you end two deaf people in common with people all in it ? in in it .
#
# Epoch 28/100
# 59/59 [==============================] - 13s 220ms/step - loss: 1.2898 - dense_28_loss: 1.2898 - val_loss: 1.8888 - val_dense_28_loss: 1.8888
# generated text:
# how do you end two deaf with women on it ? it had in
#
# Epoch 29/100
# 59/59 [==============================] - 13s 219ms/step - loss: 1.2439 - dense_28_loss: 1.2439 - val_loss: 1.8657 - val_dense_28_loss: 1.8657
# generated text:
# how do you end two deaf than it on sex ? they can 't like it ?
#
# Epoch 30/100
# 59/59 [==============================] - 13s 218ms/step - loss: 1.1974 - dense_28_loss: 1.1974 - val_loss: 1.8420 - val_dense_28_loss: 1.8420
# generated text:
# how do you end two deaf lawyers than it take in in common after at it in common ? it is all on all it ,
#
# Epoch 31/100
# 59/59 [==============================] - 13s 218ms/step - loss: 1.1527 - dense_28_loss: 1.1527 - val_loss: 1.8197 - val_dense_28_loss: 1.8197
# generated text:
# how do you end two deaf women in women ? if if all it becomes called at it in the other
#
# Epoch 32/100
# 59/59 [==============================] - 13s 219ms/step - loss: 1.1106 - dense_28_loss: 1.1106 - val_loss: 1.7991 - val_dense_28_loss: 1.7991
# generated text:
# how do you end two deaf people with it ? it take off
#
# Epoch 33/100
# 59/59 [==============================] - 13s 220ms/step - loss: 1.0689 - dense_28_loss: 1.0689 - val_loss: 1.7839 - val_dense_28_loss: 1.7839
# generated text:
# how do you end two deaf country with women ? all
#
# Epoch 34/100
# 59/59 [==============================] - 13s 218ms/step - loss: 1.0261 - dense_28_loss: 1.0261 - val_loss: 1.7623 - val_dense_28_loss: 1.7623
# generated text:
# how do you end two deaf with people from all than all men all at it is in china in all it makes all all long at all men at it all long ?
#
# Epoch 35/100
# 59/59 [==============================] - 13s 220ms/step - loss: 0.9835 - dense_28_loss: 0.9835 - val_loss: 1.7429 - val_dense_28_loss: 1.7429
# generated text:
# how do you end two deaf women hitler use use with christmas ?
#
# Epoch 36/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.9435 - dense_28_loss: 0.9435 - val_loss: 1.7237 - val_dense_28_loss: 1.7237
# generated text:
# how do you end two deaf lawyers with women as it take in it ? that gets at once
#
# Epoch 37/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.9044 - dense_28_loss: 0.9044 - val_loss: 1.7115 - val_dense_28_loss: 1.7115
# generated text:
# how do you end two deaf men at kids with kids with all children all children at trump ? if if it gets getting up into
#
# Epoch 38/100
# 59/59 [==============================] - 13s 220ms/step - loss: 0.8665 - dense_28_loss: 0.8665 - val_loss: 1.6937 - val_dense_28_loss: 1.6937
# generated text:
# how do you end two deaf women women eat people in jesus ? all all chicken on all
#
# Epoch 39/100
# 59/59 [==============================] - 13s 220ms/step - loss: 0.8285 - dense_28_loss: 0.8285 - val_loss: 1.6721 - val_dense_28_loss: 1.6721
# generated text:
# how do you end two deaf lawyers girls play on women play lawyers at china at it ? at it had it had all into all
#
# Epoch 40/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.7920 - dense_28_loss: 0.7920 - val_loss: 1.6545 - val_dense_28_loss: 1.6545
# generated text:
# how do you end two deaf girls all girls on with hitler all kids ? hitler has all 7 at 7
#
# Epoch 41/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.7556 - dense_28_loss: 0.7556 - val_loss: 1.6364 - val_dense_28_loss: 1.6364
# generated text:
# how do you end two deaf women brown cows from women hitler all ? minnesota
#
# Epoch 42/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.7197 - dense_28_loss: 0.7197 - val_loss: 1.6160 - val_dense_28_loss: 1.6160
# generated text:
# how do you end two deaf girls at hitler change all ? donald jews have jews all
#
# Epoch 43/100
# 59/59 [==============================] - 13s 221ms/step - loss: 0.6857 - dense_28_loss: 0.6857 - val_loss: 1.5968 - val_dense_28_loss: 1.5968
# generated text:
# how do you end two deaf men brown all kids at paper ? guys guys open it over
#
# Epoch 44/100
# 59/59 [==============================] - 13s 220ms/step - loss: 0.6523 - dense_28_loss: 0.6523 - val_loss: 1.5834 - val_dense_28_loss: 1.5834
# generated text:
# how do you end two deaf lawyers girls at russia on china ?
#
# Epoch 45/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.6205 - dense_28_loss: 0.6205 - val_loss: 1.5660 - val_dense_28_loss: 1.5660
# generated text:
# how do you end two deaf women people all hitler open
#
# Epoch 46/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.5886 - dense_28_loss: 0.5886 - val_loss: 1.5513 - val_dense_28_loss: 1.5513
# generated text:
# how do you end two deaf lawyers brown at women at russia ? clowns open into asians
#
# Epoch 47/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.5572 - dense_28_loss: 0.5572 - val_loss: 1.5340 - val_dense_28_loss: 1.5340
# generated text:
# how do you end two deaf lawyers brown girls from jesus at least russia drop that hits that once leaves ?
#
# Epoch 48/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.5274 - dense_28_loss: 0.5274 - val_loss: 1.5134 - val_dense_28_loss: 1.5134
# generated text:
# how do you end two deaf lawyers kids at paper at paper at america ? cry all men once open
#
# Epoch 49/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.4988 - dense_28_loss: 0.4988 - val_loss: 1.4965 - val_dense_28_loss: 1.4965
# generated text:
# how do you end two deaf women brown
#
# Epoch 50/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.4720 - dense_28_loss: 0.4720 - val_loss: 1.4816 - val_dense_28_loss: 1.4816
# generated text:
# how do you end two deaf lawyers lawyers at christmas christmas christmas that china gets fire it coming at america
#
# Epoch 51/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.4451 - dense_28_loss: 0.4451 - val_loss: 1.4676 - val_dense_28_loss: 1.4676
# generated text:
# how do you end two deaf brown cows brown  cows
#
# Epoch 52/100
# 59/59 [==============================] - 13s 216ms/step - loss: 0.4190 - dense_28_loss: 0.4190 - val_loss: 1.4564 - val_dense_28_loss: 1.4564
# generated text:
# how do you end two deaf lawyers girls cows brown at lawyers at lawyers at top
#
# Epoch 53/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.3949 - dense_28_loss: 0.3949 - val_loss: 1.4422 - val_dense_28_loss: 1.4422
# generated text:
# how do you end two deaf girls at 2016 guys hitler park at hitler stay bottom at lawyers at it
#
# Epoch 54/100
# 59/59 [==============================] - 13s 220ms/step - loss: 0.3714 - dense_28_loss: 0.3714 - val_loss: 1.4275 - val_dense_28_loss: 1.4275
# generated text:
# how do you end two deaf lawyers brown at jesus at america cry free  it first morning at 2016 chicken
#
# Epoch 55/100
# 59/59 [==============================] - 13s 217ms/step - loss: 0.3490 - dense_28_loss: 0.3490 - val_loss: 1.4151 - val_dense_28_loss: 1.4151
# generated text:
# how do you end two deaf lawyers at cheese hitler once once coming
#
# Epoch 56/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.3283 - dense_28_loss: 0.3283 - val_loss: 1.4045 - val_dense_28_loss: 1.4045
# generated text:
# how do you end two deaf country cheese ?
#
# Epoch 57/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.3093 - dense_28_loss: 0.3093 - val_loss: 1.3908 - val_dense_28_loss: 1.3908
# generated text:
# how do you end two deaf brown girls girls
#
# Epoch 58/100
# 59/59 [==============================] - 13s 221ms/step - loss: 0.2916 - dense_28_loss: 0.2916 - val_loss: 1.3743 - val_dense_28_loss: 1.3743
# generated text:
# how do you end two deaf lawyers lawyers at 2016 hitler hitler may stay bottom ? hitler
#
# Epoch 59/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.2743 - dense_28_loss: 0.2743 - val_loss: 1.3631 - val_dense_28_loss: 1.3631
# generated text:
# how do you end two deaf lawyers lawyers guys hitler cry lawyers bottom  ? wise 2016
#
# Epoch 60/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.2575 - dense_28_loss: 0.2575 - val_loss: 1.3582 - val_dense_28_loss: 1.3582
# generated text:
# how do you end two deaf lawyers at 2016 hitler swing hitler
#
# Epoch 61/100
# 59/59 [==============================] - 13s 217ms/step - loss: 0.2411 - dense_28_loss: 0.2411 - val_loss: 1.3483 - val_dense_28_loss: 1.3483
# generated text:
# how do you end two deaf lawyers brown
#
# Epoch 62/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.2262 - dense_28_loss: 0.2262 - val_loss: 1.3345 - val_dense_28_loss: 1.3345
# generated text:
# how do you end two deaf lawyers girls only jesus lawyers ? donald china
#
# Epoch 63/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.2120 - dense_28_loss: 0.2120 - val_loss: 1.3270 - val_dense_28_loss: 1.3270
# generated text:
# how do you end two deaf lawyers lawyers in 2016 cheese cry in mexico
#
# Epoch 64/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.1987 - dense_28_loss: 0.1987 - val_loss: 1.3217 - val_dense_28_loss: 1.3217
# generated text:
# how do you end two deaf country lawyers
#
# Epoch 65/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.1863 - dense_28_loss: 0.1863 - val_loss: 1.3135 - val_dense_28_loss: 1.3135
# generated text:
# how do you end two deaf lawyers lawyers lawyers at 2016 jesus hitler hitler cry ?
#
# Epoch 66/100
# 59/59 [==============================] - 13s 217ms/step - loss: 0.1749 - dense_28_loss: 0.1749 - val_loss: 1.3051 - val_dense_28_loss: 1.3051
# generated text:
# how do you end two deaf lawyers guys hitler hitler eat lawyers
#
# Epoch 67/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.1642 - dense_28_loss: 0.1642 - val_loss: 1.2965 - val_dense_28_loss: 1.2965
# generated text:
# how do you end two deaf lawyers lawyers lawyers standing off semen post lawyers ? hitler leaves
#
# Epoch 68/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.1539 - dense_28_loss: 0.1539 - val_loss: 1.2896 - val_dense_28_loss: 1.2896
# generated text:
# how do you end two deaf women lawyers brown girls others jesus ? hitler called jesus
#
# Epoch 69/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.1445 - dense_28_loss: 0.1445 - val_loss: 1.2827 - val_dense_28_loss: 1.2827
# generated text:
# how do you end two deaf girls girls
#
# Epoch 70/100
# 59/59 [==============================] - 13s 217ms/step - loss: 0.1353 - dense_28_loss: 0.1353 - val_loss: 1.2751 - val_dense_28_loss: 1.2751
# generated text:
# how do you end two deaf lawyers  lawyers
#
# Epoch 71/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.1270 - dense_28_loss: 0.1270 - val_loss: 1.2671 - val_dense_28_loss: 1.2671
# generated text:
# how do you end two deaf lawyers hitler girls lawyers at lawyers off
#
# Epoch 72/100
# 59/59 [==============================] - 13s 217ms/step - loss: 0.1195 - dense_28_loss: 0.1195 - val_loss: 1.2594 - val_dense_28_loss: 1.2594
# generated text:
# how do you end two deaf money hitler
#
# Epoch 73/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.1121 - dense_28_loss: 0.1121 - val_loss: 1.2539 - val_dense_28_loss: 1.2539
# generated text:
# how do you end two deaf lawyers guys ring lawyers
#
# Epoch 74/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.1051 - dense_28_loss: 0.1051 - val_loss: 1.2479 - val_dense_28_loss: 1.2479
# generated text:
# how do you end two deaf lawyers girls girls  hitler guys at mexico
#
# Epoch 75/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.0985 - dense_28_loss: 0.0985 - val_loss: 1.2403 - val_dense_28_loss: 1.2403
# generated text:
# how do you end two deaf lawyers lawyers lawyers guys in mexico jesus leaves
#
# Epoch 76/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.0924 - dense_28_loss: 0.0924 - val_loss: 1.2367 - val_dense_28_loss: 1.2367
# generated text:
# how do you end two deaf cheese lawyers lawyers ring in cheese hitler
#
# Epoch 77/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.0868 - dense_28_loss: 0.0868 - val_loss: 1.2321 - val_dense_28_loss: 1.2321
# generated text:
# how do you end two deaf lawyers lawyers hitler at cheese
#
# Epoch 78/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.0816 - dense_28_loss: 0.0816 - val_loss: 1.2261 - val_dense_28_loss: 1.2261
# generated text:
# how do you end two deaf lawyers lawyers lawyers lawyers ring at cheese beach
#
# Epoch 79/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.0767 - dense_28_loss: 0.0767 - val_loss: 1.2208 - val_dense_28_loss: 1.2208
# generated text:
# how do you end two deaf lawyers lawyers lawyers lawyers at china
#
# Epoch 80/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.0722 - dense_28_loss: 0.0722 - val_loss: 1.2164 - val_dense_28_loss: 1.2164
# generated text:
# how do you end two deaf cheese at lawyers lawyers ? roast
#
# Epoch 81/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.0679 - dense_28_loss: 0.0679 - val_loss: 1.2118 - val_dense_28_loss: 1.2118
# generated text:
# how do you end two deaf ring lawyers lawyers lawyers lawyers
#
# Epoch 82/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.0642 - dense_28_loss: 0.0642 - val_loss: 1.2071 - val_dense_28_loss: 1.2071
# generated text:
# how do you end two deaf lawyers lawyers brown
#
# Epoch 83/100
# 59/59 [==============================] - 13s 221ms/step - loss: 0.0605 - dense_28_loss: 0.0605 - val_loss: 1.2035 - val_dense_28_loss: 1.2035
# generated text:
# how do you end two deaf girls
#
# Epoch 84/100
# 59/59 [==============================] - 13s 217ms/step - loss: 0.0570 - dense_28_loss: 0.0570 - val_loss: 1.2013 - val_dense_28_loss: 1.2013
# generated text:
# how do you end two deaf lawyers lawyers ring
#
# Epoch 85/100
# 59/59 [==============================] - 13s 221ms/step - loss: 0.0538 - dense_28_loss: 0.0538 - val_loss: 1.1965 - val_dense_28_loss: 1.1965
# generated text:
# how do you end two deaf lawyers lawyers brown hitler
#
# Epoch 86/100
# 59/59 [==============================] - 13s 220ms/step - loss: 0.0509 - dense_28_loss: 0.0509 - val_loss: 1.1929 - val_dense_28_loss: 1.1929
# generated text:
# how do you end two deaf lawyers lawyers brown at 2016
#
# Epoch 87/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.0481 - dense_28_loss: 0.0481 - val_loss: 1.1900 - val_dense_28_loss: 1.1900
# generated text:
# how do you end two deaf lawyers lawyers at 2016 hitler hitler only
#
# Epoch 88/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.0454 - dense_28_loss: 0.0454 - val_loss: 1.1857 - val_dense_28_loss: 1.1857
# generated text:
# how do you end two deaf lawyers lawyers brown
#
# Epoch 89/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.0430 - dense_28_loss: 0.0430 - val_loss: 1.1801 - val_dense_28_loss: 1.1801
# generated text:
# how do you end two deaf lawyers lawyers lawyers
#
# Epoch 90/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.0407 - dense_28_loss: 0.0407 - val_loss: 1.1763 - val_dense_28_loss: 1.1763
# generated text:
# how do you end two deaf lawyers lawyers
#
# Epoch 91/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.0386 - dense_28_loss: 0.0386 - val_loss: 1.1714 - val_dense_28_loss: 1.1714
# generated text:
# how do you end two deaf lawyers lawyers lawyers lawyers off china ?
#
# Epoch 92/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.0365 - dense_28_loss: 0.0365 - val_loss: 1.1695 - val_dense_28_loss: 1.1695
# generated text:
# how do you end two deaf  lawyers girls
#
# Epoch 93/100
# 59/59 [==============================] - 13s 217ms/step - loss: 0.0347 - dense_28_loss: 0.0347 - val_loss: 1.1665 - val_dense_28_loss: 1.1665
# generated text:
# how do you end two deaf lawyers brown lawyers
#
# Epoch 94/100
# 59/59 [==============================] - 13s 220ms/step - loss: 0.0328 - dense_28_loss: 0.0328 - val_loss: 1.1659 - val_dense_28_loss: 1.1659
# generated text:
# how do you end two deaf lawyers at lawyers
#
# Epoch 95/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.0311 - dense_28_loss: 0.0311 - val_loss: 1.1622 - val_dense_28_loss: 1.1622
# generated text:
# how do you end two deaf lawyers brown that lawyers laundry
#
# Epoch 96/100
# 59/59 [==============================] - 13s 218ms/step - loss: 0.0294 - dense_28_loss: 0.0294 - val_loss: 1.1604 - val_dense_28_loss: 1.1604
# generated text:
# how do you end two deaf lawyers brown to lawyers
#
# Epoch 97/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.0279 - dense_28_loss: 0.0279 - val_loss: 1.1574 - val_dense_28_loss: 1.1574
# generated text:
# how do you end two deaf lawyers brown to cheese
#
# Epoch 98/100
# 59/59 [==============================] - 13s 219ms/step - loss: 0.0265 - dense_28_loss: 0.0265 - val_loss: 1.1548 - val_dense_28_loss: 1.1548
# generated text:
# how do you end two deaf lawyers lawyers lawyers
#
# Epoch 99/100
# 59/59 [==============================] - 13s 217ms/step - loss: 0.0252 - dense_28_loss: 0.0252 - val_loss: 1.1525 - val_dense_28_loss: 1.1525
# generated text:
# how do you end two deaf lawyers at lawyers
#
# Epoch 100/100
# 59/59 [==============================] - 13s 216ms/step - loss: 0.0240 - dense_28_loss: 0.0240 - val_loss: 1.1508 - val_dense_28_loss: 1.1508
# generated text:
# how do you end two deaf cheese lawyers

# %%
# Plot History
history_dict = history.history
plt.plot(range(1,epochs+1), history_dict['loss'], 'r', label='Training loss')
plt.plot(range(1,epochs+1), history_dict['val_loss'], 'g', label='Validation loss')
plt.title('BiLSTM Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Test
model.load_weights('bilstm.h5')
test_model(model)
# Out:
# TRUE:  How do you end two deaf persons' arguing? Switch off the light.
# INPUT:  how do you end two deaf persons
# GENERATED:  how do you end two deaf persons lawyers
#
# TRUE:  What does a blonde have in common with a hurricane? First there’s a lot of suckin and blowin, then you lose your house.
# INPUT:  What does a blonde have in common with a hurricane
# GENERATED:  what does a blonde have in common with a hurricane
#
# TRUE:  I went to a white pride parade the other day. The floats just kept going around in circles about 200 miles per hour.
# INPUT:  I went to a white pride parade the other day
# GENERATED:  i went to a white pride parade the other day
#
# TRUE:  Going to make an app. I've decided to create an app where you tour museums and art galleries finding famous paintings.  I'm going to call it Van Gogh.   Source - Me
# INPUT:  Going to make an app
# GENERATED:  going to make an app teacher teacher called me to post
#
# TRUE:  I'd make a joke about my neighbor.... But it would be too close to home
# INPUT:  i would  make a joke about my neighbor
# GENERATED:  i would make a joke about my neighbor teacher
#
# TRUE:  What is the difference between God and you Ex-wife? God only wants 10 things.   Your ex-wife wants half of everything.
# INPUT:  what is the difference between god and you
# GENERATED:  what is the difference between god and you smells beer nuts at china post gets only sad

# %% [markdown]
# # Seq2Seq

# %%
class AttentionLayer(Layer):
  def compute_mask(self, inputs, mask=None):
    if mask == None:
      return None
    return mask[1]

  def compute_output_shape(self, input_shape):
    return (input_shape[1][0],input_shape[1][1],input_shape[1][2]*2)


  def call(self, inputs, mask=None):
    encoder_outputs, decoder_outputs = inputs

    # transpose the dimensions of decoder outputs
    decoder_outputs_t = K.permute_dimensions(decoder_outputs, (0,2,1))

    # calculate luong score
    luong_score = K.batch_dot(encoder_outputs,decoder_outputs_t)
    luong_score = K.softmax(luong_score, axis=1) # along the 2nd axis

    # expand the dimensions of luong score and encoded outputs to enable multiplication
    luong_score = K.expand_dims(luong_score, axis=-1) # along last axis
    encoder_outputs = K.expand_dims(encoder_outputs, axis=2) # along 2nd axis

    # get encoded vector
    encoder_vector = encoder_outputs * luong_score
    encoder_vector = K.sum(encoder_vector, axis=1, keepdims=False)

    # [batch,max_dec,2*emb]
    new_decoder_outputs = K.concatenate([decoder_outputs, encoder_vector])

    return new_decoder_outputs

    @classmethod
    def from_config(cls, config):
        return cls(**config)

# %%
latent_dim = 300
embedding_dim = 200
max_text_len = maxlen

# Encoder
encoder_inputs = Input(shape=(11, ))

# Embedding layer
enc_emb = Embedding(vocab_size, embedding_dim,
                    trainable=True)(encoder_inputs)

# Encoder LSTM
encoder_lstm3 = LSTM(latent_dim, return_state=True,
                     return_sequences=True, dropout=0.4,
                     recurrent_dropout=0.0)
(encoder_outputs, state_h, state_c) = encoder_lstm3(enc_emb)

# Set up the decoder, using encoder_states as the initial state
decoder_inputs = Input(shape=(None, ))

# Embedding layer
dec_emb_layer = Embedding(vocab_size, embedding_dim, trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

# Decoder LSTM
decoder_lstm = LSTM(latent_dim, return_sequences=True,
                    return_state=True, dropout=0.4,
                    recurrent_dropout=0.0)
(decoder_outputs, decoder_fwd_state, decoder_back_state) = \
    decoder_lstm(dec_emb, initial_state=[state_h, state_c])

# Attention
decoder_attention = AttentionLayer()
decoder_outputs = decoder_attention([encoder_outputs,decoder_outputs])

# Dense layer
decoder_dense = TimeDistributed(Dense(vocab_size, activation='softmax'))
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 11)]         0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 11, 200)      1966400     input_3[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 11, 300), (N 601200      embedding_2[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, None, 200)    1966400     input_4[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 300),  601200      embedding_3[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer_1 (AttentionLay (None, None, 600)    0           lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, None, 9832)   5909032     attention_layer_1[0][0]
# ==================================================================================================
# Total params: 11,044,232
# Trainable params: 11,044,232
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Compile and Fit model
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
es = EarlyStopping(monitor='val_loss', mode='min', patience=50)

epochs = 100
history = model.fit([seq_in,seq_out],
                   seq_lab,
                   batch_size=batch_size,
                   validation_split=0.1,
                   epochs=epochs,
                   callbacks=[es])
# Out:
# Epoch 1/100
# 716/716 [==============================] - 65s 63ms/step - loss: 4.0602 - val_loss: 3.2072
# Epoch 2/100
# 716/716 [==============================] - 44s 62ms/step - loss: 3.1335 - val_loss: 2.9952
# Epoch 3/100
# 716/716 [==============================] - 44s 62ms/step - loss: 2.9060 - val_loss: 2.8442
# Epoch 4/100
# 716/716 [==============================] - 44s 62ms/step - loss: 2.7620 - val_loss: 2.7428
# Epoch 5/100
# 716/716 [==============================] - 44s 62ms/step - loss: 2.6357 - val_loss: 2.6612
# Epoch 6/100
# 716/716 [==============================] - 44s 61ms/step - loss: 2.5440 - val_loss: 2.5984
# Epoch 7/100
# 716/716 [==============================] - 44s 62ms/step - loss: 2.4587 - val_loss: 2.5473
# Epoch 8/100
# 716/716 [==============================] - 44s 62ms/step - loss: 2.3946 - val_loss: 2.5093
# Epoch 9/100
# 716/716 [==============================] - 44s 62ms/step - loss: 2.3369 - val_loss: 2.4726
# Epoch 10/100
# 716/716 [==============================] - 44s 62ms/step - loss: 2.2885 - val_loss: 2.4455
# Epoch 11/100
# 716/716 [==============================] - 44s 62ms/step - loss: 2.2463 - val_loss: 2.4232
# Epoch 12/100
# 716/716 [==============================] - 44s 62ms/step - loss: 2.1980 - val_loss: 2.4018
# Epoch 13/100
# 716/716 [==============================] - 44s 62ms/step - loss: 2.1720 - val_loss: 2.3841
# Epoch 14/100
# 716/716 [==============================] - 44s 62ms/step - loss: 2.1284 - val_loss: 2.3676
# Epoch 15/100
# 716/716 [==============================] - 44s 62ms/step - loss: 2.1100 - val_loss: 2.3560
# Epoch 16/100
# 716/716 [==============================] - 44s 61ms/step - loss: 2.0822 - val_loss: 2.3444
# Epoch 17/100
# 716/716 [==============================] - 44s 62ms/step - loss: 2.0620 - val_loss: 2.3352
# Epoch 18/100
# 716/716 [==============================] - 44s 61ms/step - loss: 2.0395 - val_loss: 2.3257
# Epoch 19/100
# 716/716 [==============================] - 44s 62ms/step - loss: 2.0239 - val_loss: 2.3175
# Epoch 20/100
# 716/716 [==============================] - 44s 61ms/step - loss: 2.0006 - val_loss: 2.3116
# Epoch 21/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.9843 - val_loss: 2.3038
# Epoch 22/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.9744 - val_loss: 2.2993
# Epoch 23/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.9552 - val_loss: 2.2920
# Epoch 24/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.9375 - val_loss: 2.2874
# Epoch 25/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.9314 - val_loss: 2.2841
# Epoch 26/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.9179 - val_loss: 2.2789
# Epoch 27/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.9007 - val_loss: 2.2755
# Epoch 28/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.8918 - val_loss: 2.2725
# Epoch 29/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.8872 - val_loss: 2.2697
# Epoch 30/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.8760 - val_loss: 2.2644
# Epoch 31/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.8683 - val_loss: 2.2625
# Epoch 32/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.8670 - val_loss: 2.2586
# Epoch 33/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.8494 - val_loss: 2.2568
# Epoch 34/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.8442 - val_loss: 2.2548
# Epoch 35/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.8287 - val_loss: 2.2542
# Epoch 36/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.8312 - val_loss: 2.2526
# Epoch 37/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.8181 - val_loss: 2.2435
# Epoch 38/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.8117 - val_loss: 2.2462
# Epoch 39/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.8117 - val_loss: 2.2445
# Epoch 40/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.8020 - val_loss: 2.2437
# Epoch 41/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.7959 - val_loss: 2.2407
# Epoch 42/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.7964 - val_loss: 2.2427
# Epoch 43/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.7803 - val_loss: 2.2412
# Epoch 44/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.7757 - val_loss: 2.2367
# Epoch 45/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.7703 - val_loss: 2.2388
# Epoch 46/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.7711 - val_loss: 2.2367
# Epoch 47/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.7689 - val_loss: 2.2367
# Epoch 48/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.7550 - val_loss: 2.2340
# Epoch 49/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.7529 - val_loss: 2.2295
# Epoch 50/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.7537 - val_loss: 2.2335
# Epoch 51/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.7513 - val_loss: 2.2350
# Epoch 52/100
# 716/716 [==============================] - 45s 63ms/step - loss: 1.7427 - val_loss: 2.2310
# Epoch 53/100
# 716/716 [==============================] - 45s 63ms/step - loss: 1.7368 - val_loss: 2.2296
# Epoch 54/100
# 716/716 [==============================] - 45s 63ms/step - loss: 1.7328 - val_loss: 2.2315
# Epoch 55/100
# 716/716 [==============================] - 45s 63ms/step - loss: 1.7278 - val_loss: 2.2251
# Epoch 56/100
# 716/716 [==============================] - 45s 63ms/step - loss: 1.7314 - val_loss: 2.2247
# Epoch 57/100
# 716/716 [==============================] - 45s 63ms/step - loss: 1.7243 - val_loss: 2.2260
# Epoch 58/100
# 716/716 [==============================] - 45s 63ms/step - loss: 1.7225 - val_loss: 2.2212
# Epoch 59/100
# 716/716 [==============================] - 45s 63ms/step - loss: 1.7172 - val_loss: 2.2217
# Epoch 60/100
# 716/716 [==============================] - 45s 63ms/step - loss: 1.7122 - val_loss: 2.2212
# Epoch 61/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.7180 - val_loss: 2.2199
# Epoch 62/100
# 716/716 [==============================] - 44s 61ms/step - loss: 1.7066 - val_loss: 2.2215
# Epoch 63/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.7051 - val_loss: 2.2204
# Epoch 64/100
# 716/716 [==============================] - 45s 62ms/step - loss: 1.7045 - val_loss: 2.2268
# Epoch 65/100
# 716/716 [==============================] - 45s 62ms/step - loss: 1.7012 - val_loss: 2.2187
# Epoch 66/100
# 716/716 [==============================] - 45s 62ms/step - loss: 1.7106 - val_loss: 2.2206
# Epoch 67/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.6981 - val_loss: 2.2226
# Epoch 68/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.6942 - val_loss: 2.2203
# Epoch 69/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.6954 - val_loss: 2.2227
# Epoch 70/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.6893 - val_loss: 2.2215
# Epoch 71/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.6907 - val_loss: 2.2172
# Epoch 72/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.6904 - val_loss: 2.2169
# Epoch 73/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.6845 - val_loss: 2.2165
# Epoch 74/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.6815 - val_loss: 2.2183
# Epoch 75/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.6816 - val_loss: 2.2212
# Epoch 76/100
# 716/716 [==============================] - 45s 62ms/step - loss: 1.6870 - val_loss: 2.2181
# Epoch 77/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.6775 - val_loss: 2.2182
# Epoch 78/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.6733 - val_loss: 2.2178
# Epoch 79/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.6731 - val_loss: 2.2164
# Epoch 80/100
# 716/716 [==============================] - 44s 62ms/step - loss: 1.6649 - val_loss: 2.2137
# Epoch 81/100
# 716/716 [==============================] - 45s 63ms/step - loss: 1.6619 - val_loss: 2.2165
# Epoch 82/100
# 716/716 [==============================] - 46s 64ms/step - loss: 1.6668 - val_loss: 2.2138
# Epoch 83/100
# 716/716 [==============================] - 46s 64ms/step - loss: 1.6623 - val_loss: 2.2127
# Epoch 84/100
# 716/716 [==============================] - 46s 64ms/step - loss: 1.6579 - val_loss: 2.2157
# Epoch 85/100
# 716/716 [==============================] - 46s 64ms/step - loss: 1.6556 - val_loss: 2.2169
# Epoch 86/100
# 716/716 [==============================] - 46s 64ms/step - loss: 1.6515 - val_loss: 2.2146
# Epoch 87/100
# 716/716 [==============================] - 46s 64ms/step - loss: 1.6531 - val_loss: 2.2139
# Epoch 88/100
# 716/716 [==============================] - 46s 64ms/step - loss: 1.6571 - val_loss: 2.2134
# Epoch 89/100
# 716/716 [==============================] - 46s 64ms/step - loss: 1.6555 - val_loss: 2.2126
# Epoch 90/100
# 716/716 [==============================] - 46s 64ms/step - loss: 1.6483 - val_loss: 2.2124
# Epoch 91/100
# 716/716 [==============================] - 46s 64ms/step - loss: 1.6462 - val_loss: 2.2118
# Epoch 92/100
# 716/716 [==============================] - 46s 64ms/step - loss: 1.6436 - val_loss: 2.2093
# Epoch 93/100
# 716/716 [==============================] - 46s 64ms/step - loss: 1.6410 - val_loss: 2.2141
# Epoch 94/100
# 716/716 [==============================] - 46s 64ms/step - loss: 1.6379 - val_loss: 2.2183
# Epoch 95/100
# 716/716 [==============================] - 46s 64ms/step - loss: 1.6401 - val_loss: 2.2122
# Epoch 96/100
# 716/716 [==============================] - 46s 64ms/step - loss: 1.6330 - val_loss: 2.2078
# Epoch 97/100
# 716/716 [==============================] - 46s 64ms/step - loss: 1.6386 - val_loss: 2.2084
# Epoch 98/100
# 716/716 [==============================] - 46s 64ms/step - loss: 1.6337 - val_loss: 2.2088
# Epoch 99/100
# 716/716 [==============================] - 46s 64ms/step - loss: 1.6290 - val_loss: 2.2115
# Epoch 100/100
# 716/716 [==============================] - 46s 64ms/step - loss: 1.6292 - val_loss: 2.2075

# %%
# Plot History
history_dict = history.history
plt.plot(range(1,epochs+1), history_dict['loss'], 'r', label='Training loss')
plt.plot(range(1,epochs+1), history_dict['val_loss'], 'g', label='Validation loss')
plt.title('Seq2Seq Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Inference Models

# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs,
                      state_h, state_c])

# Decoder setup

# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim, ))
decoder_state_input_c = Input(shape=(latent_dim, ))
decoder_hidden_state_input = Input(shape=(11, latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2 = dec_emb_layer(decoder_inputs)

# To predict the next word in the sequence, set the initial states to the states from the previous time step
(decoder_outputs2, state_h2, state_c2) = decoder_lstm(dec_emb2,
        initial_state=[decoder_state_input_h, decoder_state_input_c])

# Attention
decoder_outputs2 = decoder_attention([decoder_hidden_state_input,decoder_outputs2])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_outputs2)

# Final decoder model
decoder_model = Model([decoder_inputs] + [decoder_hidden_state_input,
                      decoder_state_input_h, decoder_state_input_c],
                      [decoder_outputs2] + [state_h2, state_c2])

# %%
# Test
real = np.load("encoded_jokes.npy", allow_pickle=True)
for i in range(6):
  keywords = seq_in[i]
  kw = detokenize(keywords)
  print("KEYWORDS:", [x for x in kw if x != '[PAD]' and x != '[START]'])
  true = detokenize(real[i])
  print("TRUE:", ' '.join([x for x in true if x != '[PAD]']))
  generated = decode_sequence(keywords.reshape(1, 11))
  print("GENERATED:", generated)
  print("")
# Out:
# KEYWORDS: ['switch', 'light', 'arguing']
# TRUE: how do you end two deaf persons ' arguing ? switch off the light .
# GENERATED:  how do you switch a light in a light switch ? you switch off in the light switch .
#
# KEYWORDS: ['suckin', 'lot', 'lose', 'hurricane', 'house', 'first', 'common', 'blowin']
# TRUE: what does a blonde have in common with a hurricane ? first there is a lot of suckin and blowin , then you lose your house .
# GENERATED:  what does a hurricane and a hurricane have in common ? they both blow your blow up and suckin and then blow your house .
#
# KEYWORDS: ['went', 'floats', 'day', 'circles']
# TRUE: i went to a white pride parade the other day . the floats just kept going around in circles about 200 miles per hour .
# GENERATED:  i went to a zoo the other day but it was a nice day . i was going to buy some shit .
#
# KEYWORDS: ['would', 'neighbor', 'joke', 'home', 'close']
# TRUE: i would make a joke about my neighbor . but it would be too close to home
# GENERATED:  my neighbor is so close to be home . he would be close to be home .
#
# KEYWORDS: ['god', 'everything', 'difference']
# TRUE: what is the difference between god and you ex wife ? god only wants 10 things . your ex wife wants half of everything .
# GENERATED:  what is the difference between god and god ? god wants to make everything up in a woman
#
# KEYWORDS: ['swear', 'castrate']
# TRUE: i swear , i will castrate you do it , you won t . no balls bro .
# GENERATED:  how do you castrate a swear ? you ' ll castrate

# %%
# Save models
with open('encoder_model.json', 'w', encoding='utf8') as f:
    f.write(encoder_model.to_json())
encoder_model.save_weights('encoder_model_weights.h5')

with open('decoder_model.json', 'w', encoding='utf8') as f:
    f.write(decoder_model.to_json())
decoder_model.save_weights('decoder_model_weights.h5')

# %%
# Download models and weights
files.download('encoder_model.json)
files.download('encoder_model_weights.h5')
files.download('decoder_model.json)
files.download('decoder_model_weights.h5')

# %%
# Load models and weights
encoder_model = load_model('encoder_model.json', 'encoder_model_weights.h5')
decoder_model = load_model('decoder_model.json', 'decoder_model_weights.h5')

# %%
# Test
start_prompt = "trump"
start_tokens = tokenizer.tokenize(start_prompt)
start_tokens = tf.squeeze(start_tokens,axis=0)
start_tokens = list(tf.squeeze(start_tokens, axis=1).numpy())
start_tokens = keras.preprocessing.sequence.pad_sequences([start_tokens],
                                            value=0,
                                            padding='post',
                                            maxlen=11)[0] 

print("KEYWORDS:", start_prompt)
print("OUTPUT:", decode_sequence(start_tokens.reshape(1, 11)))
# Out:
# KEYWORDS: trump
# OUTPUT:  what is the best part about eating a black guy ? a shot knock

# %% [markdown]
# # BiLSTM

# %%
# Simple BiLSTM
inputs = layers.Input(shape=(maxlen,), dtype=tf.int32)
# Embedding
x = layers.Embedding(vocab_size, 100, input_length=maxlen)(inputs)
# BiLSTM
x = layers.Bidirectional(layers.LSTM(100,return_sequences=True))(x)
# Outputs
outputs = layers.Dense(vocab_size)(x)

# Setup model
model = keras.Model(inputs=inputs, outputs=[outputs, x])
# Loss
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
# Compile
model.compile(optimizer="adam", loss=[loss_fn, None],)
# Summarize
model.summary()
# Out:
# Model: "model_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_15 (InputLayer)        [(None, 30)]              0
# _________________________________________________________________
# embedding_22 (Embedding)     (None, 30, 100)           983200
# _________________________________________________________________
# bidirectional_13 (Bidirectio (None, 30, 200)           160800
# _________________________________________________________________
# dense_22 (Dense)             (None, 30, 9832)          1976232
# =================================================================
# Total params: 3,120,232
# Trainable params: 3,120,232
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 10

# Fit model
history = model.fit(dataset, epochs=epochs, validation_data=valid, callbacks=[text_gen_callback])
# Out:
# Epoch 1/10
# 715/715 [==============================] - 29s 35ms/step - loss: 3.8340 - dense_22_loss: 3.8340 - val_loss: 2.8656 - val_dense_22_loss: 2.8656
# generated text:
# what do you call when
#
# Epoch 2/10
# 715/715 [==============================] - 25s 35ms/step - loss: 2.3894 - dense_22_loss: 2.3894 - val_loss: 2.0240 - val_dense_22_loss: 2.0240
# generated text:
# what do you know do
#
# Epoch 3/10
# 715/715 [==============================] - 25s 34ms/step - loss: 1.7467 - dense_22_loss: 1.7467 - val_loss: 1.5164 - val_dense_22_loss: 1.5164
# generated text:
# what do you say when when do
#
# Epoch 4/10
# 715/715 [==============================] - 25s 34ms/step - loss: 1.2826 - dense_22_loss: 1.2826 - val_loss: 1.1212 - val_dense_22_loss: 1.1212
# generated text:
# what do you say
#
# Epoch 5/10
# 715/715 [==============================] - 25s 34ms/step - loss: 0.9257 - dense_22_loss: 0.9257 - val_loss: 0.8228 - val_dense_22_loss: 0.8228
# generated text:
# what do you say
#
# Epoch 6/10
# 715/715 [==============================] - 25s 34ms/step - loss: 0.6583 - dense_22_loss: 0.6583 - val_loss: 0.6010 - val_dense_22_loss: 0.6010
# generated text:
# what do you say
#
# Epoch 7/10
# 715/715 [==============================] - 25s 34ms/step - loss: 0.4589 - dense_22_loss: 0.4589 - val_loss: 0.4373 - val_dense_22_loss: 0.4373
# generated text:
# what do you
#
# Epoch 8/10
# 715/715 [==============================] - 25s 35ms/step - loss: 0.3149 - dense_22_loss: 0.3149 - val_loss: 0.3204 - val_dense_22_loss: 0.3204
# generated text:
# what do you say
#
# Epoch 9/10
# 715/715 [==============================] - 24s 34ms/step - loss: 0.2142 - dense_22_loss: 0.2142 - val_loss: 0.2380 - val_dense_22_loss: 0.2380
# generated text:
# what do you say
#
# Epoch 10/10
# 715/715 [==============================] - 25s 34ms/step - loss: 0.1450 - dense_22_loss: 0.1450 - val_loss: 0.1799 - val_dense_22_loss: 0.1799
# generated text:
# what do you

# %%
# Save model
model.save_weights('bilstm_sub.h5')

# Download model
files.download('bilstm_sub.h5')

# %%
# Plot History
history_dict = history.history
plt.plot(range(1,epochs+1), history_dict['loss'], 'r', label='Training loss')
plt.plot(range(1,epochs+1), history_dict['val_loss'], 'g', label='Validation loss')
plt.title('BiLSTM Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
start_prompt = "how do"
start_tokens = tokenizer.tokenize(start_prompt)
start_tokens = tf.squeeze(start_tokens,axis=0)
start_tokens = list(tf.squeeze(start_tokens, axis=1).numpy())
generate(model, maxlen, start_tokens, tokenizer)

# %%
# Test
#model.load_weights('bilstm_sub.h5')
test_model(model)
# Out:
# TRUE:  how do you end two deaf persons ' arguing ? switch off the light .
# INPUT:  how do you end two deaf persons '
# GENERATED:  how do you end two deaf persons ' say alike alike alike alike alike alike alike alike cells ? racists racists racists racists racists racists racists racists racists racists racists yourself yourself yourself yourself yourself yourself yourself yourself yourself
#
# TRUE:  what does a blonde have in common with a hurricane ? first there is a lot of suckin and blowin , then you lose your house .
# INPUT:  What does a blonde have in common with a hurricane
# GENERATED:  what does a blonde have in common with a hurricane dinosaur dinosaur rhymes cells say timing out out wine ? fsh tickles . rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit
#
# TRUE:  i went to a white pride parade the other day . the floats just kept going around in circles about 200 miles per hour .
# INPUT:  I went to a white pride parade the other day
# GENERATED:  i went to a white pride parade the other day asked say asked say asked say asked say asked say asked say asked say asked say asked say asked say wonderwall wonderwall wonderwall wonderwall wonderwall wonderwall wonderwall wonderwall wonderwall wonderwall wonderwall
#
# TRUE:  i would make a joke about my neighbor . but it would be too close to home
# INPUT:  i would  make a joke about my neighbor
# GENERATED:  i would make a joke about my neighbor says asked say wonderwall say asked say asked say asked say asked say asked say asked say asked say asked say asked amy amy amy amy amy amy amy amy amy
#
# TRUE:  what is the difference between god and you ex wife ? god only wants 10 things . your ex wife wants half of everything .
# INPUT:  what is the difference between god and you
# GENERATED:  what is the difference between god and you say timing say timing heard cells say timing say timing say rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit rubbit

# %%
# Simple BiLSTM
inputs = layers.Input(shape=(maxlen,), dtype=tf.int32)
# Embedding
x = layers.Embedding(vocab_size, 300, input_length=maxlen)(inputs)
# BiLSTM
x = layers.Bidirectional(layers.LSTM(100,return_sequences=True))(x)
# Outputs
outputs = layers.Dense(vocab_size)(x)

# Setup model
model = keras.Model(inputs=inputs, outputs=[outputs, x])
# Loss
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
# Compile
model.compile("adam", loss='categorical_crossentropy')  # No loss and optimization based on word embeddings from transformer block
# Summarize
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 30)]              0
# _________________________________________________________________
# embedding (Embedding)        (None, 30, 300)           2949600
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               160400
# _________________________________________________________________
# dense_9 (Dense)              (None, 9832)              993032
# =================================================================
# Total params: 4,103,032
# Trainable params: 4,103,032
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Transformer (Archived)

# %%
########################################## TRANSFORMER ############################################

def causal_attention_mask(batch_size, n_dest, n_src, dtype):
    """
    Mask the upper half of the dot product matrix in self attention.
    This prevents flow of information from future tokens to current token.
    1's in the lower triangle, counting from the lower right corner.
    """
    i = tf.range(n_dest)[:, None]
    j = tf.range(n_src)
    m = i >= j - n_src + n_dest
    mask = tf.cast(m, dtype)
    mask = tf.reshape(mask, [1, n_dest, n_src])
    mult = tf.concat(
        [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)], 0
    )
    return tf.tile(mask, mult)

class TokenAndPositionEmbedding(layers.Layer):
    def __init__(self, maxlen, vocab_size, embed_dim):
        super(TokenAndPositionEmbedding, self).__init__()
        self.token_emb = layers.Embedding(input_dim=vocab_size, output_dim=embed_dim)
        self.pos_emb = layers.Embedding(input_dim=maxlen, output_dim=embed_dim)

    def call(self, x):
        maxlen = tf.shape(x)[-1]
        positions = tf.range(start=0, limit=maxlen, delta=1)
        positions = self.pos_emb(positions)
        x = self.token_emb(x)
        return x + positions

class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = layers.MultiHeadAttention(num_heads, embed_dim)
        self.ffn = keras.Sequential(
            [layers.Dense(ff_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size = input_shape[0]
        seq_len = input_shape[1]
        causal_mask = causal_attention_mask(batch_size, seq_len, seq_len, tf.bool)
        attention_output = self.att(inputs, inputs, attention_mask=causal_mask)
        attention_output = self.dropout1(attention_output)
        out1 = self.layernorm1(inputs + attention_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output)
        return self.layernorm2(out1 + ffn_output)

# %%
# Initiatialise test tokens
start_prompt = "how do you"
start_tokens = [word_to_index.get(_, 1) for _ in start_prompt.split()]
num_tokens_generated = 40
text_gen_callback = TextGenerator(num_tokens_generated, start_tokens, vocab)

# %%
################ Transformer Params ###########
embed_dim = 256  # Embedding size for each token
num_heads = 3  # Number of attention heads
feed_forward_dim = 256  # Hidden layer size in feed forward network inside transformer

# %%
# GPT2 Style Transformer
inputs = layers.Input(shape=(maxlen,), dtype=tf.int32)
embedding_layer = TokenAndPositionEmbedding(maxlen, vocab_size, embed_dim)
x = embedding_layer(inputs)
transformer_block1 = TransformerBlock(embed_dim, num_heads, feed_forward_dim)
x = transformer_block1(x)
transformer_block2 = TransformerBlock(embed_dim, num_heads, feed_forward_dim)
x = transformer_block2(x)
transformer_block3 = TransformerBlock(embed_dim, num_heads, feed_forward_dim)
x = transformer_block3(x)
transformer_block4 = TransformerBlock(embed_dim, num_heads, feed_forward_dim)
x = transformer_block4(x)
outputs = layers.Dense(vocab_size)(x)
model = keras.Model(inputs=inputs, outputs=[outputs, x])
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
model.compile("adam", loss=[loss_fn, None],)  # No loss and optimization based on word embeddings from transformer block
model.summary()
# Out:
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        [(None, 50)]              0
# _________________________________________________________________
# token_and_position_embedding (None, 50, 256)           15372800
# _________________________________________________________________
# transformer_block_4 (Transfo (None, 50, 256)           921600
# _________________________________________________________________
# transformer_block_5 (Transfo (None, 50, 256)           921600
# _________________________________________________________________
# transformer_block_6 (Transfo (None, 50, 256)           921600
# _________________________________________________________________
# transformer_block_7 (Transfo (None, 50, 256)           921600
# _________________________________________________________________
# dense_26 (Dense)             (None, 50, 60000)         15420000
# =================================================================
# Total params: 34,479,200
# Trainable params: 34,479,200
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit model
model.fit(dataset, verbose=2, epochs=50, callbacks=[text_gen_callback])

# Save model
model.save_weights('transformer.h5')

files.download('transformer.h5')
# Out:
# Epoch 1/50
# 59/59 - 18s - loss: 4.7691 - dense_14_loss: 4.7691
# generated text:
# how do you end two deaf , . . ? i a the you i . a . a you . " a ? . ? to ? . a ? . a a ? . the the " . ? is . " the , is
#
# Epoch 2/50
# 59/59 - 14s - loss: 2.8492 - dense_14_loss: 2.8492
# generated text:
# how do you end two deaf is do the do the was have the do you have the the was a you a you is a to a have have was ? .
#
# Epoch 3/50
# 59/59 - 14s - loss: 2.7328 - dense_14_loss: 2.7328
# generated text:
# how do you end two deaf is the difference be have was call i a have was be have the a be do .
#
# Epoch 4/50
# 59/59 - 14s - loss: 2.6124 - dense_14_loss: 2.6124
# generated text:
# how do you end two deaf a bar " to the other a wife i was a guy and the new guy to be a other a bar the new wife . . " , " the bar . .
#
# Epoch 5/50
# 59/59 - 14s - loss: 2.4347 - dense_14_loss: 2.4347
# generated text:
# how do you end two deaf ? it is like the other of his bar .
#
# Epoch 6/50
# 59/59 - 14s - loss: 2.2295 - dense_14_loss: 2.2295
# generated text:
# how do you end two deaf people ? a new lot .
#
# Epoch 7/50
# 59/59 - 14s - loss: 2.0607 - dense_14_loss: 2.0607
# generated text:
# how do you end two deaf people in you have in common ? because it is a bar .
#
# Epoch 8/50
# 59/59 - 14s - loss: 1.9109 - dense_14_loss: 1.9109
# generated text:
# how do you end two deaf people with a good ? a few hours .
#
# Epoch 9/50
# 59/59 - 14s - loss: 1.7777 - dense_14_loss: 1.7777
# generated text:
# how do you end two deaf women ? a big time and #x200b ;
#
# Epoch 10/50
# 59/59 - 14s - loss: 1.6485 - dense_14_loss: 1.6485
# generated text:
# how do you end two deaf people in a light bulb ? no legs . the first .
#
# Epoch 11/50
# 59/59 - 14s - loss: 1.5226 - dense_14_loss: 1.5226
# generated text:
# how do you end two deaf people on work ? can 't go to the fuck out
#
# Epoch 12/50
# 59/59 - 14s - loss: 1.4003 - dense_14_loss: 1.4003
# generated text:
# how do you end two deaf people on the same time ? because they are catcalling them .
#
# Epoch 13/50
# 59/59 - 14s - loss: 1.2814 - dense_14_loss: 1.2814
# generated text:
# how do you end two deaf people ? ask her too much .
#
# Epoch 14/50
# 59/59 - 14s - loss: 1.1622 - dense_14_loss: 1.1622
# generated text:
# how do you end two deaf people in his hands ? ask her too .
#
# Epoch 15/50
# 59/59 - 14s - loss: 1.0513 - dense_14_loss: 1.0513
# generated text:
# how do you end two deaf people from the same . . it will now be the same time
#
# Epoch 16/50
# 59/59 - 14s - loss: 0.9492 - dense_14_loss: 0.9492
# generated text:
# how do you end two deaf people on a nudist ? not dutch me "
#
# Epoch 17/50
# 59/59 - 14s - loss: 0.8545 - dense_14_loss: 0.8545
# generated text:
# how do you end two deaf persons ' arguing ? switch off the a booby shells ? they don 't want to the karma .
#
# Epoch 18/50
# 59/59 - 14s - loss: 0.7709 - dense_14_loss: 0.7709
# generated text:
# how do you end two deaf people from no legs ? very nice belt .
#
# Epoch 19/50
# 59/59 - 14s - loss: 0.6905 - dense_14_loss: 0.6905
# generated text:
# how do you end two deaf people at work ? turn off a coma .
#
# Epoch 20/50
# 59/59 - 14s - loss: 0.6182 - dense_14_loss: 0.6182
# generated text:
# how do you end two deaf persons ' arguing ? narcolepsy
#
# Epoch 21/50
# 59/59 - 14s - loss: 0.5567 - dense_14_loss: 0.5567
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light .
#
# Epoch 22/50
# 59/59 - 14s - loss: 0.4978 - dense_14_loss: 0.4978
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light .
#
# Epoch 23/50
# 59/59 - 14s - loss: 0.4486 - dense_14_loss: 0.4486
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light .
#
# Epoch 24/50
# 59/59 - 14s - loss: 0.4103 - dense_14_loss: 0.4103
# generated text:
# how do you end two deaf persons ' arguing it wont ?
#
# Epoch 25/50
# 59/59 - 14s - loss: 0.3772 - dense_14_loss: 0.3772
# generated text:
# how do you end two deaf people from work ? boss defecated in the front of it out the ass .
#
# Epoch 26/50
# 59/59 - 14s - loss: 0.3474 - dense_14_loss: 0.3474
# generated text:
# how do you end two deaf people outside were cutting through the front door ? fucking school .
#
# Epoch 27/50
# 59/59 - 14s - loss: 0.3242 - dense_14_loss: 0.3242
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light .
#
# Epoch 28/50
# 59/59 - 14s - loss: 0.3039 - dense_14_loss: 0.3039
# generated text:
# how do you end two deaf persons ' in the wrong ? switch . credits . the light . . the light at the light the count again . . .
#
# Epoch 29/50
# 59/59 - 14s - loss: 0.2828 - dense_14_loss: 0.2828
# generated text:
# how do you end two deaf persons ' play cards ? switch to the light .
#
# Epoch 30/50
# 59/59 - 14s - loss: 0.2651 - dense_14_loss: 0.2651
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light .
#
# Epoch 31/50
# 59/59 - 14s - loss: 0.2529 - dense_14_loss: 0.2529
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light .
#
# Epoch 32/50
# 59/59 - 14s - loss: 0.2409 - dense_14_loss: 0.2409
# generated text:
# how do you end two deaf people from work ? turn off the front of them in 3 .
#
# Epoch 33/50
# 59/59 - 14s - loss: 0.2304 - dense_14_loss: 0.2304
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light .
#
# Epoch 34/50
# 59/59 - 14s - loss: 0.2239 - dense_14_loss: 0.2239
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light .
#
# Epoch 35/50
# 59/59 - 14s - loss: 0.2169 - dense_14_loss: 0.2169
# generated text:
# how do you end two deaf people ? just ice .
#
# Epoch 36/50
# 59/59 - 14s - loss: 0.2113 - dense_14_loss: 0.2113
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light .
#
# Epoch 37/50
# 59/59 - 14s - loss: 0.2047 - dense_14_loss: 0.2047
# generated text:
# how do you end two deaf persons ' arguing ? they wouldn’t leave .
#
# Epoch 38/50
# 59/59 - 14s - loss: 0.2003 - dense_14_loss: 0.2003
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light .
#
# Epoch 39/50
# 59/59 - 14s - loss: 0.1963 - dense_14_loss: 0.1963
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light .
#
# Epoch 40/50
# 59/59 - 14s - loss: 0.1923 - dense_14_loss: 0.1923
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light .
#
# Epoch 41/50
# 59/59 - 14s - loss: 0.1907 - dense_14_loss: 0.1907
# generated text:
# how do you end two deaf people ? turn off
#
# Epoch 42/50
# 59/59 - 14s - loss: 0.1876 - dense_14_loss: 0.1876
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light .
#
# Epoch 43/50
# 59/59 - 14s - loss: 0.1856 - dense_14_loss: 0.1856
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light .
#
# Epoch 44/50
# 59/59 - 14s - loss: 0.1814 - dense_14_loss: 0.1814
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light .
#
# Epoch 45/50
# 59/59 - 14s - loss: 0.1802 - dense_14_loss: 0.1802
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light
#
# Epoch 46/50
# 59/59 - 14s - loss: 0.1792 - dense_14_loss: 0.1792
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light .
#
# Epoch 47/50
# 59/59 - 14s - loss: 0.1795 - dense_14_loss: 0.1795
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light .
#
# Epoch 48/50
# 59/59 - 14s - loss: 0.1766 - dense_14_loss: 0.1766
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light .
#
# Epoch 49/50
# 59/59 - 14s - loss: 0.1746 - dense_14_loss: 0.1746
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light .
#
# Epoch 50/50
# 59/59 - 14s - loss: 0.1720 - dense_14_loss: 0.1720
# generated text:
# how do you end two deaf persons ' arguing ? switch off the light .

# %%
# Test
model.load_weights('transformer.h5')
test_model(model)
# Out:
# TRUE:  how do you end two deaf persons' arguing? switch off the light.
# INPUT:  how do you end two deaf persons
# GENERATED:  how do you end two deaf persons ' arguing ? switch off the light .
#
# TRUE:  what does a blonde have in common with a hurricane? first there is a lot of suckin and blowin, then you lose your house.
# INPUT:  What does a blonde have in common with a hurricane
# GENERATED:  what does a blonde have in common with a hurricane ? first there is a lot of suckin and blowin , then you lose your house .
#
# TRUE:  i went to a white pride parade the other day. the floats just kept going around in circles about 200 miles per hour.
# INPUT:  I went to a white pride parade the other day
# GENERATED:  i went to a white pride parade the other day . the floats just kept going around in circles about 200 miles per hour .
#
# TRUE:  going to make an app. i have decided to create an app where you tour museums and art galleries finding famous paintings.  i am going to call it van gogh.   source - me
# INPUT:  Going to make an app
# GENERATED:  going to make an app . i have decided to create an app where you tour museums and art galleries finding famous paintings . i am going to call it van gogh . source - me
#
# TRUE:  i would  make a joke about my neighbor.... but it would be too close to home
# INPUT:  i would  make a joke about my neighbor
# GENERATED:  i would make a joke about my neighbor . . . . but it would be too close to home
#
# TRUE:  what is the difference between god and you ex-wife? god only wants 10 things.   your ex-wife wants half of everything.
# INPUT:  what is the difference between god and you
# GENERATED:  what is the difference between god and you ex -wife ? god only wants 10 things . your ex -wife wants half of everything .

# %% [markdown]
# # PyTorch Models (Archived)

# %%
def train(epoch):
    model.train()
    train_loss = 0.
    for i, x in enumerate(train_loader):
        optimizer.zero_grad()
        if cuda:
            x = x.cuda()
        _, logits = model(x)
        loss = criterion(logits, x)

        train_loss += loss.item()
        loss.backward()
        optimizer.step()
        #if interval > 0 and i % interval == 0:
            #print('Epoch: {} | Batch: {}/{} ({:.0f}%) | Loss: {:.6f}'.format(
                #epoch, batch_size*i, len(train_loader.dataset),
                #100.*(batch_size*i)/len(train_loader.dataset),
                #loss.item()
            #))
        
    train_loss /= len(train_loader)
    print('* (Train) Epoch: {} | Loss: {:.4f}'.format(epoch, train_loss))
    return train_loss

# %%
################################ Autoencoder Pytorch #################################
import math
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import TransformerEncoder, TransformerEncoderLayer, TransformerDecoderLayer, TransformerDecoder
import torch.optim as optim
import torch.autograd as autograd
from torch.autograd import Variable
from torch.distributions.normal import Normal
from torch.utils.data import DataLoader

class Autoencoder(nn.Module):
    def __init__(self, enc_hidden_dim, dec_hidden_dim, embedding_dim, 
                 latent_dim, vocab_size, dropout, seq_len, num_layers):
        super().__init__()

        self.seq_len = seq_len

        # Embedding
        self.embedding = nn.Embedding(vocab_size, embedding_dim)

        # Encoder
        self.encoder = nn.LSTM(embedding_dim, 
                               enc_hidden_dim, 
                               num_layers, 
                               bidirectional=True, 
                               dropout=dropout)
        
        self.fc1 = nn.Linear(enc_hidden_dim, latent_dim)
        self.relu = nn.ReLU(True)
        self.dropout = nn.Dropout(dropout)

        # Decoder
        self.fc2 = nn.Linear(latent_dim, dec_hidden_dim)
        self.decoder = nn.LSTM(dec_hidden_dim, 
                               dec_hidden_dim, 
                               num_layers, 
                               #bidirectional=True, 
                               dropout=dropout)
        
        self.fc3 = nn.Linear(dec_hidden_dim, vocab_size)

    def encode(self, x):
        x = self.embedding(x).permute(1,0,2) # [T,B,E]
        _, (hidden, _) = self.encoder(x)
        #print(hidden.shape)
        z = self.fc1(hidden) # [1,B,L]
        z = self.dropout(z)
        return z
    
    def decode(self, z):
        z = self.fc2(z) # [1,B,H_dec]
        out, _ = self.decoder(z.repeat(self.seq_len,1,1), (z, z))
        # Permute from (time, batch, dim) to (batch, time, dim)
        out = out.permute(1,0,2)
        logits = self.fc3(out)
        return logits.transpose(1,2)
    
    def forward(self, x):
        z = self.encode(x)
        logits = self.decode(z)
        return (z.squeeze(), logits)

class Block(nn.Module):
    
    def __init__(self, block_dim):
        super().__init__()

        self.net = nn.Sequential(
            nn.Linear(block_dim, block_dim),
            nn.ReLU(True),
            nn.Linear(block_dim, block_dim),
        )
    
    def forward(self, x):
        return self.net(x) + x

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd
from torch.autograd import Variable
from torch.distributions.normal import Normal
from torch.utils.data import DataLoader
######################################## VAE #########################################
class VAE(nn.Module):
    def __init__(self, enc_hidden_dim, dec_hidden_dim, embedding_dim, 
                 latent_dim, vocab_size, dropout, seq_len):
        super().__init__()

        self.seq_len = seq_len

        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.encoder = nn.LSTM(embedding_dim, enc_hidden_dim)
        self.mu = nn.Linear(enc_hidden_dim, latent_dim)
        self.sigma = nn.Linear(enc_hidden_dim, latent_dim)
        self.fc1 = nn.Linear(latent_dim, latent_dim)
        self.relu = nn.ReLU(True)
        self.dropout = nn.Dropout(dropout)
        self.fc2 = nn.Linear(latent_dim, dec_hidden_dim)
        self.decoder = nn.LSTM(dec_hidden_dim, dec_hidden_dim)
        self.fc3 = nn.Linear(dec_hidden_dim, vocab_size)
        self.kl = 0

    def sample(self, mu, sigma):
        eps = Variable(torch.randn(mu.size())).cuda()
        std = torch.exp(sigma / 2.0)
        return mu + eps * std

    def encode(self, x):
        x = self.embedding(x).permute(1,0,2) # [T,B,E]
        _, (hidden, _) = self.encoder(x)
        mu = self.mu(hidden)
        sigma = self.sigma(hidden)
        z = self.sample(mu, sigma)
        z = self.fc1(z)
        z = self.dropout(z)
        self.kl = (sigma**2 + mu**2 - torch.log(sigma) - 1/2).sum()
        return z, mu, sigma
    
    def decode(self, z):
        z = self.fc2(z) # [1,B,H_dec]
        out, _ = self.decoder(z.repeat(self.seq_len,1,1), (z, z))
        out = out.permute(1,0,2) # [B,T,H_dec]
        logits = self.fc3(out) # [B,T,V]
        return logits.transpose(1,2)
    
    def forward(self, x):
        z, mu, sigma = self.encode(x)
        logits = self.decode(z)
        return (z.squeeze(), logits, mu, sigma)



def kl_anneal_function(anneal_function, step, k, x0):
    if anneal_function == 'logistic':
        return float(1/(1+np.exp(-k*(step-x0))))
    elif anneal_function == 'linear':
        return min(1, step/x0)


def train_vae(epoch):
    model.train()
    train_loss = 0.
    step = 0
    for i, x in enumerate(train_loader):
        optimizer.zero_grad()
        if cuda:
            x = x.cuda()
        _, logits, mu, sigma = model(x)

        # Reconstruction loss
        ll_loss = criterion(logits, x)

        # KL loss
        KL_loss = -0.5 * torch.sum(1 + sigma - mu.pow(2) - sigma.exp())

        # KL annealing to keep the KL term from disapearing
        KL_weight = min(1, step/2500)

        # Total loss
        loss = ll_loss + KL_loss #* KL_weight

        train_loss += loss.item()
        loss.backward()
        optimizer.step()
        #if interval > 0 and i % interval == 0:
            #print('Epoch: {} | Batch: {}/{} ({:.0f}%) | Loss: {:.6f}'.format(
                #epoch, batch_size*i, len(train_loader.dataset),
                #100.*(batch_size*i)/len(train_loader.dataset),
                #loss.item()
            #))
        step += 1
    train_loss /= len(train_loader)
    print('* (Train) Epoch: {} | Loss: {:.4f}'.format(epoch, train_loss))
    return train_loss

# %%
################################ Transformer Pytorch #################################
import math
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import TransformerEncoder, TransformerEncoderLayer, TransformerDecoderLayer, TransformerDecoder
import torch.optim as optim
import torch.autograd as autograd
from torch.autograd import Variable
from torch.distributions.normal import Normal
from torch.utils.data import DataLoader

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)


class Transformer(nn.Module):
    def __init__(self, enc_hidden_dim, dec_hidden_dim, embedding_dim, 
                 latent_dim, vocab_size, dropout, seq_len):
        super().__init__()
        n_head = 3
        n_layers = 1
        self.seq_len = seq_len
        self.embedding = nn.Embedding(vocab_size, maxlen)
        self.encoder = nn.LSTM(embedding_dim, enc_hidden_dim)
        self.dropout = nn.Dropout(dropout)

        encoder_layers = TransformerEncoderLayer(seq_len, n_head, enc_hidden_dim, dropout)
        self.pos_embed = PositionalEncoding(seq_len, dropout)
        self.transformer_encoder = TransformerEncoder(encoder_layers, n_layers)
        #self.fc1 = nn.Linear(enc_hidden_dim, latent_dim)
        #self.fc2 = nn.Linear(latent_dim, dec_hidden_dim)
        #self.decoder = nn.LSTM(dec_hidden_dim, dec_hidden_dim)
        #self.dropout = nn.Dropout(dropout)

        decoder_layers = TransformerDecoderLayer(seq_len, n_head, dec_hidden_dim, dropout)
        self.decoder = TransformerDecoder(encoder_layers, n_layers)
        self.fc3 = nn.Linear(dec_hidden_dim, vocab_size)


    #def generate_square_subsequent_mask(self, sz):
        #mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        #mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        #return mask


    def encode(self, x):
        #mask = self.generate_square_subsequent_mask(32)
        x = self.embedding(x) * math.sqrt(self.seq_len)
        x = self.pos_embed(x)
        z = self.transformer_encoder(x)
        #z = self.fc1(hidden) # [1,B,L]
        #z = self.dropout(z)
        return z
    
    def decode(self, z):
        #z = self.fc2(z) # [1,B,H_dec]
        out = self.decoder(z.repeat(self.seq_len,1,1), (z, z))
        out = out.permute(1,0,2) # [B,T,H_dec]
        logits = self.fc3(out) # [B,T,V]
        return logits.transpose(1,2)
    
    def forward(self, x):
        z = self.encode(x)
        logits = self.decode(z)
        return (z.squeeze(), logits)

# %%
batch_size = 32
enc_hidden_dim = 100
dec_hidden_dim= 300
embedding_dim = 200 
latent_dim = 100
vocab_size = 9832
dropout = 0.5
maxlen = 30
num_layers = 3
seed=0
epochs=200
lr=5e-4
interval=90
cuda=torch.cuda.is_available()

# Load Data
data = torch.tensor(seq_out,dtype=torch.long)
train_loader = DataLoader(data, batch_size, shuffle=True)

# Build autoencoder
model = Autoencoder(enc_hidden_dim, 
                    dec_hidden_dim, 
                    embedding_dim,
                    latent_dim, 
                    vocab_size, 
                    dropout, 
                    maxlen, 
                    num_layers)
print(model.forward)

# %%
torch.manual_seed(seed)
torch.backends.cudnn.deterministic = True
total_loss = []
if cuda:
   model = model.cuda()
   print('Parameters:', sum([p.numel() for p in model.parameters() if p.requires_grad]))
   print('Vocab size:', vocab_size)
   criterion = nn.CrossEntropyLoss()
   optimizer = optim.Adam(model.parameters(), lr=lr)
   best_loss = np.inf
   for epoch in range(1, epochs + 1):
     loss = train(epoch)
     total_loss.append(loss)
   
     # Test after each epoch
     sample = data[:3].cuda()
     for x in sample:
       print('REAL:', decode(x[x>0][None,:].cpu()))
       z = model.encode(x[None, :])
  
       # create new sent
       logits = model.decode(z).squeeze()
       seq = logits.argmax(dim=0)
       seq = seq[seq>0].cpu()
       print("RECONSTRUCTED:", decode(seq[None,:]))
       print("")

     if loss < best_loss:
        best_loss = loss
        print('* Saved\n')
        torch.save(model.state_dict(), 'autoencoder.th')

# %%
plt.plot(range(epochs), total_loss)

# %%
# Test Autoencoder
sample = data[:100].cuda()
for x in sample:
  print('REAL:', decode(x[x>0][None,:].cpu()))
  z = model.encode(x[None, :])
  
  # create new sent
  logits = model.decode(z).squeeze()
  seq = logits.argmax(dim=0)
  seq = seq[seq>0]
  seq = seq[None,:].cpu()

  print("RECONSTRUCTED:",decode(seq))
  print("")
